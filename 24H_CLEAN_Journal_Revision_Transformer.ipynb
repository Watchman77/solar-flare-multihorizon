# %% [markdown]
# <a href="https://colab.research.google.com/github/Watchman77/solar-flare-multihorizon/blob/main/24H_CLEAN_Journal_Revision_Transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 24H Journal Revision — Clean Transformer Benchmark
#
# This clean notebook runs the **24h forecasting branch** using the former 24h code as the base, but fixes the revision issues:
#
# 1. Uses the same 24h dataset and features: **16 SHARP magnetic features + GOES-derived flare-history features**.
# 2. Builds chronological lookback sequences.
# 3. Trains **LSTM, BiLSTM, Transformer, and DLSTM**.
# 4. Uses scaled inputs consistently.
# 5. Tunes decision thresholds on the **validation set only**.
# 6. Selects weighted ensemble weights using **validation TSS only**.
# 7. Saves a manuscript-ready results table for the 24h section.
#
# No stale/manual table. No test-set weight selection.

# %%
# ============================================================
# 0. Mount Google Drive
# ============================================================

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ============================================================
# 1. Imports and reproducibility
# ============================================================

import os
import random
import joblib
import numpy as np
import pandas as pd
import tensorflow as tf

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    confusion_matrix,
    roc_auc_score,
    average_precision_score,
    precision_score,
    recall_score,
    f1_score
)
from sklearn.linear_model import LogisticRegression
from sklearn.utils.class_weight import compute_class_weight

from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

SEED = 42

os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print("TensorFlow:", tf.__version__)
print("Seed fixed:", SEED)
# Out:
# TensorFlow: 2.20.0
# Seed fixed: 42

# %%
# ============================================================
# 2. Experiment configuration
# ============================================================

DATA_PATH_24H = "/content/drive/MyDrive/AR_Stratified/24H_FINAL_CLEAN_READY.csv"
OUT_DIR = "/content/drive/MyDrive/AR_Stratified/Journal_Revision_24h_CLEAN_TRANSFORMER"
os.makedirs(OUT_DIR, exist_ok=True)

TIME_COL = "T_REC_dt"
AR_COL = "NOAA_AR"
LABEL_COL = "label_MX_1d"

LOOKBACK_24H = 4          # 4 sampled states; physical span is measured below from the actual cadence.
MA_WINDOW = 3
EPOCHS = 30
BATCH_SIZE = 128

MAG_FEATURES = [
    "MEANGBZ", "MEANGAM", "MEANGBT", "MEANGBH", "MEANJZD",
    "TOTUSJZ", "MEANALP", "MEANJZH", "ABSNJZH", "SAVNCPP",
    "MEANSHR", "SHRGT45", "R_VALUE", "USFLUX", "TOTPOT", "TOTUSJH"
]

FLARE_HISTORY_FEATURES = [
    "flare_count_past_24h",
    "time_since_last_flare_hours_24h",
    "max_peak_flux_past_24h",
    "mean_peak_flux_past_24h",
    "flare_activity_index_past_24h"
]

ALL_FEATURES = MAG_FEATURES + FLARE_HISTORY_FEATURES

print("DATA_PATH_24H:", DATA_PATH_24H)
print("OUT_DIR:", OUT_DIR)
print("LOOKBACK_24H:", LOOKBACK_24H)
print("MA_WINDOW:", MA_WINDOW)
print("Magnetic features:", len(MAG_FEATURES))
print("Flare-history features:", len(FLARE_HISTORY_FEATURES))
print("Total features:", len(ALL_FEATURES))
# Out:
# DATA_PATH_24H: /content/drive/MyDrive/AR_Stratified/24H_FINAL_CLEAN_READY.csv
# OUT_DIR: /content/drive/MyDrive/AR_Stratified/Journal_Revision_24h_CLEAN_TRANSFORMER
# LOOKBACK_24H: 4
# MA_WINDOW: 3
# Magnetic features: 16
# Flare-history features: 5
# Total features: 21

# %%
# ============================================================
# 3. Load, clean, and inspect dataset
# ============================================================

df = pd.read_csv(DATA_PATH_24H)

print("Raw shape:", df.shape)
print("Columns:", df.columns.tolist())

required_cols = [TIME_COL, AR_COL, LABEL_COL] + ALL_FEATURES
missing_cols = [c for c in required_cols if c not in df.columns]
assert len(missing_cols) == 0, f"Missing columns: {missing_cols}"

df[TIME_COL] = pd.to_datetime(df[TIME_COL], errors="coerce")

for col in ALL_FEATURES:
    df[col] = pd.to_numeric(df[col], errors="coerce")

df = df.dropna(subset=required_cols).copy()
df[LABEL_COL] = df[LABEL_COL].astype(int)
df = df.sort_values([AR_COL, TIME_COL]).reset_index(drop=True)

print("Clean shape:", df.shape)
print("Label distribution:", df[LABEL_COL].value_counts().to_dict())
print("Positive prevalence:", df[LABEL_COL].mean())

display(df[[TIME_COL, AR_COL, LABEL_COL] + ALL_FEATURES[:8]].head())
# Out:
# Raw shape: (22355, 26)
# Columns: ['T_REC_dt', 'year', 'NOAA_AR', 'MEANGBZ', 'MEANGAM', 'MEANGBT', 'MEANGBH', 'MEANJZD', 'TOTUSJZ', 'MEANALP', 'MEANJZH', 'ABSNJZH', 'SAVNCPP', 'MEANSHR', 'SHRGT45', 'R_VALUE', 'USFLUX', 'TOTPOT', 'TOTUSJH', 'label_MX_1d', 'flare_count_past_24h', 'time_since_last_flare_hours_24h', 'max_peak_flux_past_24h', 'mean_peak_flux_past_24h', 'flare_activity_index_past_24h', 'had_flare_past_24h']
# Clean shape: (5493, 26)
# Label distribution: {0: 4894, 1: 599}
# Positive prevalence: 0.10904787911887857
#              T_REC_dt  NOAA_AR  label_MX_1d  MEANGBZ  MEANGAM  MEANGBT  \
# 0 2010-05-04 12:00:00    11063            0  114.931   23.572  111.969
# 1 2010-05-04 12:00:00    11066            0  163.612   33.349  158.310
# 2 2010-05-06 12:00:00    11067            0  120.344   30.754  123.132
# 3 2010-05-04 12:00:00    11068            0   68.033   20.239   66.450
# 4 2010-05-06 12:00:00    11068            0  109.701   29.563  109.877
#
#    MEANGBH   MEANJZD       TOTUSJZ   MEANALP   MEANJZH
# 0   48.270 -0.446712  1.144288e+12 -0.006346 -0.003990
# 1   83.826  2.161599  9.491178e+11 -0.047176 -0.023881
# 2   52.503  0.809853  5.854035e+12 -0.000631 -0.000130
# 3   27.658 -0.044283  2.832238e+12  0.004054  0.001657
# 4   44.013  0.177906  7.031297e+12  0.024635  0.006839

# %%
# ============================================================
# 4. Cadence and lookback diagnostics
# ============================================================

cadence_hours = (
    df.sort_values([AR_COL, TIME_COL])
      .groupby(AR_COL)[TIME_COL]
      .diff()
      .dt.total_seconds() / 3600.0
).dropna()

print("Cadence diagnostics in hours:")
display(cadence_hours.describe(percentiles=[0.25, 0.50, 0.75, 0.90, 0.95, 0.99]))

median_cadence = float(cadence_hours.median()) if len(cadence_hours) else np.nan
approx_span = (LOOKBACK_24H - 1) * median_cadence if not np.isnan(median_cadence) else np.nan

print(f"Median cadence: {median_cadence:.2f} hours")
print(f"Approximate span between first and final input timestamp: ({LOOKBACK_24H}-1) × {median_cadence:.2f}h = {approx_span:.2f}h")
print("Note: the 24h label horizon refers to the future prediction window, not necessarily the exact input span.")
print(f"Rows with gaps > 2 × median cadence: {int((cadence_hours > 2 * median_cadence).sum()) if not np.isnan(median_cadence) else 'NA'}")
# Out:
# Cadence diagnostics in hours:
# count    4137.000000
# mean       36.142132
# std        28.435667
# min        24.000000
# 25%        24.000000
# 50%        24.000000
# 75%        24.000000
# 90%        72.000000
# 95%        96.000000
# 99%       168.000000
# max       264.000000
# Name: T_REC_dt, dtype: float64
# Median cadence: 24.00 hours
# Approximate span between first and final input timestamp: (4-1) × 24.00h = 72.00h
# Note: the 24h label horizon refers to the future prediction window, not necessarily the exact input span.
# Rows with gaps > 2 × median cadence: 480

# %%
# ============================================================
# 5. Build chronological sequences
# ============================================================

def build_sequences(frame, feature_cols, lookback):
    X_seq, y_seq, t_seq, ar_seq = [], [], [], []

    for ar, group in frame.groupby(AR_COL):
        group = group.sort_values(TIME_COL).reset_index(drop=True)

        if len(group) < lookback:
            continue

        values = group[feature_cols].values.astype(np.float32)
        labels = group[LABEL_COL].values.astype(int)
        times = group[TIME_COL].values

        for i in range(lookback - 1, len(group)):
            X_seq.append(values[i - lookback + 1:i + 1])
            y_seq.append(labels[i])
            t_seq.append(times[i])
            ar_seq.append(ar)

    return (
        np.array(X_seq, dtype=np.float32),
        np.array(y_seq, dtype=int),
        np.array(t_seq),
        np.array(ar_seq)
    )


X_seq, y_seq, t_seq, ar_seq = build_sequences(df, ALL_FEATURES, LOOKBACK_24H)

print("X_seq:", X_seq.shape)
print("y_seq:", y_seq.shape)
print("Positive count:", int(y_seq.sum()))
print("Positive prevalence:", y_seq.mean())
# Out:
# X_seq: (2342, 4, 21)
# y_seq: (2342,)
# Positive count: 344
# Positive prevalence: 0.14688300597779674

# %%
# ============================================================
# 6. Chronological split and scaling
# ============================================================

order = np.argsort(t_seq)

X_seq = X_seq[order]
y_seq = y_seq[order]
t_seq = t_seq[order]
ar_seq = ar_seq[order]

n_total = len(X_seq)
n_train = int(0.70 * n_total)
n_val = int(0.15 * n_total)

X_train_seq = X_seq[:n_train]
y_train_seq = y_seq[:n_train]

X_val_seq = X_seq[n_train:n_train + n_val]
y_val_seq = y_seq[n_train:n_train + n_val]

X_test_seq = X_seq[n_train + n_val:]
y_test_seq = y_seq[n_train + n_val:]

t_train = t_seq[:n_train]
t_val = t_seq[n_train:n_train + n_val]
t_test = t_seq[n_train + n_val:]

ar_train = set(ar_seq[:n_train])
ar_val = set(ar_seq[n_train:n_train + n_val])
ar_test = set(ar_seq[n_train + n_val:])

print("Train:", X_train_seq.shape, "Pos:", int(y_train_seq.sum()))
print("Val  :", X_val_seq.shape, "Pos:", int(y_val_seq.sum()))
print("Test :", X_test_seq.shape, "Pos:", int(y_test_seq.sum()))

print("\nTemporal range:")
print("Train:", pd.to_datetime(t_train.min()), "→", pd.to_datetime(t_train.max()))
print("Val  :", pd.to_datetime(t_val.min()), "→", pd.to_datetime(t_val.max()))
print("Test :", pd.to_datetime(t_test.min()), "→", pd.to_datetime(t_test.max()))

print("\nActive-region overlap across chronological splits:")
print("Train ∩ Val :", len(ar_train & ar_val))
print("Val ∩ Test  :", len(ar_val & ar_test))
print("Train ∩ Test:", len(ar_train & ar_test))

scaler = StandardScaler()
n_features = X_train_seq.shape[-1]

X_train_scaled = scaler.fit_transform(
    X_train_seq.reshape(-1, n_features)
).reshape(X_train_seq.shape)

X_val_scaled = scaler.transform(
    X_val_seq.reshape(-1, n_features)
).reshape(X_val_seq.shape)

X_test_scaled = scaler.transform(
    X_test_seq.reshape(-1, n_features)
).reshape(X_test_seq.shape)

joblib.dump(scaler, os.path.join(OUT_DIR, "scaler_24h_clean_transformer.joblib"))

print("\nScaled shapes:")
print("X_train_scaled:", X_train_scaled.shape)
print("X_val_scaled  :", X_val_scaled.shape)
print("X_test_scaled :", X_test_scaled.shape)
# Out:
# Train: (1639, 4, 21) Pos: 174
# Val  : (351, 4, 21) Pos: 63
# Test : (352, 4, 21) Pos: 107
#
# Temporal range:
# Train: 2010-05-08 12:00:00 → 2023-02-22 12:00:00
# Val  : 2023-02-24 12:00:00 → 2024-02-16 12:00:00
# Test : 2024-02-16 12:00:00 → 2025-04-18 12:00:00
#
# Active-region overlap across chronological splits:
# Train ∩ Val : 1
# Val ∩ Test  : 2
# Train ∩ Test: 0
#
# Scaled shapes:
# X_train_scaled: (1639, 4, 21)
# X_val_scaled  : (351, 4, 21)
# X_test_scaled : (352, 4, 21)

# %%
# ============================================================
# 7. Metric helpers
# ============================================================

def tss_hss_from_cm(cm):
    tn, fp, fn, tp = cm.ravel()

    tpr = tp / (tp + fn + 1e-9)
    fpr = fp / (fp + tn + 1e-9)
    tss = tpr - fpr

    numerator = 2 * (tp * tn - fp * fn)
    denominator = ((tp + fn) * (fn + tn) + (tp + fp) * (fp + tn) + 1e-9)
    hss = numerator / denominator

    return float(tss), float(hss)


def tune_threshold_by_tss(y_true, prob):
    thresholds = np.linspace(0, 1, 1001)
    best_thr = 0.5
    best_tss = -999.0

    for thr in thresholds:
        y_pred = (prob >= thr).astype(int)
        cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
        tss, _ = tss_hss_from_cm(cm)

        if tss > best_tss:
            best_tss = tss
            best_thr = thr

    return float(best_thr), float(best_tss)


def evaluate_probs_clean(model_name, y_val, val_prob, y_test, test_prob):
    threshold, val_tss = tune_threshold_by_tss(y_val, val_prob)

    y_pred = (test_prob >= threshold).astype(int)
    cm = confusion_matrix(y_test, y_pred, labels=[0, 1])
    tss, hss = tss_hss_from_cm(cm)
    tn, fp, fn, tp = cm.ravel()

    return {
        "Model": model_name,
        "Threshold": float(threshold),
        "Val_TSS": float(val_tss),
        "Test_TSS": float(tss),
        "HSS": float(hss),
        "ROC_AUC": float(roc_auc_score(y_test, test_prob)),
        "PR_AUC": float(average_precision_score(y_test, test_prob)),
        "Recall": float(recall_score(y_test, y_pred, zero_division=0)),
        "Precision": float(precision_score(y_test, y_pred, zero_division=0)),
        "F1": float(f1_score(y_test, y_pred, zero_division=0)),
        "TN": int(tn),
        "FP": int(fp),
        "FN": int(fn),
        "TP": int(tp)
    }, y_pred


def get_class_weights(y):
    classes = np.unique(y)
    weights = compute_class_weight(class_weight="balanced", classes=classes, y=y)
    return {int(c): float(w) for c, w in zip(classes, weights)}


class_weight_dict = get_class_weights(y_train_seq)
print("Class weights:", class_weight_dict)
# Out:
# Class weights: {0: 0.5593856655290103, 1: 4.709770114942529}

# %%
# ============================================================
# 8. Model builders
# ============================================================

def make_callbacks(patience=5):
    return [
        EarlyStopping(
            monitor="val_auc",
            mode="max",
            patience=patience,
            restore_best_weights=True,
            verbose=1
        ),
        ReduceLROnPlateau(
            monitor="val_auc",
            mode="max",
            factor=0.5,
            patience=max(2, patience // 2),
            min_lr=1e-5,
            verbose=1
        )
    ]


def build_lstm_model(input_shape):
    model = models.Sequential([
        layers.Input(shape=input_shape),
        layers.LSTM(128, return_sequences=True, dropout=0.2, recurrent_dropout=0.0),
        layers.Dropout(0.3),
        layers.LSTM(64, return_sequences=False, dropout=0.2, recurrent_dropout=0.0),
        layers.Dropout(0.3),
        layers.Dense(32, activation="relu", kernel_regularizer=regularizers.l2(1e-4)),
        layers.Dropout(0.2),
        layers.Dense(1, activation="sigmoid")
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
        loss="binary_crossentropy",
        metrics=[tf.keras.metrics.AUC(name="auc")]
    )

    return model


def build_bilstm_model(input_shape):
    model = models.Sequential([
        layers.Input(shape=input_shape),
        layers.Bidirectional(layers.LSTM(128, return_sequences=True, dropout=0.2, recurrent_dropout=0.0)),
        layers.Dropout(0.3),
        layers.Bidirectional(layers.LSTM(64, return_sequences=False, dropout=0.2, recurrent_dropout=0.0)),
        layers.Dropout(0.3),
        layers.Dense(32, activation="relu", kernel_regularizer=regularizers.l2(1e-4)),
        layers.Dropout(0.2),
        layers.Dense(1, activation="sigmoid")
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
        loss="binary_crossentropy",
        metrics=[tf.keras.metrics.AUC(name="auc")]
    )

    return model


def transformer_encoder_block(x, num_heads=4, key_dim=32, ff_dim=128, dropout=0.20):
    attn = layers.MultiHeadAttention(
        num_heads=num_heads,
        key_dim=key_dim,
        dropout=dropout
    )(x, x)

    x = layers.Add()([x, attn])
    x = layers.LayerNormalization(epsilon=1e-6)(x)

    ff = layers.Dense(ff_dim, activation="relu")(x)
    ff = layers.Dropout(dropout)(ff)
    ff = layers.Dense(x.shape[-1])(ff)

    x = layers.Add()([x, ff])
    x = layers.LayerNormalization(epsilon=1e-6)(x)

    return x


def build_transformer_model(input_shape, num_blocks=2, num_heads=4, key_dim=32, ff_dim=128, dropout=0.20, dense_units=64):
    inp = layers.Input(shape=input_shape, name="sequence_input")

    x = layers.Dense(64, activation="relu", name="feature_projection")(inp)

    for _ in range(num_blocks):
        x = transformer_encoder_block(
            x,
            num_heads=num_heads,
            key_dim=key_dim,
            ff_dim=ff_dim,
            dropout=dropout
        )

    x = layers.GlobalAveragePooling1D(name="temporal_pooling")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Dense(dense_units, activation="relu")(x)
    x = layers.Dropout(dropout)(x)

    out = layers.Dense(1, activation="sigmoid", name="flare_probability")(x)

    model = models.Model(inp, out, name="Transformer_24h")

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
        loss="binary_crossentropy",
        metrics=[tf.keras.metrics.AUC(name="auc")]
    )

    return model


def moving_average_decomposition(X, window=3):
    trend = np.zeros_like(X)
    kernel = np.ones(window, dtype=np.float32) / float(window)

    for feature_idx in range(X.shape[2]):
        for sample_idx in range(X.shape[0]):
            trend[sample_idx, :, feature_idx] = np.convolve(
                X[sample_idx, :, feature_idx],
                kernel,
                mode="same"
            )

    residual = X - trend
    return trend, residual


def build_dlstm_model(input_shape):
    model = models.Sequential([
        layers.Input(shape=input_shape),
        layers.LSTM(128, return_sequences=True, dropout=0.2, recurrent_dropout=0.0),
        layers.Dropout(0.3),
        layers.LSTM(64, return_sequences=False, dropout=0.2, recurrent_dropout=0.0),
        layers.Dropout(0.3),
        layers.Dense(32, activation="relu"),
        layers.Dropout(0.2),
        layers.Dense(1, activation="sigmoid")
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
        loss="binary_crossentropy",
        metrics=[tf.keras.metrics.AUC(name="auc")]
    )

    return model

# %%
# ============================================================
# 9. Train LSTM
# ============================================================

input_shape = (X_train_scaled.shape[1], X_train_scaled.shape[2])

lstm_model = build_lstm_model(input_shape)
lstm_model.summary()

history_lstm = lstm_model.fit(
    X_train_scaled,
    y_train_seq,
    validation_data=(X_val_scaled, y_val_seq),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=make_callbacks(5),
    shuffle=False,
    verbose=1
)

val_prob_lstm = lstm_model.predict(X_val_scaled, verbose=0).ravel()
test_prob_lstm = lstm_model.predict(X_test_scaled, verbose=0).ravel()

results_lstm, y_pred_lstm = evaluate_probs_clean(
    "LSTM",
    y_val_seq,
    val_prob_lstm,
    y_test_seq,
    test_prob_lstm
)

display(pd.DataFrame([results_lstm]))
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 4, 128)         │        76,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 4, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 128,321 (501.25 KB)
#  Trainable params: 128,321 (501.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 110ms/step - auc: 0.7274 - loss: 0.6561 - val_auc: 0.7440 - val_loss: 0.7126 - learning_rate: 0.0010
# Epoch 2/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - auc: 0.7713 - loss: 0.5892 - val_auc: 0.7451 - val_loss: 0.7401 - learning_rate: 0.0010
# Epoch 3/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - auc: 0.7955 - loss: 0.5470 - val_auc: 0.7494 - val_loss: 0.7111 - learning_rate: 0.0010
# Epoch 4/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - auc: 0.8042 - loss: 0.5325 - val_auc: 0.7595 - val_loss: 0.6891 - learning_rate: 0.0010
# Epoch 5/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - auc: 0.8214 - loss: 0.5143 - val_auc: 0.7773 - val_loss: 0.6937 - learning_rate: 0.0010
# Epoch 6/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - auc: 0.8293 - loss: 0.5016 - val_auc: 0.7939 - val_loss: 0.6798 - learning_rate: 0.0010
# Epoch 7/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - auc: 0.8421 - loss: 0.4910 - val_auc: 0.8096 - val_loss: 0.6755 - learning_rate: 0.0010
# Epoch 8/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - auc: 0.8573 - loss: 0.4708 - val_auc: 0.8162 - val_loss: 0.6672 - learning_rate: 0.0010
# Epoch 9/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - auc: 0.8486 - loss: 0.4805 - val_auc: 0.8206 - val_loss: 0.6501 - learning_rate: 0.0010
# Epoch 10/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - auc: 0.8702 - loss: 0.4497 - val_auc: 0.8277 - val_loss: 0.6619 - learning_rate: 0.0010
# Epoch 11/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - auc: 0.8745 - loss: 0.4437 - val_auc: 0.8268 - val_loss: 0.6293 - learning_rate: 0.0010
# Epoch 12/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - auc: 0.8776 - loss: 0.4429 - val_auc: 0.8323 - val_loss: 0.6526 - learning_rate: 0.0010
# Epoch 13/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - auc: 0.8793 - loss: 0.4375 - val_auc: 0.8345 - val_loss: 0.6381 - learning_rate: 0.0010
# Epoch 14/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - auc: 0.8740 - loss: 0.4438 - val_auc: 0.8365 - val_loss: 0.6258 - learning_rate: 0.0010
# Epoch 15/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - auc: 0.8817 - loss: 0.4253 - val_auc: 0.8382 - val_loss: 0.6325 - learning_rate: 0.0010
# Epoch 16/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - auc: 0.8849 - loss: 0.4280 - val_auc: 0.8323 - val_loss: 0.6324 - learning_rate: 0.0010
# Epoch 17/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.9026 - loss: 0.4035
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - auc: 0.8924 - loss: 0.4124 - val_auc: 0.8352 - val_loss: 0.6187 - learning_rate: 0.0010
# Epoch 18/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - auc: 0.8874 - loss: 0.4148 - val_auc: 0.8355 - val_loss: 0.6149 - learning_rate: 5.0000e-04
# Epoch 19/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - auc: 0.9073 - loss: 0.3962
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - auc: 0.9013 - loss: 0.3982 - val_auc: 0.8356 - val_loss: 0.6154 - learning_rate: 5.0000e-04
# Epoch 20/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - auc: 0.8830 - loss: 0.4300 - val_auc: 0.8346 - val_loss: 0.6156 - learning_rate: 2.5000e-04
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 15.
#   Model  Threshold   Val_TSS  Test_TSS       HSS   ROC_AUC   PR_AUC    Recall  \
# 0  LSTM       0.59  0.560516  0.427046  0.362216  0.801106  0.66806  0.794393
#
#    Precision        F1   TN  FP  FN  TP
# 0   0.485714  0.602837  155  90  22  85

# %%
# ============================================================
# 10. Train BiLSTM
# ============================================================

bilstm_model = build_bilstm_model(input_shape)
bilstm_model.summary()

history_bilstm = bilstm_model.fit(
    X_train_scaled,
    y_train_seq,
    validation_data=(X_val_scaled, y_val_seq),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=make_callbacks(5),
    shuffle=False,
    verbose=1
)

val_prob_bilstm = bilstm_model.predict(X_val_scaled, verbose=0).ravel()
test_prob_bilstm = bilstm_model.predict(X_test_scaled, verbose=0).ravel()

results_bilstm, y_pred_bilstm = evaluate_probs_clean(
    "BiLSTM",
    y_val_seq,
    val_prob_bilstm,
    y_test_seq,
    test_prob_bilstm
)

display(pd.DataFrame([results_bilstm]))
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 4, 256)         │       153,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 4, 256)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 128)            │       164,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 322,113 (1.23 MB)
#  Trainable params: 322,113 (1.23 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - auc: 0.7399 - loss: 0.6247 - val_auc: 0.7808 - val_loss: 0.7563 - learning_rate: 0.0010
# Epoch 2/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - auc: 0.8238 - loss: 0.5161 - val_auc: 0.7948 - val_loss: 0.6903 - learning_rate: 0.0010
# Epoch 3/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - auc: 0.8425 - loss: 0.4907 - val_auc: 0.8088 - val_loss: 0.6778 - learning_rate: 0.0010
# Epoch 4/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - auc: 0.8484 - loss: 0.4786 - val_auc: 0.8208 - val_loss: 0.6891 - learning_rate: 0.0010
# Epoch 5/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - auc: 0.8655 - loss: 0.4585 - val_auc: 0.8304 - val_loss: 0.6795 - learning_rate: 0.0010
# Epoch 6/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - auc: 0.8664 - loss: 0.4585 - val_auc: 0.8350 - val_loss: 0.6728 - learning_rate: 0.0010
# Epoch 7/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - auc: 0.8829 - loss: 0.4260 - val_auc: 0.8392 - val_loss: 0.6479 - learning_rate: 0.0010
# Epoch 8/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - auc: 0.8653 - loss: 0.4580 - val_auc: 0.8427 - val_loss: 0.6444 - learning_rate: 0.0010
# Epoch 9/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - auc: 0.8790 - loss: 0.4299 - val_auc: 0.8405 - val_loss: 0.6733 - learning_rate: 0.0010
# Epoch 10/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - auc: 0.8798 - loss: 0.4328 - val_auc: 0.8431 - val_loss: 0.6509 - learning_rate: 0.0010
# Epoch 11/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - auc: 0.8982 - loss: 0.4079 - val_auc: 0.8403 - val_loss: 0.6309 - learning_rate: 0.0010
# Epoch 12/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - auc: 0.8931 - loss: 0.4132 - val_auc: 0.8437 - val_loss: 0.6524 - learning_rate: 0.0010
# Epoch 13/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - auc: 0.8945 - loss: 0.4069 - val_auc: 0.8391 - val_loss: 0.6352 - learning_rate: 0.0010
# Epoch 14/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - auc: 0.8980 - loss: 0.4092
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - auc: 0.8914 - loss: 0.4163 - val_auc: 0.8426 - val_loss: 0.6271 - learning_rate: 0.0010
# Epoch 15/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - auc: 0.8898 - loss: 0.4172 - val_auc: 0.8419 - val_loss: 0.6094 - learning_rate: 5.0000e-04
# Epoch 16/30
# 12/13 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - auc: 0.9101 - loss: 0.3816
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - auc: 0.9000 - loss: 0.3939 - val_auc: 0.8426 - val_loss: 0.6214 - learning_rate: 5.0000e-04
# Epoch 17/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - auc: 0.9038 - loss: 0.3875 - val_auc: 0.8419 - val_loss: 0.6222 - learning_rate: 2.5000e-04
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 12.
#     Model  Threshold   Val_TSS  Test_TSS       HSS  ROC_AUC    PR_AUC  \
# 0  BiLSTM      0.565  0.568948   0.43704  0.359458  0.80637  0.687897
#
#      Recall  Precision        F1   TN  FP  FN  TP
# 0  0.841121    0.47619  0.608108  146  99  17  90

# %%
# ============================================================
# 11. Train Transformer
# ============================================================

transformer_model = build_transformer_model(input_shape)
transformer_model.summary()

history_transformer = transformer_model.fit(
    X_train_scaled,
    y_train_seq,
    validation_data=(X_val_scaled, y_val_seq),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=make_callbacks(6),
    shuffle=False,
    verbose=1
)

val_prob_transformer = transformer_model.predict(X_val_scaled, verbose=0).ravel()
test_prob_transformer = transformer_model.predict(X_test_scaled, verbose=0).ravel()

results_transformer, y_pred_transformer = evaluate_probs_clean(
    "Transformer",
    y_val_seq,
    val_prob_transformer,
    y_test_seq,
    test_prob_transformer
)

display(pd.DataFrame([results_transformer]))
# Out:
# Model: "Transformer_24h"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ sequence_input      │ (None, 4, 21)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ feature_projection  │ (None, 4, 64)     │      1,408 │ sequence_input[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 64)     │     33,216 │ feature_projecti… │
# │ (MultiHeadAttentio… │                   │            │ feature_projecti… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 4, 64)     │          0 │ feature_projecti… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 4, 64)     │        128 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 4, 128)    │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 4, 128)    │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 4, 64)     │      8,256 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 4, 64)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64)     │        128 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 4, 64)     │     33,216 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 4, 64)     │          0 │ layer_normalizat… │
# │                     │                   │            │ multi_head_atten… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64)     │        128 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 4, 128)    │      8,320 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 4, 128)    │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 4, 64)     │      8,256 │ dropout_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 4, 64)     │          0 │ layer_normalizat… │
# │                     │                   │            │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 4, 64)     │        128 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ temporal_pooling    │ (None, 64)        │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 64)        │          0 │ temporal_pooling… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 64)        │      4,160 │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 64)        │          0 │ dense_8[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flare_probability   │ (None, 1)         │         65 │ dropout_11[0][0]  │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 105,729 (413.00 KB)
#  Trainable params: 105,729 (413.00 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 191ms/step - auc: 0.7040 - loss: 0.6463 - val_auc: 0.7553 - val_loss: 0.7754 - learning_rate: 0.0010
# Epoch 2/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - auc: 0.7886 - loss: 0.5447 - val_auc: 0.7558 - val_loss: 0.8928 - learning_rate: 0.0010
# Epoch 3/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - auc: 0.8097 - loss: 0.5182 - val_auc: 0.7625 - val_loss: 0.7832 - learning_rate: 0.0010
# Epoch 4/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - auc: 0.8333 - loss: 0.4902 - val_auc: 0.7840 - val_loss: 0.7363 - learning_rate: 0.0010
# Epoch 5/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - auc: 0.8402 - loss: 0.4841 - val_auc: 0.7764 - val_loss: 0.7305 - learning_rate: 0.0010
# Epoch 6/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - auc: 0.8490 - loss: 0.4664 - val_auc: 0.7892 - val_loss: 0.7473 - learning_rate: 0.0010
# Epoch 7/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - auc: 0.8529 - loss: 0.4644 - val_auc: 0.8007 - val_loss: 0.7176 - learning_rate: 0.0010
# Epoch 8/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 153ms/step - auc: 0.8710 - loss: 0.4435 - val_auc: 0.7887 - val_loss: 0.7260 - learning_rate: 0.0010
# Epoch 9/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - auc: 0.8778 - loss: 0.4211 - val_auc: 0.7808 - val_loss: 0.7053 - learning_rate: 0.0010
# Epoch 10/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - auc: 0.8894 - loss: 0.4093
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - auc: 0.8826 - loss: 0.4146 - val_auc: 0.7924 - val_loss: 0.6793 - learning_rate: 0.0010
# Epoch 11/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - auc: 0.8895 - loss: 0.4022 - val_auc: 0.7920 - val_loss: 0.6473 - learning_rate: 5.0000e-04
# Epoch 12/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 238ms/step - auc: 0.8942 - loss: 0.3903 - val_auc: 0.7777 - val_loss: 0.6579 - learning_rate: 5.0000e-04
# Epoch 13/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - auc: 0.9086 - loss: 0.3670
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 202ms/step - auc: 0.9061 - loss: 0.3720 - val_auc: 0.7871 - val_loss: 0.6421 - learning_rate: 5.0000e-04
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 7.
#          Model  Threshold   Val_TSS  Test_TSS       HSS   ROC_AUC    PR_AUC  \
# 0  Transformer      0.669  0.487599  0.357658  0.292269  0.759184  0.596968
#
#      Recall  Precision        F1   TN   FP  FN  TP
# 0  0.794393   0.442708  0.568562  138  107  22  85

# %%
# ============================================================
# 12. DLSTM decomposition and training
# ============================================================

trend_train, res_train = moving_average_decomposition(X_train_scaled, window=MA_WINDOW)
trend_val, res_val = moving_average_decomposition(X_val_scaled, window=MA_WINDOW)
trend_test, res_test = moving_average_decomposition(X_test_scaled, window=MA_WINDOW)

X_train_dlstm = np.concatenate([trend_train, res_train], axis=2)
X_val_dlstm = np.concatenate([trend_val, res_val], axis=2)
X_test_dlstm = np.concatenate([trend_test, res_test], axis=2)

print("DLSTM input shape:", X_train_dlstm.shape)

dlstm_model = build_dlstm_model((X_train_dlstm.shape[1], X_train_dlstm.shape[2]))
dlstm_model.summary()

history_dlstm = dlstm_model.fit(
    X_train_dlstm,
    y_train_seq,
    validation_data=(X_val_dlstm, y_val_seq),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=make_callbacks(5),
    shuffle=False,
    verbose=1
)

val_prob_dlstm = dlstm_model.predict(X_val_dlstm, verbose=0).ravel()
test_prob_dlstm = dlstm_model.predict(X_test_dlstm, verbose=0).ravel()

results_dlstm, y_pred_dlstm = evaluate_probs_clean(
    "DLSTM",
    y_val_seq,
    val_prob_dlstm,
    y_test_seq,
    test_prob_dlstm
)

display(pd.DataFrame([results_dlstm]))
# Out:
# DLSTM input shape: (1639, 4, 42)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                   │ (None, 4, 128)         │        87,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 4, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 139,073 (543.25 KB)
#  Trainable params: 139,073 (543.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - auc: 0.6887 - loss: 0.6639 - val_auc: 0.7588 - val_loss: 0.6775 - learning_rate: 0.0010
# Epoch 2/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - auc: 0.7716 - loss: 0.5867 - val_auc: 0.7535 - val_loss: 0.7127 - learning_rate: 0.0010
# Epoch 3/30
# 12/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - auc: 0.7973 - loss: 0.5455
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - auc: 0.7943 - loss: 0.5417 - val_auc: 0.7561 - val_loss: 0.7051 - learning_rate: 0.0010
# Epoch 4/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - auc: 0.7991 - loss: 0.5389 - val_auc: 0.7586 - val_loss: 0.6942 - learning_rate: 5.0000e-04
# Epoch 5/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - auc: 0.8083 - loss: 0.5241 - val_auc: 0.7621 - val_loss: 0.6959 - learning_rate: 5.0000e-04
# Epoch 6/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - auc: 0.8145 - loss: 0.5155 - val_auc: 0.7657 - val_loss: 0.6971 - learning_rate: 5.0000e-04
# Epoch 7/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - auc: 0.8160 - loss: 0.5136 - val_auc: 0.7718 - val_loss: 0.6909 - learning_rate: 5.0000e-04
# Epoch 8/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - auc: 0.8237 - loss: 0.5007 - val_auc: 0.7778 - val_loss: 0.6764 - learning_rate: 5.0000e-04
# Epoch 9/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - auc: 0.8284 - loss: 0.5016 - val_auc: 0.7841 - val_loss: 0.6686 - learning_rate: 5.0000e-04
# Epoch 10/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - auc: 0.8365 - loss: 0.4847 - val_auc: 0.7879 - val_loss: 0.6700 - learning_rate: 5.0000e-04
# Epoch 11/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - auc: 0.8424 - loss: 0.4816 - val_auc: 0.7981 - val_loss: 0.6711 - learning_rate: 5.0000e-04
# Epoch 12/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - auc: 0.8430 - loss: 0.4742 - val_auc: 0.8065 - val_loss: 0.6663 - learning_rate: 5.0000e-04
# Epoch 13/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - auc: 0.8520 - loss: 0.4691 - val_auc: 0.8143 - val_loss: 0.6491 - learning_rate: 5.0000e-04
# Epoch 14/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - auc: 0.8623 - loss: 0.4569 - val_auc: 0.8171 - val_loss: 0.6524 - learning_rate: 5.0000e-04
# Epoch 15/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - auc: 0.8626 - loss: 0.4581 - val_auc: 0.8201 - val_loss: 0.6502 - learning_rate: 5.0000e-04
# Epoch 16/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - auc: 0.8716 - loss: 0.4446 - val_auc: 0.8240 - val_loss: 0.6380 - learning_rate: 5.0000e-04
# Epoch 17/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - auc: 0.8633 - loss: 0.4623 - val_auc: 0.8244 - val_loss: 0.6379 - learning_rate: 5.0000e-04
# Epoch 18/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - auc: 0.8759 - loss: 0.4408 - val_auc: 0.8262 - val_loss: 0.6472 - learning_rate: 5.0000e-04
# Epoch 19/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - auc: 0.8718 - loss: 0.4412 - val_auc: 0.8231 - val_loss: 0.6430 - learning_rate: 5.0000e-04
# Epoch 20/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - auc: 0.8898 - loss: 0.4200
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - auc: 0.8796 - loss: 0.4310 - val_auc: 0.8223 - val_loss: 0.6226 - learning_rate: 5.0000e-04
# Epoch 21/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - auc: 0.8805 - loss: 0.4366 - val_auc: 0.8206 - val_loss: 0.6234 - learning_rate: 2.5000e-04
# Epoch 22/30
# 12/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - auc: 0.9003 - loss: 0.4104
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - auc: 0.8841 - loss: 0.4260 - val_auc: 0.8216 - val_loss: 0.6284 - learning_rate: 2.5000e-04
# Epoch 23/30
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - auc: 0.8823 - loss: 0.4339 - val_auc: 0.8223 - val_loss: 0.6277 - learning_rate: 1.2500e-04
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 18.
#    Model  Threshold   Val_TSS  Test_TSS       HSS   ROC_AUC    PR_AUC  \
# 0  DLSTM      0.566  0.551091  0.396224  0.318982  0.803166  0.677047
#
#      Recall  Precision        F1   TN   FP  FN  TP
# 0  0.841121   0.452261  0.588235  136  109  17  90

# %%
# ============================================================
# 13. Final clean 24h table: individual + ensembles
# ============================================================

final_rows = [
    results_lstm,
    results_bilstm,
    results_transformer,
    results_dlstm
]

# ------------------------------------------------------------
# Simple average ensemble: LSTM + BiLSTM + DLSTM
# ------------------------------------------------------------

val_prob_simple = (val_prob_lstm + val_prob_bilstm + val_prob_dlstm) / 3.0
test_prob_simple = (test_prob_lstm + test_prob_bilstm + test_prob_dlstm) / 3.0

results_simple, y_pred_simple = evaluate_probs_clean(
    "Simple/Avg Ensemble",
    y_val_seq,
    val_prob_simple,
    y_test_seq,
    test_prob_simple
)

final_rows.append(results_simple)


# ------------------------------------------------------------
# Weighted ensemble search
# Selected by VALIDATION TSS only.
# ------------------------------------------------------------

weight_sets = [
    (0.20, 0.40, 0.40),
    (0.20, 0.30, 0.50),
    (0.15, 0.35, 0.50),
    (0.25, 0.35, 0.40),
    (0.30, 0.30, 0.40),
    (0.10, 0.45, 0.45),
    (0.33, 0.33, 0.34),
    (0.25, 0.25, 0.50),
    (0.40, 0.30, 0.30),
    (1/3, 1/3, 1/3)
]

weighted_rows = []
weighted_preds = {}

for w_lstm, w_bilstm, w_dlstm in weight_sets:
    val_prob_weighted = (
        w_lstm * val_prob_lstm +
        w_bilstm * val_prob_bilstm +
        w_dlstm * val_prob_dlstm
    )

    test_prob_weighted = (
        w_lstm * test_prob_lstm +
        w_bilstm * test_prob_bilstm +
        w_dlstm * test_prob_dlstm
    )

    model_name = f"Weighted Ensemble ({w_lstm:.2f},{w_bilstm:.2f},{w_dlstm:.2f})"

    result, y_pred_weighted = evaluate_probs_clean(
        model_name,
        y_val_seq,
        val_prob_weighted,
        y_test_seq,
        test_prob_weighted
    )

    weighted_rows.append(result)
    weighted_preds[model_name] = y_pred_weighted

weighted_df = pd.DataFrame(weighted_rows).sort_values(
    ["Val_TSS", "Test_TSS"],
    ascending=[False, False]
).reset_index(drop=True)

best_weighted_result = weighted_df.iloc[0].to_dict()
best_weighted_name = best_weighted_result["Model"]
y_pred_best_weighted = weighted_preds[best_weighted_name]

final_rows.append(best_weighted_result)


# ------------------------------------------------------------
# Stacking ensemble: logistic regression on validation predictions
# ------------------------------------------------------------

X_meta_val = np.column_stack([
    val_prob_lstm,
    val_prob_bilstm,
    val_prob_dlstm
])

X_meta_test = np.column_stack([
    test_prob_lstm,
    test_prob_bilstm,
    test_prob_dlstm
])

stack_model = LogisticRegression(
    class_weight="balanced",
    max_iter=3000,
    random_state=SEED
)

stack_model.fit(X_meta_val, y_val_seq)

val_prob_stack = stack_model.predict_proba(X_meta_val)[:, 1]
test_prob_stack = stack_model.predict_proba(X_meta_test)[:, 1]

results_stack, y_pred_stack = evaluate_probs_clean(
    "Stacking Ensemble",
    y_val_seq,
    val_prob_stack,
    y_test_seq,
    test_prob_stack
)

final_rows.append(results_stack)


# ------------------------------------------------------------
# Final table
# ------------------------------------------------------------

final_24h_df = pd.DataFrame(final_rows).sort_values(
    "Test_TSS",
    ascending=False
).reset_index(drop=True)

display(final_24h_df.round(6))

print("\nWeighted ensemble search, selected by validation TSS:")
display(weighted_df.round(6))
# Out:
#                                 Model  Threshold   Val_TSS  Test_TSS  \
# 0                              BiLSTM      0.565  0.568948  0.437040
# 1                                LSTM      0.590  0.560516  0.427046
# 2  Weighted Ensemble (0.20,0.30,0.50)      0.593  0.580357  0.418882
# 3                   Stacking Ensemble      0.473  0.582341  0.417166
# 4                 Simple/Avg Ensemble      0.585  0.569940  0.406637
# 5                               DLSTM      0.566  0.551091  0.396224
# 6                         Transformer      0.669  0.487599  0.357658
#
#         HSS   ROC_AUC    PR_AUC    Recall  Precision        F1   TN   FP  FN  \
# 0  0.359458  0.806370  0.687897  0.841121   0.476190  0.608108  146   99  17
# 1  0.362216  0.801106  0.668060  0.794393   0.485714  0.602837  155   90  22
# 2  0.353712  0.807858  0.685879  0.794393   0.480226  0.598592  153   92  22
# 3  0.346866  0.809384  0.685773  0.813084   0.472826  0.597938  148   97  20
# 4  0.341098  0.807934  0.685540  0.794393   0.472222  0.592334  150   95  22
# 5  0.318982  0.803166  0.677047  0.841121   0.452261  0.588235  136  109  17
# 6  0.292269  0.759184  0.596968  0.794393   0.442708  0.568562  138  107  22
#
#    TP
# 0  90
# 1  85
# 2  85
# 3  87
# 4  85
# 5  90
# 6  85
# Weighted ensemble search, selected by validation TSS:
#                                 Model  Threshold   Val_TSS  Test_TSS  \
# 0  Weighted Ensemble (0.20,0.30,0.50)      0.593  0.580357  0.418882
# 1  Weighted Ensemble (0.15,0.35,0.50)      0.592  0.576885  0.422964
# 2  Weighted Ensemble (0.25,0.25,0.50)      0.588  0.576885  0.410719
# 3  Weighted Ensemble (0.25,0.35,0.40)      0.589  0.573413  0.418882
# 4  Weighted Ensemble (0.10,0.45,0.45)      0.598  0.573413  0.417700
# 5  Weighted Ensemble (0.33,0.33,0.34)      0.587  0.573413  0.410719
# 6  Weighted Ensemble (0.30,0.30,0.40)      0.586  0.573413  0.402556
# 7  Weighted Ensemble (0.20,0.40,0.40)      0.589  0.569940  0.414801
# 8  Weighted Ensemble (0.33,0.33,0.33)      0.585  0.569940  0.406637
# 9  Weighted Ensemble (0.40,0.30,0.30)      0.569  0.568452  0.391493
#
#         HSS   ROC_AUC    PR_AUC    Recall  Precision        F1   TN   FP  FN  \
# 0  0.353712  0.807858  0.685879  0.794393   0.480226  0.598592  153   92  22
# 1  0.357955  0.808049  0.686854  0.794393   0.482955  0.600707  154   91  22
# 2  0.345284  0.807591  0.684537  0.794393   0.474860  0.594406  151   94  22
# 3  0.353712  0.808201  0.686757  0.794393   0.480226  0.598592  153   92  22
# 4  0.355081  0.808697  0.687265  0.785047   0.482759  0.597865  155   90  23
# 5  0.345284  0.807858  0.685569  0.794393   0.474860  0.594406  151   94  22
# 6  0.336930  0.807820  0.685528  0.794393   0.469613  0.590278  149   96  22
# 7  0.349489  0.808774  0.686940  0.794393   0.477528  0.596491  152   93  22
# 8  0.341098  0.807934  0.685540  0.794393   0.472222  0.592334  150   95  22
# 9  0.323397  0.807553  0.684061  0.803738   0.459893  0.585034  144  101  21
#
#    TP
# 0  85
# 1  85
# 2  85
# 3  85
# 4  84
# 5  85
# 6  85
# 7  85
# 8  85
# 9  86

# %%
# ============================================================
# 14. Save clean outputs
# ============================================================

final_24h_df.to_csv(
    os.path.join(OUT_DIR, "FINAL_CLEAN_24H_RESULTS_WITH_TRANSFORMER.csv"),
    index=False
)

weighted_df.to_csv(
    os.path.join(OUT_DIR, "FINAL_24H_WEIGHTED_ENSEMBLE_SEARCH_BY_VAL_TSS.csv"),
    index=False
)

np.save(os.path.join(OUT_DIR, "y_val_24h.npy"), y_val_seq)
np.save(os.path.join(OUT_DIR, "y_test_24h.npy"), y_test_seq)

arrays_to_save = {
    "val_prob_lstm": val_prob_lstm,
    "test_prob_lstm": test_prob_lstm,
    "y_pred_lstm": y_pred_lstm,
    "val_prob_bilstm": val_prob_bilstm,
    "test_prob_bilstm": test_prob_bilstm,
    "y_pred_bilstm": y_pred_bilstm,
    "val_prob_transformer": val_prob_transformer,
    "test_prob_transformer": test_prob_transformer,
    "y_pred_transformer": y_pred_transformer,
    "val_prob_dlstm": val_prob_dlstm,
    "test_prob_dlstm": test_prob_dlstm,
    "y_pred_dlstm": y_pred_dlstm,
    "val_prob_simple": val_prob_simple,
    "test_prob_simple": test_prob_simple,
    "y_pred_simple": y_pred_simple,
    "y_pred_best_weighted": y_pred_best_weighted,
    "val_prob_stack": val_prob_stack,
    "test_prob_stack": test_prob_stack,
    "y_pred_stack": y_pred_stack,
}

for name, arr in arrays_to_save.items():
    np.save(os.path.join(OUT_DIR, f"{name}.npy"), arr)

joblib.dump(stack_model, os.path.join(OUT_DIR, "stacking_model_24h.joblib"))

print("Saved all clean outputs to:")
print(OUT_DIR)
# Out:
# Saved all clean outputs to:
# /content/drive/MyDrive/AR_Stratified/Journal_Revision_24h_CLEAN_TRANSFORMER

# %%
# ============================================================
# 15. Bootstrap confidence interval for best TSS model
# ============================================================

def bootstrap_tss_ci(y_true, y_pred, n_boot=2000, seed=42):
    rng = np.random.default_rng(seed)

    y_true = np.array(y_true).astype(int)
    y_pred = np.array(y_pred).astype(int)

    n = len(y_true)
    scores = []

    for _ in range(n_boot):
        idx = rng.integers(0, n, n)
        yt = y_true[idx]
        yp = y_pred[idx]

        if len(np.unique(yt)) < 2:
            continue

        cm = confusion_matrix(yt, yp, labels=[0, 1])
        tss, _ = tss_hss_from_cm(cm)
        scores.append(tss)

    scores = np.array(scores)

    return {
        "mean": float(scores.mean()),
        "ci_low": float(np.percentile(scores, 2.5)),
        "ci_high": float(np.percentile(scores, 97.5)),
        "n_boot_valid": int(len(scores))
    }, scores


best_model_name = final_24h_df.iloc[0]["Model"]

pred_lookup = {
    "LSTM": y_pred_lstm,
    "BiLSTM": y_pred_bilstm,
    "Transformer": y_pred_transformer,
    "DLSTM": y_pred_dlstm,
    "Simple/Avg Ensemble": y_pred_simple,
    best_weighted_name: y_pred_best_weighted,
    "Stacking Ensemble": y_pred_stack
}

best_pred = pred_lookup[best_model_name]

best_ci, best_boot_scores = bootstrap_tss_ci(
    y_test_seq,
    best_pred,
    n_boot=2000,
    seed=SEED
)

print("Best model:", best_model_name)
print("Bootstrap TSS CI:", best_ci)

pd.DataFrame([{
    "Model": best_model_name,
    "Bootstrap_Mean_TSS": best_ci["mean"],
    "CI_Low": best_ci["ci_low"],
    "CI_High": best_ci["ci_high"],
    "N_Boot_Valid": best_ci["n_boot_valid"]
}]).to_csv(
    os.path.join(OUT_DIR, "BEST_24H_MODEL_BOOTSTRAP_TSS_CI.csv"),
    index=False
)

np.save(
    os.path.join(OUT_DIR, "best_24h_model_bootstrap_tss_scores.npy"),
    best_boot_scores
)
# Out:
# Best model: BiLSTM
# Bootstrap TSS CI: {'mean': 0.43748164338741696, 'ci_low': 0.3446322761801376, 'ci_high': 0.5241362594679626, 'n_boot_valid': 2000}

# %%
# ============================================================
# 16. McNemar comparisons: best model vs baselines
# ============================================================

from math import erf, sqrt

def mcnemar_test(y_true, pred_a, pred_b):
    y_true = np.array(y_true).astype(int)
    pred_a = np.array(pred_a).astype(int)
    pred_b = np.array(pred_b).astype(int)

    a_correct = pred_a == y_true
    b_correct = pred_b == y_true

    b = int(np.sum((a_correct == 1) & (b_correct == 0)))
    c = int(np.sum((a_correct == 0) & (b_correct == 1)))

    n = b + c

    if n == 0:
        chi2 = 0.0
        p_value = 1.0
    else:
        chi2 = ((abs(b - c) - 1) ** 2) / (b + c + 1e-9)
        z = sqrt(chi2)
        p_value = 2 * (1 - 0.5 * (1 + erf(z / sqrt(2))))

    return {
        "b": b,
        "c": c,
        "n": n,
        "chi2": float(chi2),
        "p_value": float(p_value)
    }


mcnemar_rows = []

for comparison_name, baseline_pred in [
    ("Best vs LSTM", y_pred_lstm),
    ("Best vs BiLSTM", y_pred_bilstm),
    ("Best vs Transformer", y_pred_transformer),
    ("Best vs DLSTM", y_pred_dlstm),
    ("Best vs Simple/Avg Ensemble", y_pred_simple),
    ("Best vs Stacking Ensemble", y_pred_stack),
]:
    out = mcnemar_test(y_test_seq, best_pred, baseline_pred)
    out["Comparison"] = comparison_name
    out["Best_Model"] = best_model_name
    mcnemar_rows.append(out)

mcnemar_df = pd.DataFrame(mcnemar_rows)[
    ["Comparison", "Best_Model", "b", "c", "n", "chi2", "p_value"]
]

display(mcnemar_df)

mcnemar_df.to_csv(
    os.path.join(OUT_DIR, "MCNEMAR_24H_BEST_MODEL_COMPARISONS.csv"),
    index=False
)
# Out:
#                     Comparison Best_Model   b   c   n      chi2   p_value
# 0                 Best vs LSTM     BiLSTM  17  21  38  0.236842  0.626496
# 1               Best vs BiLSTM     BiLSTM   0   0   0  0.000000  1.000000
# 2          Best vs Transformer     BiLSTM  44  31  75  1.920000  0.165857
# 3                Best vs DLSTM     BiLSTM  31  21  52  1.557692  0.212003
# 4  Best vs Simple/Avg Ensemble     BiLSTM  12  11  23  0.000000  1.000000
# 5    Best vs Stacking Ensemble     BiLSTM  10   9  19  0.000000  1.000000

# %% [markdown]
# ## Manuscript reminder
#
# For the 24h section, report the clean table from:
#
# `FINAL_CLEAN_24H_RESULTS_WITH_TRANSFORMER.csv`
#
# Use the cadence diagnostics to describe the **actual input span**, and state clearly that:
#
# - thresholds were tuned on validation only;
# - weighted ensemble weights were selected using validation TSS only;
# - the test set was reserved for final reporting.

# %% [markdown]
# ---

# %%
X_train_scaled, X_val_scaled, X_test_scaled
y_train_seq, y_val_seq, y_test_seq
OUT_DIR
# Out:
# '/content/drive/MyDrive/AR_Stratified/Journal_Revision_24h_CLEAN_TRANSFORMER'

# %%
import os, random, gc, itertools
import numpy as np
import pandas as pd
import tensorflow as tf

from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (
    confusion_matrix,
    roc_auc_score,
    average_precision_score,
    precision_score,
    recall_score,
    f1_score
)

# -----------------------------
# Reproducibility
# -----------------------------
SEED = 42
os.environ["PYTHONHASHSEED"] = str(SEED)

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

TUNE_OUT_DIR = os.path.join(OUT_DIR, "24h_all_models_hyperparameter_tuning")
os.makedirs(TUNE_OUT_DIR, exist_ok=True)

print("Saving tuning outputs to:", TUNE_OUT_DIR)
print("TensorFlow:", tf.__version__)


# ============================================================
# Metric helpers
# ============================================================

def tss_hss_from_cm(cm):
    tn, fp, fn, tp = cm.ravel()

    recall = tp / (tp + fn + 1e-9)
    fpr = fp / (fp + tn + 1e-9)
    tss = recall - fpr

    numerator = 2 * (tp * tn - fp * fn)
    denominator = ((tp + fn) * (fn + tn) + (tp + fp) * (fp + tn) + 1e-9)
    hss = numerator / denominator

    return float(tss), float(hss)


def tune_threshold_by_tss(y_true, prob):
    thresholds = np.linspace(0, 1, 1001)

    best_thr = 0.5
    best_tss = -999

    for thr in thresholds:
        y_pred = (prob >= thr).astype(int)
        cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
        tss, _ = tss_hss_from_cm(cm)

        if tss > best_tss:
            best_tss = tss
            best_thr = thr

    return float(best_thr), float(best_tss)


def evaluate_probs(model_name, y_val, val_prob, y_test, test_prob, extra=None):
    threshold, val_tss = tune_threshold_by_tss(y_val, val_prob)

    y_pred = (test_prob >= threshold).astype(int)

    cm = confusion_matrix(y_test, y_pred, labels=[0, 1])
    tss, hss = tss_hss_from_cm(cm)
    tn, fp, fn, tp = cm.ravel()

    result = {
        "Model": model_name,
        "Threshold": threshold,
        "Val_TSS": val_tss,
        "Test_TSS": tss,
        "HSS": hss,
        "ROC_AUC": roc_auc_score(y_test, test_prob),
        "PR_AUC": average_precision_score(y_test, test_prob),
        "Recall": recall_score(y_test, y_pred, zero_division=0),
        "Precision": precision_score(y_test, y_pred, zero_division=0),
        "F1": f1_score(y_test, y_pred, zero_division=0),
        "TN": int(tn),
        "FP": int(fp),
        "FN": int(fn),
        "TP": int(tp)
    }

    if extra is not None:
        result.update(extra)

    return result, y_pred


def get_class_weights(y):
    classes = np.unique(y)
    weights = compute_class_weight(
        class_weight="balanced",
        classes=classes,
        y=y
    )

    return {int(c): float(w) for c, w in zip(classes, weights)}


def make_callbacks(patience=5):
    return [
        EarlyStopping(
            monitor="val_auc",
            mode="max",
            patience=patience,
            restore_best_weights=True,
            verbose=0
        ),
        ReduceLROnPlateau(
            monitor="val_auc",
            mode="max",
            factor=0.5,
            patience=max(2, patience // 2),
            min_lr=1e-5,
            verbose=0
        )
    ]


# ============================================================
# Decomposition helper for DLSTM
# ============================================================

def moving_average_decomposition(X, window=3):
    trend = np.zeros_like(X)
    kernel = np.ones(window, dtype=np.float32) / float(window)

    for feature_idx in range(X.shape[2]):
        for sample_idx in range(X.shape[0]):
            # Ensure the convoluted output matches the expected sequence length
            convolved_output = np.convolve(
                X[sample_idx, :, feature_idx],
                kernel,
                mode="same"
            )
            trend[sample_idx, :, feature_idx] = convolved_output[:X.shape[1]]

    residual = X - trend

    return trend, residual


# ============================================================
# Model builders
# ============================================================

def build_lstm_tuned(input_shape, lstm_units=64, dense_units=32, dropout=0.3, lr=1e-3):
    model = models.Sequential([
        layers.Input(shape=input_shape),

        layers.LSTM(
            lstm_units,
            return_sequences=False,
            dropout=dropout,
            recurrent_dropout=0.0
        ),

        layers.Dense(
            dense_units,
            activation="relu",
            kernel_regularizer=regularizers.l2(1e-4)
        ),

        layers.Dropout(dropout),

        layers.Dense(1, activation="sigmoid")
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss="binary_crossentropy",
        metrics=[tf.keras.metrics.AUC(name="auc")]
    )

    return model


def build_bilstm_tuned(input_shape, lstm_units=64, dense_units=32, dropout=0.3, lr=1e-3):
    model = models.Sequential([
        layers.Input(shape=input_shape),

        layers.Bidirectional(
            layers.LSTM(
                lstm_units,
                return_sequences=False,
                dropout=dropout,
                recurrent_dropout=0.0
            )
        ),

        layers.Dense(
            dense_units,
            activation="relu",
            kernel_regularizer=regularizers.l2(1e-4)
        ),

        layers.Dropout(dropout),

        layers.Dense(1, activation="sigmoid")
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss="binary_crossentropy",
        metrics=[tf.keras.metrics.AUC(name="auc")]
    )

    return model


def build_dlstm_tuned(input_shape, lstm_units=64, dropout=0.3, lr=1e-3):
    second_units = max(16, lstm_units // 2)

    model = models.Sequential([
        layers.Input(shape=input_shape),

        layers.LSTM(
            lstm_units,
            return_sequences=True,
            dropout=dropout,
            recurrent_dropout=0.0
        ),

        layers.Dropout(dropout),

        layers.LSTM(
            second_units,
            return_sequences=False,
            dropout=dropout,
            recurrent_dropout=0.0
        ),

        layers.Dropout(dropout),

        layers.Dense(1, activation="sigmoid")
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss="binary_crossentropy",
        metrics=[tf.keras.metrics.AUC(name="auc")]
    )

    return model


def transformer_encoder_block(x, num_heads=4, key_dim=32, ff_dim=128, dropout=0.2):
    attn = layers.MultiHeadAttention(
        num_heads=num_heads,
        key_dim=key_dim,
        dropout=dropout
    )(x, x)

    x = layers.Add()([x, attn])
    x = layers.LayerNormalization(epsilon=1e-6)(x)

    ff = layers.Dense(ff_dim, activation="relu")(x)
    ff = layers.Dropout(dropout)(ff)
    ff = layers.Dense(x.shape[-1])(ff)

    x = layers.Add()([x, ff])
    x = layers.LayerNormalization(epsilon=1e-6)(x)

    return x


def build_transformer_tuned(
    input_shape,
    num_blocks=1,
    num_heads=2,
    key_dim=16,
    ff_dim=64,
    dense_units=32,
    dropout=0.2,
    lr=1e-3
):
    inp = layers.Input(shape=input_shape)

    x = layers.Dense(64, activation="relu")(inp)

    for _ in range(num_blocks):
        x = transformer_encoder_block(
            x,
            num_heads=num_heads,
            key_dim=key_dim,
            ff_dim=ff_dim,
            dropout=dropout
        )

    x = layers.GlobalAveragePooling1D()(x)
    x = layers.Dropout(dropout)(x)

    x = layers.Dense(
        dense_units,
        activation="relu",
        kernel_regularizer=regularizers.l2(1e-4)
    )(x)

    x = layers.Dropout(dropout)(x)

    out = layers.Dense(1, activation="sigmoid")(x)

    model = models.Model(inp, out, name="Transformer_24h_Tuned")

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss="binary_crossentropy",
        metrics=[tf.keras.metrics.AUC(name="auc")]
    )

    return model


# ============================================================
# Tuning grids
# Keep this moderate. Transformer tuning is expensive.
# ============================================================

input_shape = (X_train_scaled.shape[1], X_train_scaled.shape[2])
class_weight_tune = get_class_weights(y_train_seq)

print("Input shape:", input_shape)
print("Class weights:", class_weight_tune)

EPOCHS_TUNE = 25

LSTM_UNITS_GRID = [64, 128]
DENSE_UNITS_GRID = [32, 64]
DROPOUT_GRID = [0.2, 0.3]
LR_GRID = [1e-3, 5e-4]
BATCH_SIZE_GRID = [64, 128]

MA_WINDOW_GRID = [3, 5]

TRANSFORMER_BLOCKS_GRID = [1, 2]
TRANSFORMER_HEADS_GRID = [2, 4]
TRANSFORMER_KEY_DIM_GRID = [16, 32]
TRANSFORMER_FF_DIM_GRID = [64, 128]


# ============================================================
# Main tuning loop
# ============================================================

tuning_rows = []
prob_store = {}

run_id = 0


def run_and_record(model, model_name, family, batch_size, extra):
    global run_id

    history = model.fit(
        X_train_input,
        y_train_seq,
        validation_data=(X_val_input, y_val_seq),
        epochs=EPOCHS_TUNE,
        batch_size=batch_size,
        class_weight=class_weight_tune,
        callbacks=make_callbacks(patience=5),
        shuffle=False,
        verbose=0
    )

    val_prob = model.predict(X_val_input, verbose=0).ravel()
    test_prob = model.predict(X_test_input, verbose=0).ravel()

    result, y_pred = evaluate_probs(
        model_name,
        y_val_seq,
        val_prob,
        y_test_seq,
        test_prob,
        extra={
            "Family": family,
            "Batch_Size": batch_size,
            "Epochs_Used": len(history.history["loss"]),
            **extra
        }
    )

    tuning_rows.append(result)

    prob_store[model_name] = {
        "val_prob": val_prob,
        "test_prob": test_prob,
        "y_pred": y_pred,
        "result": result
    }

    print(
        f"Val_TSS={result['Val_TSS']:.4f} | "
        f"Test_TSS={result['Test_TSS']:.4f} | "
        f"PR_AUC={result['PR_AUC']:.4f} | "
        f"Precision={result['Precision']:.4f} | "
        f"F1={result['F1']:.4f}"
    )


# -----------------------------
# LSTM tuning
# -----------------------------
for lstm_units, dense_units, dropout, lr, batch_size in itertools.product(
    LSTM_UNITS_GRID,
    DENSE_UNITS_GRID,
    DROPOUT_GRID,
    LR_GRID,
    BATCH_SIZE_GRID
):
    run_id += 1

    tf.keras.backend.clear_session()
    random.seed(SEED)
    np.random.seed(SEED)
    tf.random.set_seed(SEED)

    model_name = f"LSTM_24h_U{lstm_units}_Dense{dense_units}_D{dropout}_LR{lr}_BS{batch_size}"

    print("\n======================================")
    print(f"Run {run_id}: {model_name}")
    print("======================================")

    X_train_input = X_train_scaled
    X_val_input = X_val_scaled
    X_test_input = X_test_scaled

    model = build_lstm_tuned(
        input_shape=input_shape,
        lstm_units=lstm_units,
        dense_units=dense_units,
        dropout=dropout,
        lr=lr
    )

    run_and_record(
        model,
        model_name,
        "LSTM",
        batch_size,
        {
            "LSTM_Units": lstm_units,
            "Dense_Units": dense_units,
            "Dropout": dropout,
            "Learning_Rate": lr,
            "MA_Window": np.nan,
            "Transformer_Blocks": np.nan,
            "Transformer_Heads": np.nan,
            "Transformer_Key_Dim": np.nan,
            "Transformer_FF_Dim": np.nan
        }
    )

    del model
    gc.collect()


# -----------------------------
# BiLSTM tuning
# -----------------------------
for lstm_units, dense_units, dropout, lr, batch_size in itertools.product(
    LSTM_UNITS_GRID,
    DENSE_UNITS_GRID,
    DROPOUT_GRID,
    LR_GRID,
    BATCH_SIZE_GRID
):
    run_id += 1

    tf.keras.backend.clear_session()
    random.seed(SEED)
    np.random.seed(SEED)
    tf.random.set_seed(SEED)

    model_name = f"BiLSTM_24h_U{lstm_units}_Dense{dense_units}_D{dropout}_LR{lr}_BS{batch_size}"

    print("\n======================================")
    print(f"Run {run_id}: {model_name}")
    print("======================================")

    X_train_input = X_train_scaled
    X_val_input = X_val_scaled
    X_test_input = X_test_scaled

    model = build_bilstm_tuned(
        input_shape=input_shape,
        lstm_units=lstm_units,
        dense_units=dense_units,
        dropout=dropout,
        lr=lr
    )

    run_and_record(
        model,
        model_name,
        "BiLSTM",
        batch_size,
        {
            "LSTM_Units": lstm_units,
            "Dense_Units": dense_units,
            "Dropout": dropout,
            "Learning_Rate": lr,
            "MA_Window": np.nan,
            "Transformer_Blocks": np.nan,
            "Transformer_Heads": np.nan,
            "Transformer_Key_Dim": np.nan,
            "Transformer_FF_Dim": np.nan
        }
    )

    del model
    gc.collect()


# -----------------------------
# DLSTM tuning
# -----------------------------
for ma_window, lstm_units, dropout, lr, batch_size in itertools.product(
    MA_WINDOW_GRID,
    LSTM_UNITS_GRID,
    DROPOUT_GRID,
    LR_GRID,
    BATCH_SIZE_GRID
):
    run_id += 1

    tf.keras.backend.clear_session()
    random.seed(SEED)
    np.random.seed(SEED)
    tf.random.set_seed(SEED)

    model_name = f"DLSTM_24h_MA{ma_window}_U{lstm_units}_D{dropout}_LR{lr}_BS{batch_size}"

    print("\n======================================")
    print(f"Run {run_id}: {model_name}")
    print("======================================")

    trend_train, res_train = moving_average_decomposition(X_train_scaled, window=ma_window)
    trend_val, res_val = moving_average_decomposition(X_val_scaled, window=ma_window)
    trend_test, res_test = moving_average_decomposition(X_test_scaled, window=ma_window)

    X_train_input = np.concatenate([trend_train, res_train], axis=2)
    X_val_input = np.concatenate([trend_val, res_val], axis=2)
    X_test_input = np.concatenate([trend_test, res_test], axis=2)

    model = build_dlstm_tuned(
        input_shape=(X_train_input.shape[1], X_train_input.shape[2]),
        lstm_units=lstm_units,
        dropout=dropout,
        lr=lr
    )

    run_and_record(
        model,
        model_name,
        "DLSTM",
        batch_size,
        {
            "LSTM_Units": lstm_units,
            "Dense_Units": np.nan,
            "Dropout": dropout,
            "Learning_Rate": lr,
            "MA_Window": ma_window,
            "Transformer_Blocks": np.nan,
            "Transformer_Heads": np.nan,
            "Transformer_Key_Dim": np.nan,
            "Transformer_FF_Dim": np.nan
        }
    )

    del model
    gc.collect()


# -----------------------------
# Transformer tuning
# -----------------------------
for num_blocks, num_heads, key_dim, ff_dim, dropout, lr, batch_size in itertools.product(
    TRANSFORMER_BLOCKS_GRID,
    TRANSFORMER_HEADS_GRID,
    TRANSFORMER_KEY_DIM_GRID,
    TRANSFORMER_FF_DIM_GRID,
    DROPOUT_GRID,
    LR_GRID,
    BATCH_SIZE_GRID
):
    run_id += 1

    tf.keras.backend.clear_session()
    random.seed(SEED)
    np.random.seed(SEED)
    tf.random.set_seed(SEED)

    model_name = (
        f"Transformer_24h_B{num_blocks}_H{num_heads}_K{key_dim}"
        f"_FF{ff_dim}_D{dropout}_LR{lr}_BS{batch_size}"
    )

    print("\n======================================")
    print(f"Run {run_id}: {model_name}")
    print("======================================")

    X_train_input = X_train_scaled
    X_val_input = X_val_scaled
    X_test_input = X_test_scaled

    model = build_transformer_tuned(
        input_shape=input_shape,
        num_blocks=num_blocks,
        num_heads=num_heads,
        key_dim=key_dim,
        ff_dim=ff_dim,
        dense_units=32,
        dropout=dropout,
        lr=lr
    )

    run_and_record(
        model,
        model_name,
        "Transformer",
        batch_size,
        {
            "LSTM_Units": np.nan,
            "Dense_Units": 32,
            "Dropout": dropout,
            "Learning_Rate": lr,
            "MA_Window": np.nan,
            "Transformer_Blocks": num_blocks,
            "Transformer_Heads": num_heads,
            "Transformer_Key_Dim": key_dim,
            "Transformer_FF_Dim": ff_dim
        }
    )

    del model
    gc.collect()


# ============================================================
# Collate and save results
# ============================================================

tuning_all_df = pd.DataFrame(tuning_rows)

tuning_by_val = tuning_all_df.sort_values(
    "Val_TSS",
    ascending=False
).reset_index(drop=True)

tuning_by_test = tuning_all_df.sort_values(
    "Test_TSS",
    ascending=False
).reset_index(drop=True)

print("\n======================================")
print("BEST CONFIGURATIONS BY VALIDATION TSS")
print("Official selection rule")
print("======================================")
display(tuning_by_val.head(15).round(4))

print("\n======================================")
print("AUDIT ONLY: TOP 15 BY TEST TSS")
print("Do NOT use this for model selection")
print("======================================")
display(tuning_by_test.head(15).round(4))

tuning_by_val.to_csv(
    os.path.join(TUNE_OUT_DIR, "24H_ALL_MODELS_TUNING_BY_VAL_TSS.csv"),
    index=False
)

tuning_by_test.to_csv(
    os.path.join(TUNE_OUT_DIR, "AUDIT_ONLY_24H_ALL_MODELS_TUNING_BY_TEST_TSS.csv"),
    index=False
)

# Save official best validation-selected probability arrays
best_val_model_name = tuning_by_val.iloc[0]["Model"]
best_val_item = prob_store[best_val_model_name]

np.save(os.path.join(TUNE_OUT_DIR, "best_val_24h_val_prob.npy"), best_val_item["val_prob"])
np.save(os.path.join(TUNE_OUT_DIR, "best_val_24h_test_prob.npy"), best_val_item["test_prob"])
np.save(os.path.join(TUNE_OUT_DIR, "best_val_24h_test_pred.npy"), best_val_item["y_pred"])

print("\nSaved tuning outputs to:", TUNE_OUT_DIR)
print("Best validation-selected model:", best_val_model_name)
print("\nOfficial best validation-selected result:")
display(pd.DataFrame([best_val_item["result"]]).round(4))
# Out:
# Saving tuning outputs to: /content/drive/MyDrive/AR_Stratified/Journal_Revision_24h_CLEAN_TRANSFORMER/24h_all_models_hyperparameter_tuning
# TensorFlow: 2.20.0
# Input shape: (4, 21)
# Class weights: {0: 0.5593856655290103, 1: 4.709770114942529}
#
# ======================================
# Run 1: LSTM_24h_U64_Dense32_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.5719 | Test_TSS=0.4195 | PR_AUC=0.6693 | Precision=0.4684 | F1=0.5993
#
# ======================================
# Run 2: LSTM_24h_U64_Dense32_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.5521 | Test_TSS=0.4551 | PR_AUC=0.6952 | Precision=0.4944 | F1=0.6175
#
# ======================================
# Run 3: LSTM_24h_U64_Dense32_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.5590 | Test_TSS=0.4690 | PR_AUC=0.6903 | Precision=0.5119 | F1=0.6255
#
# ======================================
# Run 4: LSTM_24h_U64_Dense32_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.5322 | Test_TSS=0.4515 | PR_AUC=0.6972 | Precision=0.5030 | F1=0.6159
#
# ======================================
# Run 5: LSTM_24h_U64_Dense32_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.5804 | Test_TSS=0.4515 | PR_AUC=0.6745 | Precision=0.5030 | F1=0.6159
#
# ======================================
# Run 6: LSTM_24h_U64_Dense32_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.5625 | Test_TSS=0.4825 | PR_AUC=0.6991 | Precision=0.5179 | F1=0.6327
#
# ======================================
# Run 7: LSTM_24h_U64_Dense32_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.5561 | Test_TSS=0.4714 | PR_AUC=0.6900 | Precision=0.5057 | F1=0.6263
#
# ======================================
# Run 8: LSTM_24h_U64_Dense32_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.5372 | Test_TSS=0.4463 | PR_AUC=0.6966 | Precision=0.5030 | F1=0.6131
#
# ======================================
# Run 9: LSTM_24h_U64_Dense64_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.5853 | Test_TSS=0.4434 | PR_AUC=0.6807 | Precision=0.4971 | F1=0.6115
#
# ======================================
# Run 10: LSTM_24h_U64_Dense64_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.5838 | Test_TSS=0.4224 | PR_AUC=0.6856 | Precision=0.4731 | F1=0.6007
#
# ======================================
# Run 11: LSTM_24h_U64_Dense64_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.5764 | Test_TSS=0.4369 | PR_AUC=0.6682 | Precision=0.5000 | F1=0.6081
#
# ======================================
# Run 12: LSTM_24h_U64_Dense64_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.5947 | Test_TSS=0.4277 | PR_AUC=0.6820 | Precision=0.4734 | F1=0.6034
#
# ======================================
# Run 13: LSTM_24h_U64_Dense64_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.6052 | Test_TSS=0.4364 | PR_AUC=0.6767 | Precision=0.4886 | F1=0.6078
#
# ======================================
# Run 14: LSTM_24h_U64_Dense64_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.5789 | Test_TSS=0.4277 | PR_AUC=0.6883 | Precision=0.4734 | F1=0.6034
#
# ======================================
# Run 15: LSTM_24h_U64_Dense64_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.6047 | Test_TSS=0.4626 | PR_AUC=0.6819 | Precision=0.5153 | F1=0.6222
#
# ======================================
# Run 16: LSTM_24h_U64_Dense64_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.5823 | Test_TSS=0.4382 | PR_AUC=0.6847 | Precision=0.4740 | F1=0.6087
#
# ======================================
# Run 17: LSTM_24h_U128_Dense32_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.5878 | Test_TSS=0.4462 | PR_AUC=0.6763 | Precision=0.5347 | F1=0.6135
#
# ======================================
# Run 18: LSTM_24h_U128_Dense32_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.5570 | Test_TSS=0.4436 | PR_AUC=0.6845 | Precision=0.4562 | F1=0.6111
#
# ======================================
# Run 19: LSTM_24h_U128_Dense32_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.5630 | Test_TSS=0.4095 | PR_AUC=0.6867 | Precision=0.4773 | F1=0.5936
#
# ======================================
# Run 20: LSTM_24h_U128_Dense32_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.5491 | Test_TSS=0.4306 | PR_AUC=0.6840 | Precision=0.4783 | F1=0.6048
#
# ======================================
# Run 21: LSTM_24h_U128_Dense32_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.5843 | Test_TSS=0.4119 | PR_AUC=0.6804 | Precision=0.4725 | F1=0.5952
#
# ======================================
# Run 22: LSTM_24h_U128_Dense32_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.5511 | Test_TSS=0.4555 | PR_AUC=0.6887 | Precision=0.5379 | F1=0.6190
#
# ======================================
# Run 23: LSTM_24h_U128_Dense32_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.5595 | Test_TSS=0.4315 | PR_AUC=0.6838 | Precision=0.5319 | F1=0.6048
#
# ======================================
# Run 24: LSTM_24h_U128_Dense32_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.5526 | Test_TSS=0.4376 | PR_AUC=0.6870 | Precision=0.4860 | F1=0.6084
#
# ======================================
# Run 25: LSTM_24h_U128_Dense64_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.5685 | Test_TSS=0.4404 | PR_AUC=0.6755 | Precision=0.5197 | F1=0.6100
#
# ======================================
# Run 26: LSTM_24h_U128_Dense64_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.5615 | Test_TSS=0.4766 | PR_AUC=0.6878 | Precision=0.5359 | F1=0.6308
#
# ======================================
# Run 27: LSTM_24h_U128_Dense64_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.5947 | Test_TSS=0.4380 | PR_AUC=0.6757 | Precision=0.5274 | F1=0.6087
#
# ======================================
# Run 28: LSTM_24h_U128_Dense64_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.5694 | Test_TSS=0.4282 | PR_AUC=0.6802 | Precision=0.4831 | F1=0.6035
#
# ======================================
# Run 29: LSTM_24h_U128_Dense64_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.5863 | Test_TSS=0.4131 | PR_AUC=0.6680 | Precision=0.4703 | F1=0.5959
#
# ======================================
# Run 30: LSTM_24h_U128_Dense64_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.5883 | Test_TSS=0.4334 | PR_AUC=0.6783 | Precision=0.5096 | F1=0.6061
#
# ======================================
# Run 31: LSTM_24h_U128_Dense64_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.5918 | Test_TSS=0.4200 | PR_AUC=0.6655 | Precision=0.5032 | F1=0.5985
#
# ======================================
# Run 32: LSTM_24h_U128_Dense64_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.5640 | Test_TSS=0.4451 | PR_AUC=0.6876 | Precision=0.5061 | F1=0.6125
#
# ======================================
# Run 33: BiLSTM_24h_U64_Dense32_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.5779 | Test_TSS=0.4015 | PR_AUC=0.6840 | Precision=0.4527 | F1=0.5909
#
# ======================================
# Run 34: BiLSTM_24h_U64_Dense32_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.5704 | Test_TSS=0.4015 | PR_AUC=0.6971 | Precision=0.4527 | F1=0.5909
#
# ======================================
# Run 35: BiLSTM_24h_U64_Dense32_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.5848 | Test_TSS=0.4859 | PR_AUC=0.6980 | Precision=0.5390 | F1=0.6360
#
# ======================================
# Run 36: BiLSTM_24h_U64_Dense32_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.5536 | Test_TSS=0.4597 | PR_AUC=0.6994 | Precision=0.5090 | F1=0.6204
#
# ======================================
# Run 37: BiLSTM_24h_U64_Dense32_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.6151 | Test_TSS=0.4806 | PR_AUC=0.6902 | Precision=0.5395 | F1=0.6332
#
# ======================================
# Run 38: BiLSTM_24h_U64_Dense32_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.5759 | Test_TSS=0.4272 | PR_AUC=0.6901 | Precision=0.4646 | F1=0.6033
#
# ======================================
# Run 39: BiLSTM_24h_U64_Dense32_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.5818 | Test_TSS=0.4393 | PR_AUC=0.6944 | Precision=0.4942 | F1=0.6093
#
# ======================================
# Run 40: BiLSTM_24h_U64_Dense32_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.5610 | Test_TSS=0.4405 | PR_AUC=0.6985 | Precision=0.4914 | F1=0.6099
#
# ======================================
# Run 41: BiLSTM_24h_U64_Dense64_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.5551 | Test_TSS=0.4573 | PR_AUC=0.7029 | Precision=0.5155 | F1=0.6194
#
# ======================================
# Run 42: BiLSTM_24h_U64_Dense64_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.5828 | Test_TSS=0.4452 | PR_AUC=0.7051 | Precision=0.4813 | F1=0.6122
#
# ======================================
# Run 43: BiLSTM_24h_U64_Dense64_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.5818 | Test_TSS=0.4475 | PR_AUC=0.7086 | Precision=0.5000 | F1=0.6137
#
# ======================================
# Run 44: BiLSTM_24h_U64_Dense64_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.5660 | Test_TSS=0.4661 | PR_AUC=0.7089 | Precision=0.5058 | F1=0.6237
#
# ======================================
# Run 45: BiLSTM_24h_U64_Dense64_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.5928 | Test_TSS=0.4328 | PR_AUC=0.6970 | Precision=0.4970 | F1=0.6058
#
# ======================================
# Run 46: BiLSTM_24h_U64_Dense64_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.5665 | Test_TSS=0.4335 | PR_AUC=0.7112 | Precision=0.4833 | F1=0.6063
#
# ======================================
# Run 47: BiLSTM_24h_U64_Dense64_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.5456 | Test_TSS=0.4598 | PR_AUC=0.7103 | Precision=0.4842 | F1=0.6195
#
# ======================================
# Run 48: BiLSTM_24h_U64_Dense64_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.5650 | Test_TSS=0.4685 | PR_AUC=0.7074 | Precision=0.5000 | F1=0.6246
#
# ======================================
# Run 49: BiLSTM_24h_U128_Dense32_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.5809 | Test_TSS=0.4469 | PR_AUC=0.6965 | Precision=0.4889 | F1=0.6132
#
# ======================================
# Run 50: BiLSTM_24h_U128_Dense32_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.5804 | Test_TSS=0.4201 | PR_AUC=0.6937 | Precision=0.4778 | F1=0.5993
#
# ======================================
# Run 51: BiLSTM_24h_U128_Dense32_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.5769 | Test_TSS=0.4498 | PR_AUC=0.6848 | Precision=0.4943 | F1=0.6148
#
# ======================================
# Run 52: BiLSTM_24h_U128_Dense32_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.5769 | Test_TSS=0.4241 | PR_AUC=0.6814 | Precision=0.4804 | F1=0.6014
#
# ======================================
# Run 53: BiLSTM_24h_U128_Dense32_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.5645 | Test_TSS=0.4632 | PR_AUC=0.7048 | Precision=0.5000 | F1=0.6219
#
# ======================================
# Run 54: BiLSTM_24h_U128_Dense32_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.5739 | Test_TSS=0.4020 | PR_AUC=0.6836 | Precision=0.4607 | F1=0.5906
#
# ======================================
# Run 55: BiLSTM_24h_U128_Dense32_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.5704 | Test_TSS=0.4411 | PR_AUC=0.7017 | Precision=0.4787 | F1=0.6102
#
# ======================================
# Run 56: BiLSTM_24h_U128_Dense32_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.5556 | Test_TSS=0.4632 | PR_AUC=0.7020 | Precision=0.5000 | F1=0.6219
#
# ======================================
# Run 57: BiLSTM_24h_U128_Dense64_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.5957 | Test_TSS=0.4485 | PR_AUC=0.6810 | Precision=0.5267 | F1=0.6148
#
# ======================================
# Run 58: BiLSTM_24h_U128_Dense64_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.5689 | Test_TSS=0.4032 | PR_AUC=0.6898 | Precision=0.4588 | F1=0.5914
#
# ======================================
# Run 59: BiLSTM_24h_U128_Dense64_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.5610 | Test_TSS=0.4679 | PR_AUC=0.7022 | Precision=0.5152 | F1=0.6250
#
# ======================================
# Run 60: BiLSTM_24h_U128_Dense64_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.5838 | Test_TSS=0.4451 | PR_AUC=0.6817 | Precision=0.5061 | F1=0.6125
#
# ======================================
# Run 61: BiLSTM_24h_U128_Dense64_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.5858 | Test_TSS=0.4288 | PR_AUC=0.6818 | Precision=0.4940 | F1=0.6036
#
# ======================================
# Run 62: BiLSTM_24h_U128_Dense64_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.5982 | Test_TSS=0.4148 | PR_AUC=0.6900 | Precision=0.4775 | F1=0.5965
#
# ======================================
# Run 63: BiLSTM_24h_U128_Dense64_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.5858 | Test_TSS=0.4743 | PR_AUC=0.6983 | Precision=0.5118 | F1=0.6282
#
# ======================================
# Run 64: BiLSTM_24h_U128_Dense64_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.5823 | Test_TSS=0.4486 | PR_AUC=0.6877 | Precision=0.4971 | F1=0.6143
#
# ======================================
# Run 65: DLSTM_24h_MA3_U64_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.5699 | Test_TSS=0.3932 | PR_AUC=0.6712 | Precision=0.4667 | F1=0.5854
#
# ======================================
# Run 66: DLSTM_24h_MA3_U64_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.5159 | Test_TSS=0.3775 | PR_AUC=0.6636 | Precision=0.4467 | F1=0.5789
#
# ======================================
# Run 67: DLSTM_24h_MA3_U64_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.4122 | Test_TSS=0.3238 | PR_AUC=0.5555 | Precision=0.4264 | F1=0.5526
#
# ======================================
# Run 68: DLSTM_24h_MA3_U64_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.4196 | Test_TSS=0.3221 | PR_AUC=0.5814 | Precision=0.4216 | F1=0.5531
#
# ======================================
# Run 69: DLSTM_24h_MA3_U64_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.5109 | Test_TSS=0.3998 | PR_AUC=0.6684 | Precision=0.4471 | F1=0.5905
#
# ======================================
# Run 70: DLSTM_24h_MA3_U64_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.5660 | Test_TSS=0.3908 | PR_AUC=0.6695 | Precision=0.4713 | F1=0.5836
#
# ======================================
# Run 71: DLSTM_24h_MA3_U64_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.4167 | Test_TSS=0.3099 | PR_AUC=0.5454 | Precision=0.4155 | F1=0.5478
#
# ======================================
# Run 72: DLSTM_24h_MA3_U64_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.4043 | Test_TSS=0.3087 | PR_AUC=0.5539 | Precision=0.4167 | F1=0.5466
#
# ======================================
# Run 73: DLSTM_24h_MA3_U128_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.5962 | Test_TSS=0.4434 | PR_AUC=0.6730 | Precision=0.4971 | F1=0.6115
#
# ======================================
# Run 74: DLSTM_24h_MA3_U128_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.5660 | Test_TSS=0.4369 | PR_AUC=0.6617 | Precision=0.5000 | F1=0.6081
#
# ======================================
# Run 75: DLSTM_24h_MA3_U128_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.5719 | Test_TSS=0.4119 | PR_AUC=0.6708 | Precision=0.4725 | F1=0.5952
#
# ======================================
# Run 76: DLSTM_24h_MA3_U128_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.5764 | Test_TSS=0.4410 | PR_AUC=0.6793 | Precision=0.5030 | F1=0.6103
#
# ======================================
# Run 77: DLSTM_24h_MA3_U128_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.5818 | Test_TSS=0.4580 | PR_AUC=0.6659 | Precision=0.5000 | F1=0.6192
#
# ======================================
# Run 78: DLSTM_24h_MA3_U128_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.5769 | Test_TSS=0.4475 | PR_AUC=0.6772 | Precision=0.5000 | F1=0.6137
#
# ======================================
# Run 79: DLSTM_24h_MA3_U128_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.5446 | Test_TSS=0.4422 | PR_AUC=0.6679 | Precision=0.5000 | F1=0.6109
#
# ======================================
# Run 80: DLSTM_24h_MA3_U128_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.5521 | Test_TSS=0.4177 | PR_AUC=0.6754 | Precision=0.4828 | F1=0.5979
#
# ======================================
# Run 81: DLSTM_24h_MA5_U64_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.5670 | Test_TSS=0.4272 | PR_AUC=0.6952 | Precision=0.4646 | F1=0.6033
#
# ======================================
# Run 82: DLSTM_24h_MA5_U64_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.5804 | Test_TSS=0.4335 | PR_AUC=0.6906 | Precision=0.4833 | F1=0.6063
#
# ======================================
# Run 83: DLSTM_24h_MA5_U64_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.3844 | Test_TSS=0.3168 | PR_AUC=0.5548 | Precision=0.4208 | F1=0.5502
#
# ======================================
# Run 84: DLSTM_24h_MA5_U64_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.3889 | Test_TSS=0.2895 | PR_AUC=0.5465 | Precision=0.4057 | F1=0.5392
#
# ======================================
# Run 85: DLSTM_24h_MA5_U64_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.5258 | Test_TSS=0.4481 | PR_AUC=0.6739 | Precision=0.4863 | F1=0.6138
#
# ======================================
# Run 86: DLSTM_24h_MA5_U64_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.5853 | Test_TSS=0.4510 | PR_AUC=0.6847 | Precision=0.4916 | F1=0.6154
#
# ======================================
# Run 87: DLSTM_24h_MA5_U64_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.3909 | Test_TSS=0.3389 | PR_AUC=0.5514 | Precision=0.4551 | F1=0.5547
#
# ======================================
# Run 88: DLSTM_24h_MA5_U64_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.3874 | Test_TSS=0.3348 | PR_AUC=0.5505 | Precision=0.4524 | F1=0.5527
#
# ======================================
# Run 89: DLSTM_24h_MA5_U128_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.5962 | Test_TSS=0.4376 | PR_AUC=0.6812 | Precision=0.4860 | F1=0.6084
#
# ======================================
# Run 90: DLSTM_24h_MA5_U128_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.5893 | Test_TSS=0.4632 | PR_AUC=0.6745 | Precision=0.5000 | F1=0.6219
#
# ======================================
# Run 91: DLSTM_24h_MA5_U128_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.5858 | Test_TSS=0.4428 | PR_AUC=0.6791 | Precision=0.4862 | F1=0.6111
#
# ======================================
# Run 92: DLSTM_24h_MA5_U128_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.5665 | Test_TSS=0.4411 | PR_AUC=0.6831 | Precision=0.4787 | F1=0.6102
#
# ======================================
# Run 93: DLSTM_24h_MA5_U128_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.5804 | Test_TSS=0.4779 | PR_AUC=0.6845 | Precision=0.5028 | F1=0.6294
#
# ======================================
# Run 94: DLSTM_24h_MA5_U128_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.5605 | Test_TSS=0.4615 | PR_AUC=0.6666 | Precision=0.4918 | F1=0.6207
#
# ======================================
# Run 95: DLSTM_24h_MA5_U128_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.5412 | Test_TSS=0.4738 | PR_AUC=0.6716 | Precision=0.5000 | F1=0.6272
#
# ======================================
# Run 96: DLSTM_24h_MA5_U128_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.5506 | Test_TSS=0.4452 | PR_AUC=0.6815 | Precision=0.4813 | F1=0.6122
#
# ======================================
# Run 97: Transformer_24h_B1_H2_K16_FF64_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.4921 | Test_TSS=0.3315 | PR_AUC=0.6331 | Precision=0.4244 | F1=0.5577
#
# ======================================
# Run 98: Transformer_24h_B1_H2_K16_FF64_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.4802 | Test_TSS=0.3216 | PR_AUC=0.6233 | Precision=0.4159 | F1=0.5545
#
# ======================================
# Run 99: Transformer_24h_B1_H2_K16_FF64_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.4633 | Test_TSS=0.3536 | PR_AUC=0.6239 | Precision=0.4404 | F1=0.5667
#
# ======================================
# Run 100: Transformer_24h_B1_H2_K16_FF64_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.4484 | Test_TSS=0.3379 | PR_AUC=0.6268 | Precision=0.4238 | F1=0.5615
#
# ======================================
# Run 101: Transformer_24h_B1_H2_K16_FF64_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.4772 | Test_TSS=0.3600 | PR_AUC=0.6242 | Precision=0.4394 | F1=0.5705
#
# ======================================
# Run 102: Transformer_24h_B1_H2_K16_FF64_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.4965 | Test_TSS=0.4102 | PR_AUC=0.6252 | Precision=0.4656 | F1=0.5946
#
# ======================================
# Run 103: Transformer_24h_B1_H2_K16_FF64_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.4812 | Test_TSS=0.3425 | PR_AUC=0.6257 | Precision=0.4322 | F1=0.5621
#
# ======================================
# Run 104: Transformer_24h_B1_H2_K16_FF64_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.4712 | Test_TSS=0.3704 | PR_AUC=0.6273 | Precision=0.4581 | F1=0.5734
#
# ======================================
# Run 105: Transformer_24h_B1_H2_K16_FF128_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.4578 | Test_TSS=0.3030 | PR_AUC=0.6194 | Precision=0.4000 | F1=0.5497
#
# ======================================
# Run 106: Transformer_24h_B1_H2_K16_FF128_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.4777 | Test_TSS=0.3449 | PR_AUC=0.6161 | Precision=0.4293 | F1=0.5641
#
# ======================================
# Run 107: Transformer_24h_B1_H2_K16_FF128_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.4692 | Test_TSS=0.3292 | PR_AUC=0.6188 | Precision=0.4144 | F1=0.5593
#
# ======================================
# Run 108: Transformer_24h_B1_H2_K16_FF128_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.4846 | Test_TSS=0.3519 | PR_AUC=0.5960 | Precision=0.4350 | F1=0.5668
#
# ======================================
# Run 109: Transformer_24h_B1_H2_K16_FF128_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.4638 | Test_TSS=0.3537 | PR_AUC=0.6124 | Precision=0.4259 | F1=0.5697
#
# ======================================
# Run 110: Transformer_24h_B1_H2_K16_FF128_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.4504 | Test_TSS=0.3170 | PR_AUC=0.6157 | Precision=0.4089 | F1=0.5542
#
# ======================================
# Run 111: Transformer_24h_B1_H2_K16_FF128_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.4707 | Test_TSS=0.3648 | PR_AUC=0.6110 | Precision=0.4333 | F1=0.5741
#
# ======================================
# Run 112: Transformer_24h_B1_H2_K16_FF128_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.4886 | Test_TSS=0.3583 | PR_AUC=0.5755 | Precision=0.4341 | F1=0.5705
#
# ======================================
# Run 113: Transformer_24h_B1_H2_K32_FF64_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.4792 | Test_TSS=0.3337 | PR_AUC=0.6151 | Precision=0.4362 | F1=0.5559
#
# ======================================
# Run 114: Transformer_24h_B1_H2_K32_FF64_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.4697 | Test_TSS=0.3745 | PR_AUC=0.6117 | Precision=0.4607 | F1=0.5754
#
# ======================================
# Run 115: Transformer_24h_B1_H2_K32_FF64_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.4603 | Test_TSS=0.3344 | PR_AUC=0.6301 | Precision=0.4279 | F1=0.5584
#
# ======================================
# Run 116: Transformer_24h_B1_H2_K32_FF64_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.4494 | Test_TSS=0.3519 | PR_AUC=0.6290 | Precision=0.4350 | F1=0.5668
#
# ======================================
# Run 117: Transformer_24h_B1_H2_K32_FF64_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.4385 | Test_TSS=0.3250 | PR_AUC=0.6077 | Precision=0.4250 | F1=0.5537
#
# ======================================
# Run 118: Transformer_24h_B1_H2_K32_FF64_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.4767 | Test_TSS=0.3286 | PR_AUC=0.6235 | Precision=0.4211 | F1=0.5570
#
# ======================================
# Run 119: Transformer_24h_B1_H2_K32_FF64_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.4420 | Test_TSS=0.3512 | PR_AUC=0.6319 | Precision=0.4439 | F1=0.5646
#
# ======================================
# Run 120: Transformer_24h_B1_H2_K32_FF64_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.4876 | Test_TSS=0.3682 | PR_AUC=0.6206 | Precision=0.4439 | F1=0.5743
#
# ======================================
# Run 121: Transformer_24h_B1_H2_K32_FF128_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.4469 | Test_TSS=0.4018 | PR_AUC=0.5977 | Precision=0.5103 | F1=0.5873
#
# ======================================
# Run 122: Transformer_24h_B1_H2_K32_FF128_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.4578 | Test_TSS=0.3071 | PR_AUC=0.6214 | Precision=0.4017 | F1=0.5513
#
# ======================================
# Run 123: Transformer_24h_B1_H2_K32_FF128_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.4618 | Test_TSS=0.3297 | PR_AUC=0.6126 | Precision=0.4198 | F1=0.5580
#
# ======================================
# Run 124: Transformer_24h_B1_H2_K32_FF128_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.4945 | Test_TSS=0.3619 | PR_AUC=0.5980 | Precision=0.4299 | F1=0.5732
#
# ======================================
# Run 125: Transformer_24h_B1_H2_K32_FF128_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.4772 | Test_TSS=0.3571 | PR_AUC=0.6106 | Precision=0.4356 | F1=0.5696
#
# ======================================
# Run 126: Transformer_24h_B1_H2_K32_FF128_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.4797 | Test_TSS=0.3636 | PR_AUC=0.6055 | Precision=0.4348 | F1=0.5732
#
# ======================================
# Run 127: Transformer_24h_B1_H2_K32_FF128_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.4618 | Test_TSS=0.3636 | PR_AUC=0.6087 | Precision=0.4348 | F1=0.5732
#
# ======================================
# Run 128: Transformer_24h_B1_H2_K32_FF128_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.4871 | Test_TSS=0.3688 | PR_AUC=0.5861 | Precision=0.4354 | F1=0.5759
#
# ======================================
# Run 129: Transformer_24h_B1_H4_K16_FF64_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.4697 | Test_TSS=0.3228 | PR_AUC=0.6376 | Precision=0.4147 | F1=0.5556
#
# ======================================
# Run 130: Transformer_24h_B1_H4_K16_FF64_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.4608 | Test_TSS=0.3961 | PR_AUC=0.6011 | Precision=0.4716 | F1=0.5866
#
# ======================================
# Run 131: Transformer_24h_B1_H4_K16_FF64_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.4494 | Test_TSS=0.4182 | PR_AUC=0.6066 | Precision=0.4939 | F1=0.5978
#
# ======================================
# Run 132: Transformer_24h_B1_H4_K16_FF64_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.4444 | Test_TSS=0.3559 | PR_AUC=0.6238 | Precision=0.4372 | F1=0.5686
#
# ======================================
# Run 133: Transformer_24h_B1_H4_K16_FF64_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.5149 | Test_TSS=0.2947 | PR_AUC=0.6276 | Precision=0.4065 | F1=0.5421
#
# ======================================
# Run 134: Transformer_24h_B1_H4_K16_FF64_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.5035 | Test_TSS=0.3641 | PR_AUC=0.6217 | Precision=0.4416 | F1=0.5724
#
# ======================================
# Run 135: Transformer_24h_B1_H4_K16_FF64_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.4573 | Test_TSS=0.3187 | PR_AUC=0.6284 | Precision=0.4128 | F1=0.5538
#
# ======================================
# Run 136: Transformer_24h_B1_H4_K16_FF64_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.5005 | Test_TSS=0.3466 | PR_AUC=0.6224 | Precision=0.4343 | F1=0.5639
#
# ======================================
# Run 137: Transformer_24h_B1_H4_K16_FF128_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.4697 | Test_TSS=0.3076 | PR_AUC=0.6179 | Precision=0.4062 | F1=0.5498
#
# ======================================
# Run 138: Transformer_24h_B1_H4_K16_FF128_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.4504 | Test_TSS=0.3210 | PR_AUC=0.6185 | Precision=0.4107 | F1=0.5559
#
# ======================================
# Run 139: Transformer_24h_B1_H4_K16_FF128_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.4618 | Test_TSS=0.3309 | PR_AUC=0.6137 | Precision=0.4186 | F1=0.5590
#
# ======================================
# Run 140: Transformer_24h_B1_H4_K16_FF128_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.4752 | Test_TSS=0.3525 | PR_AUC=0.5978 | Precision=0.4272 | F1=0.5687
#
# ======================================
# Run 141: Transformer_24h_B1_H4_K16_FF128_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.4668 | Test_TSS=0.3449 | PR_AUC=0.5853 | Precision=0.4293 | F1=0.5641
#
# ======================================
# Run 142: Transformer_24h_B1_H4_K16_FF128_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.4643 | Test_TSS=0.3549 | PR_AUC=0.6178 | Precision=0.4247 | F1=0.5706
#
# ======================================
# Run 143: Transformer_24h_B1_H4_K16_FF128_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.4583 | Test_TSS=0.3583 | PR_AUC=0.6099 | Precision=0.4341 | F1=0.5705
#
# ======================================
# Run 144: Transformer_24h_B1_H4_K16_FF128_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.4931 | Test_TSS=0.3548 | PR_AUC=0.5895 | Precision=0.4388 | F1=0.5677
#
# ======================================
# Run 145: Transformer_24h_B1_H4_K32_FF64_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.4752 | Test_TSS=0.3035 | PR_AUC=0.6013 | Precision=0.4044 | F1=0.5482
#
# ======================================
# Run 146: Transformer_24h_B1_H4_K32_FF64_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.4797 | Test_TSS=0.3542 | PR_AUC=0.6162 | Precision=0.4320 | F1=0.5687
#
# ======================================
# Run 147: Transformer_24h_B1_H4_K32_FF64_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.4722 | Test_TSS=0.3291 | PR_AUC=0.6228 | Precision=0.4271 | F1=0.5556
#
# ======================================
# Run 148: Transformer_24h_B1_H4_K32_FF64_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.4410 | Test_TSS=0.3513 | PR_AUC=0.6201 | Precision=0.4286 | F1=0.5678
#
# ======================================
# Run 149: Transformer_24h_B1_H4_K32_FF64_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.4668 | Test_TSS=0.3135 | PR_AUC=0.6049 | Precision=0.4017 | F1=0.5549
#
# ======================================
# Run 150: Transformer_24h_B1_H4_K32_FF64_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.4911 | Test_TSS=0.3333 | PR_AUC=0.6191 | Precision=0.4163 | F1=0.5610
#
# ======================================
# Run 151: Transformer_24h_B1_H4_K32_FF64_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.4643 | Test_TSS=0.3122 | PR_AUC=0.6073 | Precision=0.4131 | F1=0.5500
#
# ======================================
# Run 152: Transformer_24h_B1_H4_K32_FF64_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.4950 | Test_TSS=0.3682 | PR_AUC=0.6168 | Precision=0.4439 | F1=0.5743
#
# ======================================
# Run 153: Transformer_24h_B1_H4_K32_FF128_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.4990 | Test_TSS=0.3338 | PR_AUC=0.5818 | Precision=0.4218 | F1=0.5597
#
# ======================================
# Run 154: Transformer_24h_B1_H4_K32_FF128_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.4444 | Test_TSS=0.3367 | PR_AUC=0.5870 | Precision=0.4251 | F1=0.5605
#
# ======================================
# Run 155: Transformer_24h_B1_H4_K32_FF128_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.4638 | Test_TSS=0.3827 | PR_AUC=0.6035 | Precision=0.4659 | F1=0.5795
#
# ======================================
# Run 156: Transformer_24h_B1_H4_K32_FF128_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.4732 | Test_TSS=0.3554 | PR_AUC=0.5971 | Precision=0.4306 | F1=0.5696
#
# ======================================
# Run 157: Transformer_24h_B1_H4_K32_FF128_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.5055 | Test_TSS=0.3652 | PR_AUC=0.5446 | Precision=0.4576 | F1=0.5704
#
# ======================================
# Run 158: Transformer_24h_B1_H4_K32_FF128_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.4732 | Test_TSS=0.3234 | PR_AUC=0.5981 | Precision=0.4087 | F1=0.5579
#
# ======================================
# Run 159: Transformer_24h_B1_H4_K32_FF128_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.4876 | Test_TSS=0.3629 | PR_AUC=0.5775 | Precision=0.4433 | F1=0.5714
#
# ======================================
# Run 160: Transformer_24h_B1_H4_K32_FF128_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.5030 | Test_TSS=0.3688 | PR_AUC=0.5734 | Precision=0.4354 | F1=0.5759
#
# ======================================
# Run 161: Transformer_24h_B2_H2_K16_FF64_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.4633 | Test_TSS=0.3834 | PR_AUC=0.6207 | Precision=0.4387 | F1=0.5831
#
# ======================================
# Run 162: Transformer_24h_B2_H2_K16_FF64_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.5114 | Test_TSS=0.3403 | PR_AUC=0.6290 | Precision=0.4213 | F1=0.5635
#
# ======================================
# Run 163: Transformer_24h_B2_H2_K16_FF64_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.4856 | Test_TSS=0.4044 | PR_AUC=0.6278 | Precision=0.4569 | F1=0.5921
#
# ======================================
# Run 164: Transformer_24h_B2_H2_K16_FF64_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.4568 | Test_TSS=0.3728 | PR_AUC=0.6194 | Precision=0.4541 | F1=0.5753
#
# ======================================
# Run 165: Transformer_24h_B2_H2_K16_FF64_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.4851 | Test_TSS=0.3833 | PR_AUC=0.6205 | Precision=0.4550 | F1=0.5811
#
# ======================================
# Run 166: Transformer_24h_B2_H2_K16_FF64_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.4821 | Test_TSS=0.3776 | PR_AUC=0.6328 | Precision=0.4318 | F1=0.5810
#
# ======================================
# Run 167: Transformer_24h_B2_H2_K16_FF64_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.5084 | Test_TSS=0.4003 | PR_AUC=0.6311 | Precision=0.4545 | F1=0.5902
#
# ======================================
# Run 168: Transformer_24h_B2_H2_K16_FF64_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.4812 | Test_TSS=0.3659 | PR_AUC=0.6255 | Precision=0.4319 | F1=0.5750
#
# ======================================
# Run 169: Transformer_24h_B2_H2_K16_FF128_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.4891 | Test_TSS=0.3664 | PR_AUC=0.5839 | Precision=0.4556 | F1=0.5714
#
# ======================================
# Run 170: Transformer_24h_B2_H2_K16_FF128_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.4583 | Test_TSS=0.3437 | PR_AUC=0.6232 | Precision=0.4307 | F1=0.5631
#
# ======================================
# Run 171: Transformer_24h_B2_H2_K16_FF128_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.4737 | Test_TSS=0.3559 | PR_AUC=0.6046 | Precision=0.4372 | F1=0.5686
#
# ======================================
# Run 172: Transformer_24h_B2_H2_K16_FF128_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.4325 | Test_TSS=0.3257 | PR_AUC=0.6152 | Precision=0.4178 | F1=0.5563
#
# ======================================
# Run 173: Transformer_24h_B2_H2_K16_FF128_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.4380 | Test_TSS=0.3599 | PR_AUC=0.5899 | Precision=0.4571 | F1=0.5674
#
# ======================================
# Run 174: Transformer_24h_B2_H2_K16_FF128_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.4504 | Test_TSS=0.3403 | PR_AUC=0.6319 | Precision=0.4213 | F1=0.5635
#
# ======================================
# Run 175: Transformer_24h_B2_H2_K16_FF128_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.4489 | Test_TSS=0.3304 | PR_AUC=0.5922 | Precision=0.4133 | F1=0.5602
#
# ======================================
# Run 176: Transformer_24h_B2_H2_K16_FF128_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.4573 | Test_TSS=0.3788 | PR_AUC=0.6344 | Precision=0.4305 | F1=0.5818
#
# ======================================
# Run 177: Transformer_24h_B2_H2_K32_FF64_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.4931 | Test_TSS=0.3944 | PR_AUC=0.6217 | Precision=0.4645 | F1=0.5862
#
# ======================================
# Run 178: Transformer_24h_B2_H2_K32_FF64_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.5010 | Test_TSS=0.3741 | PR_AUC=0.6109 | Precision=0.4360 | F1=0.5786
#
# ======================================
# Run 179: Transformer_24h_B2_H2_K32_FF64_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.4945 | Test_TSS=0.3180 | PR_AUC=0.5965 | Precision=0.4195 | F1=0.5513
#
# ======================================
# Run 180: Transformer_24h_B2_H2_K32_FF64_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.4911 | Test_TSS=0.3746 | PR_AUC=0.6257 | Precision=0.4428 | F1=0.5779
#
# ======================================
# Run 181: Transformer_24h_B2_H2_K32_FF64_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.5129 | Test_TSS=0.3717 | PR_AUC=0.6334 | Precision=0.4390 | F1=0.5769
#
# ======================================
# Run 182: Transformer_24h_B2_H2_K32_FF64_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.5005 | Test_TSS=0.3472 | PR_AUC=0.6321 | Precision=0.4265 | F1=0.5660
#
# ======================================
# Run 183: Transformer_24h_B2_H2_K32_FF64_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.5283 | Test_TSS=0.4126 | PR_AUC=0.6377 | Precision=0.4615 | F1=0.5960
#
# ======================================
# Run 184: Transformer_24h_B2_H2_K32_FF64_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.4931 | Test_TSS=0.3927 | PR_AUC=0.6415 | Precision=0.4579 | F1=0.5859
#
# ======================================
# Run 185: Transformer_24h_B2_H2_K32_FF128_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.5422 | Test_TSS=0.3325 | PR_AUC=0.6256 | Precision=0.4378 | F1=0.5548
#
# ======================================
# Run 186: Transformer_24h_B2_H2_K32_FF128_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.4420 | Test_TSS=0.3344 | PR_AUC=0.6206 | Precision=0.4279 | F1=0.5584
#
# ======================================
# Run 187: Transformer_24h_B2_H2_K32_FF128_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.5164 | Test_TSS=0.3536 | PR_AUC=0.6245 | Precision=0.4404 | F1=0.5667
#
# ======================================
# Run 188: Transformer_24h_B2_H2_K32_FF128_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.4707 | Test_TSS=0.3128 | PR_AUC=0.6324 | Precision=0.4187 | F1=0.5484
#
# ======================================
# Run 189: Transformer_24h_B2_H2_K32_FF128_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.5089 | Test_TSS=0.3898 | PR_AUC=0.6358 | Precision=0.4536 | F1=0.5847
#
# ======================================
# Run 190: Transformer_24h_B2_H2_K32_FF128_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.4772 | Test_TSS=0.3745 | PR_AUC=0.6242 | Precision=0.4607 | F1=0.5754
#
# ======================================
# Run 191: Transformer_24h_B2_H2_K32_FF128_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.4881 | Test_TSS=0.4020 | PR_AUC=0.6276 | Precision=0.4607 | F1=0.5906
#
# ======================================
# Run 192: Transformer_24h_B2_H2_K32_FF128_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.4916 | Test_TSS=0.3548 | PR_AUC=0.6392 | Precision=0.4388 | F1=0.5677
#
# ======================================
# Run 193: Transformer_24h_B2_H4_K16_FF64_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.4891 | Test_TSS=0.3798 | PR_AUC=0.5928 | Precision=0.4611 | F1=0.5784
#
# ======================================
# Run 194: Transformer_24h_B2_H4_K16_FF64_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.4921 | Test_TSS=0.3648 | PR_AUC=0.6403 | Precision=0.4333 | F1=0.5741
#
# ======================================
# Run 195: Transformer_24h_B2_H4_K16_FF64_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.4826 | Test_TSS=0.3950 | PR_AUC=0.6372 | Precision=0.4541 | F1=0.5875
#
# ======================================
# Run 196: Transformer_24h_B2_H4_K16_FF64_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.5084 | Test_TSS=0.4097 | PR_AUC=0.6336 | Precision=0.4573 | F1=0.5948
#
# ======================================
# Run 197: Transformer_24h_B2_H4_K16_FF64_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.5055 | Test_TSS=0.4056 | PR_AUC=0.6251 | Precision=0.4550 | F1=0.5928
#
# ======================================
# Run 198: Transformer_24h_B2_H4_K16_FF64_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.5079 | Test_TSS=0.3733 | PR_AUC=0.6309 | Precision=0.4629 | F1=0.5745
#
# ======================================
# Run 199: Transformer_24h_B2_H4_K16_FF64_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.5228 | Test_TSS=0.4137 | PR_AUC=0.6353 | Precision=0.4596 | F1=0.5967
#
# ======================================
# Run 200: Transformer_24h_B2_H4_K16_FF64_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.5174 | Test_TSS=0.3687 | PR_AUC=0.6387 | Precision=0.4516 | F1=0.5734
#
# ======================================
# Run 201: Transformer_24h_B2_H4_K16_FF128_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.4742 | Test_TSS=0.3600 | PR_AUC=0.6108 | Precision=0.4394 | F1=0.5705
#
# ======================================
# Run 202: Transformer_24h_B2_H4_K16_FF128_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.4618 | Test_TSS=0.3109 | PR_AUC=0.6033 | Precision=0.4278 | F1=0.5442
#
# ======================================
# Run 203: Transformer_24h_B2_H4_K16_FF128_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.5045 | Test_TSS=0.3379 | PR_AUC=0.5936 | Precision=0.4238 | F1=0.5615
#
# ======================================
# Run 204: Transformer_24h_B2_H4_K16_FF128_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.4871 | Test_TSS=0.3549 | PR_AUC=0.6248 | Precision=0.4247 | F1=0.5706
#
# ======================================
# Run 205: Transformer_24h_B2_H4_K16_FF128_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.5179 | Test_TSS=0.3915 | PR_AUC=0.6257 | Precision=0.4599 | F1=0.5850
#
# ======================================
# Run 206: Transformer_24h_B2_H4_K16_FF128_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.4732 | Test_TSS=0.3478 | PR_AUC=0.6338 | Precision=0.4328 | F1=0.5649
#
# ======================================
# Run 207: Transformer_24h_B2_H4_K16_FF128_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.4916 | Test_TSS=0.3927 | PR_AUC=0.6216 | Precision=0.4579 | F1=0.5859
#
# ======================================
# Run 208: Transformer_24h_B2_H4_K16_FF128_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.4866 | Test_TSS=0.3641 | PR_AUC=0.6262 | Precision=0.4416 | F1=0.5724
#
# ======================================
# Run 209: Transformer_24h_B2_H4_K32_FF64_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.4821 | Test_TSS=0.3968 | PR_AUC=0.5673 | Precision=0.4603 | F1=0.5878
#
# ======================================
# Run 210: Transformer_24h_B2_H4_K32_FF64_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.4861 | Test_TSS=0.3344 | PR_AUC=0.5726 | Precision=0.4279 | F1=0.5584
#
# ======================================
# Run 211: Transformer_24h_B2_H4_K32_FF64_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.5124 | Test_TSS=0.3706 | PR_AUC=0.5810 | Precision=0.4406 | F1=0.5761
#
# ======================================
# Run 212: Transformer_24h_B2_H4_K32_FF64_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.4826 | Test_TSS=0.4323 | PR_AUC=0.6097 | Precision=0.4859 | F1=0.6056
#
# ======================================
# Run 213: Transformer_24h_B2_H4_K32_FF64_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.5069 | Test_TSS=0.4160 | PR_AUC=0.5736 | Precision=0.4751 | F1=0.5972
#
# ======================================
# Run 214: Transformer_24h_B2_H4_K32_FF64_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.5069 | Test_TSS=0.3635 | PR_AUC=0.5936 | Precision=0.4511 | F1=0.5704
#
# ======================================
# Run 215: Transformer_24h_B2_H4_K32_FF64_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.5372 | Test_TSS=0.4108 | PR_AUC=0.5877 | Precision=0.4554 | F1=0.5955
#
# ======================================
# Run 216: Transformer_24h_B2_H4_K32_FF64_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.4896 | Test_TSS=0.3857 | PR_AUC=0.6122 | Precision=0.4513 | F1=0.5828
#
# ======================================
# Run 217: Transformer_24h_B2_H4_K32_FF128_D0.2_LR0.001_BS64
# ======================================
# Val_TSS=0.4911 | Test_TSS=0.4066 | PR_AUC=0.5786 | Precision=0.4722 | F1=0.5923
#
# ======================================
# Run 218: Transformer_24h_B2_H4_K32_FF128_D0.2_LR0.001_BS128
# ======================================
# Val_TSS=0.4921 | Test_TSS=0.3595 | PR_AUC=0.5880 | Precision=0.4327 | F1=0.5714
#
# ======================================
# Run 219: Transformer_24h_B2_H4_K32_FF128_D0.2_LR0.0005_BS64
# ======================================
# Val_TSS=0.4707 | Test_TSS=0.3583 | PR_AUC=0.5528 | Precision=0.4341 | F1=0.5705
#
# ======================================
# Run 220: Transformer_24h_B2_H4_K32_FF128_D0.2_LR0.0005_BS128
# ======================================
# Val_TSS=0.4821 | Test_TSS=0.3577 | PR_AUC=0.6062 | Precision=0.4427 | F1=0.5686
#
# ======================================
# Run 221: Transformer_24h_B2_H4_K32_FF128_D0.3_LR0.001_BS64
# ======================================
# Val_TSS=0.4643 | Test_TSS=0.4270 | PR_AUC=0.5844 | Precision=0.4857 | F1=0.6028
#
# ======================================
# Run 222: Transformer_24h_B2_H4_K32_FF128_D0.3_LR0.001_BS128
# ======================================
# Val_TSS=0.4826 | Test_TSS=0.3711 | PR_AUC=0.6018 | Precision=0.4479 | F1=0.5753
#
# ======================================
# Run 223: Transformer_24h_B2_H4_K32_FF128_D0.3_LR0.0005_BS64
# ======================================
# Val_TSS=0.4871 | Test_TSS=0.3590 | PR_AUC=0.6001 | Precision=0.4266 | F1=0.5723
#
# ======================================
# Run 224: Transformer_24h_B2_H4_K32_FF128_D0.3_LR0.0005_BS128
# ======================================
# Val_TSS=0.4772 | Test_TSS=0.3409 | PR_AUC=0.6189 | Precision=0.4148 | F1=0.5655
#
# ======================================
# BEST CONFIGURATIONS BY VALIDATION TSS
# Official selection rule
# ======================================
#                                          Model  Threshold  Val_TSS  Test_TSS  \
# 0     BiLSTM_24h_U64_Dense32_D0.3_LR0.001_BS64      0.599   0.6151    0.4806
# 1       LSTM_24h_U64_Dense64_D0.3_LR0.001_BS64      0.578   0.6052    0.4364
# 2      LSTM_24h_U64_Dense64_D0.3_LR0.0005_BS64      0.593   0.6047    0.4626
# 3   BiLSTM_24h_U128_Dense64_D0.3_LR0.001_BS128      0.570   0.5982    0.4148
# 4         DLSTM_24h_MA3_U128_D0.2_LR0.001_BS64      0.573   0.5962    0.4434
# 5         DLSTM_24h_MA5_U128_D0.2_LR0.001_BS64      0.582   0.5962    0.4376
# 6    BiLSTM_24h_U128_Dense64_D0.2_LR0.001_BS64      0.632   0.5957    0.4485
# 7     LSTM_24h_U128_Dense64_D0.2_LR0.0005_BS64      0.666   0.5947    0.4380
# 8     LSTM_24h_U64_Dense64_D0.2_LR0.0005_BS128      0.566   0.5947    0.4277
# 9     BiLSTM_24h_U64_Dense64_D0.3_LR0.001_BS64      0.565   0.5928    0.4328
# 10    LSTM_24h_U128_Dense64_D0.3_LR0.0005_BS64      0.610   0.5918    0.4200
# 11       DLSTM_24h_MA5_U128_D0.2_LR0.001_BS128      0.563   0.5893    0.4632
# 12    LSTM_24h_U128_Dense64_D0.3_LR0.001_BS128      0.629   0.5883    0.4334
# 13     LSTM_24h_U128_Dense32_D0.2_LR0.001_BS64      0.620   0.5878    0.4462
# 14     LSTM_24h_U128_Dense64_D0.3_LR0.001_BS64      0.527   0.5863    0.4131
#
#        HSS  ROC_AUC  PR_AUC  Recall  Precision      F1  ...  Epochs_Used  \
# 0   0.4297   0.8086  0.6902  0.7664     0.5395  0.6332  ...           25
# 1   0.3693   0.8160  0.6767  0.8037     0.4886  0.6078  ...           18
# 2   0.4032   0.8175  0.6819  0.7850     0.5153  0.6222  ...           25
# 3   0.3495   0.8122  0.6900  0.7944     0.4775  0.5965  ...           20
# 4   0.3795   0.8052  0.6730  0.7944     0.4971  0.6115  ...           17
# 5   0.3679   0.8131  0.6812  0.8131     0.4860  0.6084  ...           21
# 6   0.4029   0.8003  0.6810  0.7383     0.5267  0.6148  ...           17
# 7   0.3972   0.8096  0.6757  0.7196     0.5274  0.6087  ...           21
# 8   0.3525   0.8163  0.6820  0.8318     0.4734  0.6034  ...           25
# 9   0.3738   0.8172  0.6970  0.7757     0.4970  0.6058  ...           20
# 10  0.3711   0.8059  0.6655  0.7383     0.5032  0.5985  ...           25
# 11  0.3920   0.8107  0.6745  0.8224     0.5000  0.6219  ...           25
# 12  0.3830   0.8118  0.6783  0.7477     0.5096  0.6061  ...           18
# 13  0.4066   0.8083  0.6763  0.7196     0.5347  0.6135  ...           18
# 14  0.3427   0.8063  0.6680  0.8131     0.4703  0.5959  ...           18
#
#     LSTM_Units  Dense_Units  Dropout Learning_Rate  MA_Window  \
# 0         64.0         32.0      0.3        0.0010        NaN
# 1         64.0         64.0      0.3        0.0010        NaN
# 2         64.0         64.0      0.3        0.0005        NaN
# 3        128.0         64.0      0.3        0.0010        NaN
# 4        128.0          NaN      0.2        0.0010        3.0
# 5        128.0          NaN      0.2        0.0010        5.0
# 6        128.0         64.0      0.2        0.0010        NaN
# 7        128.0         64.0      0.2        0.0005        NaN
# 8         64.0         64.0      0.2        0.0005        NaN
# 9         64.0         64.0      0.3        0.0010        NaN
# 10       128.0         64.0      0.3        0.0005        NaN
# 11       128.0          NaN      0.2        0.0010        5.0
# 12       128.0         64.0      0.3        0.0010        NaN
# 13       128.0         32.0      0.2        0.0010        NaN
# 14       128.0         64.0      0.3        0.0010        NaN
#
#     Transformer_Blocks  Transformer_Heads  Transformer_Key_Dim  \
# 0                  NaN                NaN                  NaN
# 1                  NaN                NaN                  NaN
# 2                  NaN                NaN                  NaN
# 3                  NaN                NaN                  NaN
# 4                  NaN                NaN                  NaN
# 5                  NaN                NaN                  NaN
# 6                  NaN                NaN                  NaN
# 7                  NaN                NaN                  NaN
# 8                  NaN                NaN                  NaN
# 9                  NaN                NaN                  NaN
# 10                 NaN                NaN                  NaN
# 11                 NaN                NaN                  NaN
# 12                 NaN                NaN                  NaN
# 13                 NaN                NaN                  NaN
# 14                 NaN                NaN                  NaN
#
#     Transformer_FF_Dim
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
#
# [15 rows x 26 columns]
# ======================================
# AUDIT ONLY: TOP 15 BY TEST TSS
# Do NOT use this for model selection
# ======================================
#                                           Model  Threshold  Val_TSS  Test_TSS  \
# 0     BiLSTM_24h_U64_Dense32_D0.2_LR0.0005_BS64      0.651   0.5848    0.4859
# 1       LSTM_24h_U64_Dense32_D0.3_LR0.001_BS128      0.594   0.5625    0.4825
# 2      BiLSTM_24h_U64_Dense32_D0.3_LR0.001_BS64      0.599   0.6151    0.4806
# 3          DLSTM_24h_MA5_U128_D0.3_LR0.001_BS64      0.571   0.5804    0.4779
# 4      LSTM_24h_U128_Dense64_D0.2_LR0.001_BS128      0.657   0.5615    0.4766
# 5    BiLSTM_24h_U128_Dense64_D0.3_LR0.0005_BS64      0.595   0.5858    0.4743
# 6         DLSTM_24h_MA5_U128_D0.3_LR0.0005_BS64      0.609   0.5412    0.4738
# 7       LSTM_24h_U64_Dense32_D0.3_LR0.0005_BS64      0.577   0.5561    0.4714
# 8       LSTM_24h_U64_Dense32_D0.2_LR0.0005_BS64      0.582   0.5590    0.4690
# 9    BiLSTM_24h_U64_Dense64_D0.3_LR0.0005_BS128      0.593   0.5650    0.4685
# 10   BiLSTM_24h_U128_Dense64_D0.2_LR0.0005_BS64      0.608   0.5610    0.4679
# 11   BiLSTM_24h_U64_Dense64_D0.2_LR0.0005_BS128      0.604   0.5660    0.4661
# 12        DLSTM_24h_MA5_U128_D0.2_LR0.001_BS128      0.563   0.5893    0.4632
# 13  BiLSTM_24h_U128_Dense32_D0.3_LR0.0005_BS128      0.610   0.5556    0.4632
# 14    BiLSTM_24h_U128_Dense32_D0.3_LR0.001_BS64      0.601   0.5645    0.4632
#
#        HSS  ROC_AUC  PR_AUC  Recall  Precision      F1  ...  Epochs_Used  \
# 0   0.4324   0.8155  0.6980  0.7757     0.5390  0.6360  ...           25
# 1   0.4157   0.8222  0.6991  0.8131     0.5179  0.6327  ...           25
# 2   0.4297   0.8086  0.6902  0.7664     0.5395  0.6332  ...           25
# 3   0.4017   0.8188  0.6845  0.8411     0.5028  0.6294  ...           22
# 4   0.4251   0.8158  0.6878  0.7664     0.5359  0.6308  ...           15
# 5   0.4068   0.8193  0.6983  0.8131     0.5118  0.6282  ...           20
# 6   0.3974   0.8112  0.6716  0.8411     0.5000  0.6272  ...           23
# 7   0.4007   0.8162  0.6900  0.8224     0.5057  0.6263  ...           25
# 8   0.4042   0.8170  0.6903  0.8037     0.5119  0.6255  ...           25
# 9   0.3947   0.8206  0.7074  0.8318     0.5000  0.6246  ...           25
# 10  0.4059   0.8186  0.7022  0.7944     0.5152  0.6250  ...           17
# 11  0.3980   0.8179  0.7089  0.8131     0.5058  0.6237  ...           25
# 12  0.3920   0.8107  0.6745  0.8224     0.5000  0.6219  ...           25
# 13  0.3920   0.8204  0.7020  0.8224     0.5000  0.6219  ...           22
# 14  0.3920   0.8249  0.7048  0.8224     0.5000  0.6219  ...           12
#
#     LSTM_Units  Dense_Units  Dropout Learning_Rate  MA_Window  \
# 0         64.0         32.0      0.2        0.0005        NaN
# 1         64.0         32.0      0.3        0.0010        NaN
# 2         64.0         32.0      0.3        0.0010        NaN
# 3        128.0          NaN      0.3        0.0010        5.0
# 4        128.0         64.0      0.2        0.0010        NaN
# 5        128.0         64.0      0.3        0.0005        NaN
# 6        128.0          NaN      0.3        0.0005        5.0
# 7         64.0         32.0      0.3        0.0005        NaN
# 8         64.0         32.0      0.2        0.0005        NaN
# 9         64.0         64.0      0.3        0.0005        NaN
# 10       128.0         64.0      0.2        0.0005        NaN
# 11        64.0         64.0      0.2        0.0005        NaN
# 12       128.0          NaN      0.2        0.0010        5.0
# 13       128.0         32.0      0.3        0.0005        NaN
# 14       128.0         32.0      0.3        0.0010        NaN
#
#     Transformer_Blocks  Transformer_Heads  Transformer_Key_Dim  \
# 0                  NaN                NaN                  NaN
# 1                  NaN                NaN                  NaN
# 2                  NaN                NaN                  NaN
# 3                  NaN                NaN                  NaN
# 4                  NaN                NaN                  NaN
# 5                  NaN                NaN                  NaN
# 6                  NaN                NaN                  NaN
# 7                  NaN                NaN                  NaN
# 8                  NaN                NaN                  NaN
# 9                  NaN                NaN                  NaN
# 10                 NaN                NaN                  NaN
# 11                 NaN                NaN                  NaN
# 12                 NaN                NaN                  NaN
# 13                 NaN                NaN                  NaN
# 14                 NaN                NaN                  NaN
#
#     Transformer_FF_Dim
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
#
# [15 rows x 26 columns]
# Saved tuning outputs to: /content/drive/MyDrive/AR_Stratified/Journal_Revision_24h_CLEAN_TRANSFORMER/24h_all_models_hyperparameter_tuning
# Best validation-selected model: BiLSTM_24h_U64_Dense32_D0.3_LR0.001_BS64
#
# Official best validation-selected result:
#                                       Model  Threshold  Val_TSS  Test_TSS  \
# 0  BiLSTM_24h_U64_Dense32_D0.3_LR0.001_BS64      0.599   0.6151    0.4806
#
#       HSS  ROC_AUC  PR_AUC  Recall  Precision      F1  ...  Epochs_Used  \
# 0  0.4297   0.8086  0.6902  0.7664     0.5395  0.6332  ...           25
#
#    LSTM_Units  Dense_Units  Dropout Learning_Rate  MA_Window  \
# 0          64           32      0.3         0.001        NaN
#
#    Transformer_Blocks  Transformer_Heads  Transformer_Key_Dim  \
# 0                 NaN                NaN                  NaN
#
#    Transformer_FF_Dim
# 0                 NaN
#
# [1 rows x 26 columns]

# %%
# ============================================================
# MCNEMAR TEST FOR 24H TUNED MODELS
# Compares official best validation-selected model
# against best validation-selected model from each family.
# ============================================================

import os
import numpy as np
import pandas as pd
from scipy.stats import chi2

# -----------------------------
# McNemar helper
# -----------------------------
def mcnemar_test(y_true, pred_a, pred_b):
    """
    pred_a = official best model predictions
    pred_b = comparator model predictions
    """

    correct_a = (pred_a == y_true)
    correct_b = (pred_b == y_true)

    # b: A correct, B wrong
    b = np.sum(correct_a & ~correct_b)

    # c: A wrong, B correct
    c = np.sum(~correct_a & correct_b)

    n = b + c

    if n == 0:
        chi2_stat = 0.0
        p_value = 1.0
    else:
        # continuity-corrected McNemar chi-square
        chi2_stat = ((abs(b - c) - 1) ** 2) / n
        p_value = chi2.sf(chi2_stat, df=1)

    return {
        "b": int(b),
        "c": int(c),
        "n": int(n),
        "chi2": float(chi2_stat),
        "p_value": float(p_value)
    }


# -----------------------------
# Pick official best model
# -----------------------------
official_best_row = tuning_by_val.iloc[0]
official_best_model = official_best_row["Model"]

official_best_pred = prob_store[official_best_model]["y_pred"]
y_true = np.array(y_test_seq).astype(int)

print("Official best tuned model:", official_best_model)


# -----------------------------
# Pick best validation-selected model per family
# -----------------------------
best_family_rows = (
    tuning_by_val
    .sort_values("Val_TSS", ascending=False)
    .groupby("Family", as_index=False)
    .first()
)

display(best_family_rows[[
    "Family", "Model", "Val_TSS", "Test_TSS",
    "ROC_AUC", "PR_AUC", "Recall", "Precision", "F1"
]].round(4))


# -----------------------------
# Run McNemar comparisons
# -----------------------------
mcnemar_rows = []

for _, row in best_family_rows.iterrows():
    comparator_model = row["Model"]
    comparator_family = row["Family"]

    if comparator_model == official_best_model:
        continue

    comparator_pred = prob_store[comparator_model]["y_pred"]

    result = mcnemar_test(
        y_true=y_true,
        pred_a=official_best_pred,
        pred_b=comparator_pred
    )

    result.update({
        "Comparison": f"Tuned Best BiLSTM vs Best Tuned {comparator_family}",
        "Official_Best_Model": official_best_model,
        "Comparator_Model": comparator_model,
        "Comparator_Family": comparator_family,
        "Interpretation": (
            "Significant difference"
            if result["p_value"] < 0.05
            else "No significant difference"
        )
    })

    mcnemar_rows.append(result)


mcnemar_tuned_df = pd.DataFrame(mcnemar_rows)

# Reorder columns
mcnemar_tuned_df = mcnemar_tuned_df[[
    "Comparison",
    "Official_Best_Model",
    "Comparator_Model",
    "Comparator_Family",
    "b", "c", "n", "chi2", "p_value", "Interpretation"
]]

display(mcnemar_tuned_df.round(6))

# Save
mcnemar_tuned_df.to_csv(
    os.path.join(TUNE_OUT_DIR, "MCNEMAR_24H_TUNED_MODEL_COMPARISONS.csv"),
    index=False
)

print("Saved tuned McNemar table to:", TUNE_OUT_DIR)
# Out:
# Official best tuned model: BiLSTM_24h_U64_Dense32_D0.3_LR0.001_BS64
#         Family                                              Model  Val_TSS  \
# 0       BiLSTM           BiLSTM_24h_U64_Dense32_D0.3_LR0.001_BS64   0.6151
# 1        DLSTM               DLSTM_24h_MA3_U128_D0.2_LR0.001_BS64   0.5962
# 2         LSTM             LSTM_24h_U64_Dense64_D0.3_LR0.001_BS64   0.6052
# 3  Transformer  Transformer_24h_B2_H2_K32_FF128_D0.2_LR0.001_BS64   0.5422
#
#    Test_TSS  ROC_AUC  PR_AUC  Recall  Precision      F1
# 0    0.4806   0.8086  0.6902  0.7664     0.5395  0.6332
# 1    0.4434   0.8052  0.6730  0.7944     0.4971  0.6115
# 2    0.4364   0.8160  0.6767  0.8037     0.4886  0.6078
# 3    0.3325   0.7611  0.6256  0.7570     0.4378  0.5548
#                                     Comparison  \
# 0        Tuned Best BiLSTM vs Best Tuned DLSTM
# 1         Tuned Best BiLSTM vs Best Tuned LSTM
# 2  Tuned Best BiLSTM vs Best Tuned Transformer
#
#                         Official_Best_Model  \
# 0  BiLSTM_24h_U64_Dense32_D0.3_LR0.001_BS64
# 1  BiLSTM_24h_U64_Dense32_D0.3_LR0.001_BS64
# 2  BiLSTM_24h_U64_Dense32_D0.3_LR0.001_BS64
#
#                                     Comparator_Model Comparator_Family   b  \
# 0               DLSTM_24h_MA3_U128_D0.2_LR0.001_BS64             DLSTM  23
# 1             LSTM_24h_U64_Dense64_D0.3_LR0.001_BS64              LSTM  26
# 2  Transformer_24h_B2_H2_K32_FF128_D0.2_LR0.001_BS64       Transformer  51
#
#     c   n       chi2   p_value          Interpretation
# 0  10  33   4.363636  0.036714  Significant difference
# 1  10  36   6.250000  0.012419  Significant difference
# 2  16  67  17.253731  0.000033  Significant difference
# Saved tuned McNemar table to: /content/drive/MyDrive/AR_Stratified/Journal_Revision_24h_CLEAN_TRANSFORMER/24h_all_models_hyperparameter_tuning

# %%
# ============================================================
# BOOTSTRAP CI FOR OFFICIAL TUNED 24H BEST MODEL
# ============================================================

import os
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix

def compute_tss_from_predictions(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
    tn, fp, fn, tp = cm.ravel()

    recall = tp / (tp + fn + 1e-9)
    fpr = fp / (fp + tn + 1e-9)

    return float(recall - fpr)


# Official best validation-selected model
official_best_model = tuning_by_val.iloc[0]["Model"]
official_best_pred = prob_store[official_best_model]["y_pred"]

y_true = np.array(y_test_seq).astype(int)
y_pred = np.array(official_best_pred).astype(int)

BOOT_N = 2000
rng = np.random.default_rng(42)

boot_tss = []

for _ in range(BOOT_N):
    idx = rng.choice(len(y_true), size=len(y_true), replace=True)

    # Skip invalid bootstrap samples with only one class
    if len(np.unique(y_true[idx])) < 2:
        continue

    boot_tss.append(
        compute_tss_from_predictions(
            y_true[idx],
            y_pred[idx]
        )
    )

boot_tss = np.array(boot_tss)

bootstrap_24h_tuned_ci = {
    "model": official_best_model,
    "mean": float(np.mean(boot_tss)),
    "ci_low": float(np.percentile(boot_tss, 2.5)),
    "ci_high": float(np.percentile(boot_tss, 97.5)),
    "n_boot_valid": int(len(boot_tss))
}

print("Official tuned 24h model:", official_best_model)
print("Bootstrap TSS CI:", bootstrap_24h_tuned_ci)

# Save outputs
pd.DataFrame([bootstrap_24h_tuned_ci]).to_csv(
    os.path.join(TUNE_OUT_DIR, "BOOTSTRAP_24H_TUNED_BILSTM_TSS_CI.csv"),
    index=False
)

np.save(
    os.path.join(TUNE_OUT_DIR, "BOOTSTRAP_24H_TUNED_BILSTM_TSS_SCORES.npy"),
    boot_tss
)

print("Saved bootstrap CI to:", TUNE_OUT_DIR)
# Out:
# Official tuned 24h model: BiLSTM_24h_U64_Dense32_D0.3_LR0.001_BS64
# Bootstrap TSS CI: {'model': 'BiLSTM_24h_U64_Dense32_D0.3_LR0.001_BS64', 'mean': 0.48090434535426635, 'ci_low': 0.38185717573917305, 'ci_high': 0.5780781251383921, 'n_boot_valid': 2000}
# Saved bootstrap CI to: /content/drive/MyDrive/AR_Stratified/Journal_Revision_24h_CLEAN_TRANSFORMER/24h_all_models_hyperparameter_tuning

# %% [markdown]
# # Diagnostic_Test

# %%
import numpy as np
import pandas as pd

print("\n==============================")
print("AVAILABLE NUMPY ARRAYS")
print("==============================")

for name, obj in list(globals().items()):
    if isinstance(obj, np.ndarray):
        print(name, obj.shape, obj.dtype)

print("\n==============================")
print("AVAILABLE DATAFRAMES")
print("==============================")

for name, obj in list(globals().items()):
    if isinstance(obj, pd.DataFrame):
        cols = list(obj.columns)
        time_cols = [
            c for c in cols
            if "time" in c.lower() or "date" in c.lower() or "t_rec" in c.lower()
        ]
        label_cols = [
            c for c in cols
            if "label" in c.lower() or "target" in c.lower() or "mx" in c.lower()
        ]
        print(f"\n{name}: shape={obj.shape}")
        print("Possible time columns:", time_cols[:10])
        print("Possible label columns:", label_cols[:10])
        print("First columns:", cols[:15])
# Out:
# ==============================
# AVAILABLE NUMPY ARRAYS
# ==============================
# X_seq (2342, 4, 21) float32
# y_seq (2342,) int64
# t_seq (2342,) datetime64[ns]
# ar_seq (2342,) int64
# order (2342,) int64
# X_train_seq (1639, 4, 21) float32
# y_train_seq (1639,) int64
# X_val_seq (351, 4, 21) float32
# y_val_seq (351,) int64
# X_test_seq (352, 4, 21) float32
# y_test_seq (352,) int64
# t_train (1639,) datetime64[ns]
# t_val (351,) datetime64[ns]
# t_test (352,) datetime64[ns]
# X_train_scaled (1639, 4, 21) float32
# X_val_scaled (351, 4, 21) float32
# X_test_scaled (352, 4, 21) float32
# val_prob_lstm (351,) float32
# test_prob_lstm (352,) float32
# y_pred_lstm (352,) int64
# val_prob_bilstm (351,) float32
# test_prob_bilstm (352,) float32
# y_pred_bilstm (352,) int64
# val_prob_transformer (351,) float32
# test_prob_transformer (352,) float32
# y_pred_transformer (352,) int64
# trend_train (1639, 4, 21) float32
# res_train (1639, 4, 21) float32
# trend_val (351, 4, 21) float32
# res_val (351, 4, 21) float32
# trend_test (352, 4, 21) float32
# res_test (352, 4, 21) float32
# X_train_dlstm (1639, 4, 42) float32
# X_val_dlstm (351, 4, 42) float32
# X_test_dlstm (352, 4, 42) float32
# val_prob_dlstm (351,) float32
# test_prob_dlstm (352,) float32
# y_pred_dlstm (352,) int64
# val_prob_simple (351,) float32
# test_prob_simple (352,) float32
# y_pred_simple (352,) int64
# val_prob_weighted (351,) float32
# test_prob_weighted (352,) float32
# y_pred_weighted (352,) int64
# y_pred_best_weighted (352,) int64
# X_meta_val (351, 3) float32
# X_meta_test (352, 3) float32
# val_prob_stack (351,) float64
# test_prob_stack (352,) float64
# y_pred_stack (352,) int64
# arr (352,) int64
# best_pred (352,) int64
# best_boot_scores (2000,) float64
# baseline_pred (352,) int64
# X_train_input (1639, 4, 21) float32
# X_val_input (351, 4, 21) float32
# X_test_input (352, 4, 21) float32
# official_best_pred (352,) int64
# y_true (352,) int64
# comparator_pred (352,) int64
# y_pred (352,) int64
# boot_tss (2000,) float64
# idx (352,) int64
#
# ==============================
# AVAILABLE DATAFRAMES
# ==============================
#
# df: shape=(5493, 26)
# Possible time columns: ['T_REC_dt', 'time_since_last_flare_hours_24h']
# Possible label columns: ['label_MX_1d']
# First columns: ['T_REC_dt', 'year', 'NOAA_AR', 'MEANGBZ', 'MEANGAM', 'MEANGBT', 'MEANGBH', 'MEANJZD', 'TOTUSJZ', 'MEANALP', 'MEANJZH', 'ABSNJZH', 'SAVNCPP', 'MEANSHR', 'SHRGT45']
#
# weighted_df: shape=(10, 14)
# Possible time columns: []
# Possible label columns: []
# First columns: ['Model', 'Threshold', 'Val_TSS', 'Test_TSS', 'HSS', 'ROC_AUC', 'PR_AUC', 'Recall', 'Precision', 'F1', 'TN', 'FP', 'FN', 'TP']
#
# final_24h_df: shape=(7, 14)
# Possible time columns: []
# Possible label columns: []
# First columns: ['Model', 'Threshold', 'Val_TSS', 'Test_TSS', 'HSS', 'ROC_AUC', 'PR_AUC', 'Recall', 'Precision', 'F1', 'TN', 'FP', 'FN', 'TP']
#
# mcnemar_df: shape=(6, 7)
# Possible time columns: []
# Possible label columns: []
# First columns: ['Comparison', 'Best_Model', 'b', 'c', 'n', 'chi2', 'p_value']
#
# tuning_all_df: shape=(224, 26)
# Possible time columns: []
# Possible label columns: []
# First columns: ['Model', 'Threshold', 'Val_TSS', 'Test_TSS', 'HSS', 'ROC_AUC', 'PR_AUC', 'Recall', 'Precision', 'F1', 'TN', 'FP', 'FN', 'TP', 'Family']
#
# tuning_by_val: shape=(224, 26)
# Possible time columns: []
# Possible label columns: []
# First columns: ['Model', 'Threshold', 'Val_TSS', 'Test_TSS', 'HSS', 'ROC_AUC', 'PR_AUC', 'Recall', 'Precision', 'F1', 'TN', 'FP', 'FN', 'TP', 'Family']
#
# tuning_by_test: shape=(224, 26)
# Possible time columns: []
# Possible label columns: []
# First columns: ['Model', 'Threshold', 'Val_TSS', 'Test_TSS', 'HSS', 'ROC_AUC', 'PR_AUC', 'Recall', 'Precision', 'F1', 'TN', 'FP', 'FN', 'TP', 'Family']
#
# best_family_rows: shape=(4, 26)
# Possible time columns: []
# Possible label columns: []
# First columns: ['Family', 'Model', 'Threshold', 'Val_TSS', 'Test_TSS', 'HSS', 'ROC_AUC', 'PR_AUC', 'Recall', 'Precision', 'F1', 'TN', 'FP', 'FN', 'TP']
#
# mcnemar_tuned_df: shape=(3, 10)
# Possible time columns: []
# Possible label columns: []
# First columns: ['Comparison', 'Official_Best_Model', 'Comparator_Model', 'Comparator_Family', 'b', 'c', 'n', 'chi2', 'p_value', 'Interpretation']

# %%
# ============================================================
# BLOCKED TEMPORAL CV HELPERS — RUN THIS FIRST
# ============================================================

import os, random
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (
    confusion_matrix, roc_auc_score, average_precision_score,
    precision_score, recall_score, f1_score
)

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, optimizers

SEED = 42
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)


def compute_tss_hss(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred, labels=[0, 1]).ravel()
    pod = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    far = fp / (fp + tn) if (fp + tn) > 0 else 0.0
    tss = pod - far

    denom = ((tp + fn) * (fn + tn) + (tp + fp) * (fp + tn))
    hss = (2 * ((tp * tn) - (fn * fp)) / denom) if denom > 0 else 0.0

    return tss, hss, tn, fp, fn, tp


def best_threshold_by_val_tss(y_val, p_val, grid=None):
    if grid is None:
        grid = np.linspace(0.01, 0.99, 99)

    best_thr, best_tss = 0.5, -999.0

    for thr in grid:
        pred = (p_val >= thr).astype(int)
        tss, *_ = compute_tss_hss(y_val, pred)

        if tss > best_tss:
            best_tss = tss
            best_thr = float(thr)

    return best_thr, best_tss


def evaluate_probs(y_true, p, threshold):
    pred = (p >= threshold).astype(int)
    tss, hss, tn, fp, fn, tp = compute_tss_hss(y_true, pred)

    return {
        "TSS": tss,
        "HSS": hss,
        "ROC_AUC": roc_auc_score(y_true, p) if len(np.unique(y_true)) == 2 else np.nan,
        "PR_AUC": average_precision_score(y_true, p),
        "Recall": recall_score(y_true, pred, zero_division=0),
        "Precision": precision_score(y_true, pred, zero_division=0),
        "F1": f1_score(y_true, pred, zero_division=0),
        "TN": tn,
        "FP": fp,
        "FN": fn,
        "TP": tp,
        "Threshold": threshold,
        "N": len(y_true),
        "Positives": int(np.sum(y_true)),
        "Prevalence": float(np.mean(y_true)),
    }


def scale_3d_train_only(X_train, X_val, X_test):
    n_steps, n_feat = X_train.shape[1], X_train.shape[2]

    scaler = StandardScaler()
    scaler.fit(X_train.reshape(-1, n_feat))

    def transform(X):
        return scaler.transform(X.reshape(-1, n_feat)).reshape(X.shape[0], n_steps, n_feat)

    return transform(X_train), transform(X_val), transform(X_test), scaler


def class_weight_dict(y_train):
    classes = np.array([0, 1])
    weights = compute_class_weight(
        class_weight="balanced",
        classes=classes,
        y=y_train.astype(int)
    )
    return {0: float(weights[0]), 1: float(weights[1])}


def sort_by_time(X, y, times):
    times = pd.to_datetime(times)
    order = np.argsort(times.values)
    return X[order], y[order], times.values[order]


def make_blocked_temporal_folds(n, fold_specs=None):
    # Train earlier block -> validate next block -> test later block
    if fold_specs is None:
        fold_specs = [
            (0.55, 0.70, 0.80),
            (0.65, 0.80, 0.90),
            (0.75, 0.90, 1.00),
        ]

    folds = []

    for i, (tr_end_f, val_end_f, test_end_f) in enumerate(fold_specs, start=1):
        tr_end = int(round(n * tr_end_f))
        val_end = int(round(n * val_end_f))
        test_end = int(round(n * test_end_f))

        idx_train = np.arange(0, tr_end)
        idx_val = np.arange(tr_end, val_end)
        idx_test = np.arange(val_end, test_end)

        folds.append((f"Fold_{i}", idx_train, idx_val, idx_test))

    return folds


def summarise_fold_results(df):
    metric_cols = ["TSS", "HSS", "ROC_AUC", "PR_AUC", "Recall", "Precision", "F1"]
    summary = []

    for m in metric_cols:
        summary.append({
            "Metric": m,
            "Mean": df[m].mean(),
            "SD": df[m].std(ddof=1),
            "Min": df[m].min(),
            "Max": df[m].max(),
            "Mean ± SD": f"{df[m].mean():.3f} ± {df[m].std(ddof=1):.3f}",
        })

    return pd.DataFrame(summary)


def build_lstm(input_shape, units=64, dense_units=32, dropout=0.2, lr=1e-3):
    inp = layers.Input(shape=input_shape)
    x = layers.LSTM(units)(inp)
    x = layers.Dropout(dropout)(x)
    x = layers.Dense(dense_units, activation="relu")(x)
    out = layers.Dense(1, activation="sigmoid")(x)

    model = models.Model(inp, out)
    model.compile(
        optimizer=optimizers.Adam(learning_rate=lr),
        loss="binary_crossentropy",
        metrics=[tf.keras.metrics.AUC(name="auc")]
    )
    return model


def build_bilstm(input_shape, units=64, dense_units=32, dropout=0.3, lr=1e-3):
    inp = layers.Input(shape=input_shape)
    x = layers.Bidirectional(layers.LSTM(units))(inp)
    x = layers.Dropout(dropout)(x)
    x = layers.Dense(dense_units, activation="relu")(x)
    out = layers.Dense(1, activation="sigmoid")(x)

    model = models.Model(inp, out)
    model.compile(
        optimizer=optimizers.Adam(learning_rate=lr),
        loss="binary_crossentropy",
        metrics=[tf.keras.metrics.AUC(name="auc")]
    )
    return model


def moving_average_decompose(X, kernel=3):
    """
    Return concatenated [trend, residual] channels for DLSTM-style stability checks.
    Uses edge padding and same-length output.
    """
    assert kernel <= X.shape[1], "Moving-average kernel cannot exceed sequence length."

    pad_left = kernel // 2
    pad_right = kernel - 1 - pad_left
    weights = np.ones(kernel, dtype=float) / kernel

    trend = np.empty_like(X, dtype=float)

    for i in range(X.shape[0]):
        for f in range(X.shape[2]):
            padded = np.pad(X[i, :, f], (pad_left, pad_right), mode="edge")
            trend[i, :, f] = np.convolve(padded, weights, mode="valid")

    residual = X - trend
    return np.concatenate([trend, residual], axis=-1)


def build_dlstmlike(input_shape, units=64, dense_units=32, dropout=0.2, lr=1e-3):
    # Input is already [trend, residual] after moving_average_decompose.
    return build_lstm(
        input_shape,
        units=units,
        dense_units=dense_units,
        dropout=dropout,
        lr=lr
    )


def run_blocked_temporal_cv(
    X_all,
    y_all,
    time_all,
    model_builder,
    model_name="Model",
    preprocess_fn=None,
    epochs=20,
    batch_size=128,
    patience=4,
    fold_specs=None,
    verbose=0,
):
    X_all, y_all, time_all = sort_by_time(
        np.asarray(X_all),
        np.asarray(y_all).astype(int),
        time_all
    )

    folds = make_blocked_temporal_folds(len(y_all), fold_specs=fold_specs)
    rows = []

    for fold_name, idx_tr, idx_val, idx_te in folds:
        print(f"\n=== {model_name} | {fold_name} ===")

        Xtr, ytr = X_all[idx_tr], y_all[idx_tr]
        Xva, yva = X_all[idx_val], y_all[idx_val]
        Xte, yte = X_all[idx_te], y_all[idx_te]

        print(
            f"Train={len(ytr)} pos={int(ytr.sum())} | "
            f"Val={len(yva)} pos={int(yva.sum())} | "
            f"Test={len(yte)} pos={int(yte.sum())}"
        )

        Xtr_s, Xva_s, Xte_s, scaler = scale_3d_train_only(Xtr, Xva, Xte)

        if preprocess_fn is not None:
            Xtr_s = preprocess_fn(Xtr_s)
            Xva_s = preprocess_fn(Xva_s)
            Xte_s = preprocess_fn(Xte_s)

        cw = class_weight_dict(ytr)

        tf.keras.backend.clear_session()
        model = model_builder(Xtr_s.shape[1:])

        es = callbacks.EarlyStopping(
            monitor="val_auc",
            mode="max",
            patience=patience,
            restore_best_weights=True
        )

        model.fit(
            Xtr_s,
            ytr,
            validation_data=(Xva_s, yva),
            epochs=epochs,
            batch_size=batch_size,
            class_weight=cw,
            callbacks=[es],
            verbose=verbose
        )

        p_val = model.predict(Xva_s, verbose=0).ravel()
        thr, val_tss = best_threshold_by_val_tss(yva, p_val)

        p_test = model.predict(Xte_s, verbose=0).ravel()
        metrics = evaluate_probs(yte, p_test, threshold=thr)

        metrics.update({
            "Model": model_name,
            "Fold": fold_name,
            "Val_TSS_Selected": val_tss,
            "Train_N": len(ytr),
            "Val_N": len(yva),
            "Test_N": len(yte),
            "Train_Pos": int(ytr.sum()),
            "Val_Pos": int(yva.sum()),
            "Test_Pos": int(yte.sum()),
            "Train_Start": str(pd.to_datetime(time_all[idx_tr[0]])),
            "Train_End": str(pd.to_datetime(time_all[idx_tr[-1]])),
            "Val_Start": str(pd.to_datetime(time_all[idx_val[0]])),
            "Val_End": str(pd.to_datetime(time_all[idx_val[-1]])),
            "Test_Start": str(pd.to_datetime(time_all[idx_te[0]])),
            "Test_End": str(pd.to_datetime(time_all[idx_te[-1]])),
        })

        rows.append(metrics)

        print({
            k: round(metrics[k], 4) if isinstance(metrics[k], float) else metrics[k]
            for k in ["TSS", "PR_AUC", "Recall", "Precision", "F1", "Threshold"]
        })

    fold_df = pd.DataFrame(rows)
    summary_df = summarise_fold_results(fold_df)

    return fold_df, summary_df


print("✅ Blocked temporal CV helpers loaded. You can now run fold_3h, summary_3h.")
# Out:
# ✅ Blocked temporal CV helpers loaded. You can now run fold_3h, summary_3h.

# %%
# ============================================================
# 24H: Tuned BiLSTM blocked temporal CV
# Uses official 4-step, 21-feature sequence set
# ============================================================

X_all = X_seq
y_all = y_seq
time_all = t_seq

print("X_all:", X_all.shape)
print("y_all:", y_all.shape, "positives:", y_all.sum(), "prevalence:", y_all.mean())
print("time_all:", time_all.shape)
print("date range:", pd.to_datetime(time_all).min(), "to", pd.to_datetime(time_all).max())

fold_24h, summary_24h = run_blocked_temporal_cv(
    X_all=X_all,
    y_all=y_all,
    time_all=time_all,
    model_builder=lambda input_shape: build_bilstm(
        input_shape,
        units=64,
        dense_units=32,
        dropout=0.3,
        lr=1e-3
    ),
    model_name="24h_Tuned_BiLSTM_BlockedTemporalCV",
    preprocess_fn=None,
    epochs=25,
    batch_size=64,
    patience=5,
    verbose=1
)

display(fold_24h)
display(summary_24h)
# Out:
# X_all: (2342, 4, 21)
# y_all: (2342,) positives: 344 prevalence: 0.14688300597779674
# time_all: (2342,)
# date range: 2010-05-08 12:00:00 to 2025-04-18 12:00:00
#
# === 24h_Tuned_BiLSTM_BlockedTemporalCV | Fold_1 ===
# Train=1288 pos=130 | Val=351 pos=44 | Test=235 pos=44
# Epoch 1/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - auc: 0.7885 - loss: 0.5788 - val_auc: 0.7031 - val_loss: 0.6985
# Epoch 2/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8612 - loss: 0.4650 - val_auc: 0.7108 - val_loss: 0.7096
# Epoch 3/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8736 - loss: 0.4320 - val_auc: 0.7178 - val_loss: 0.6835
# Epoch 4/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8867 - loss: 0.4072 - val_auc: 0.7279 - val_loss: 0.6886
# Epoch 5/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.8945 - loss: 0.3930 - val_auc: 0.7379 - val_loss: 0.6868
# Epoch 6/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9018 - loss: 0.3839 - val_auc: 0.7503 - val_loss: 0.6895
# Epoch 7/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9094 - loss: 0.3722 - val_auc: 0.7577 - val_loss: 0.6884
# Epoch 8/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9169 - loss: 0.3546 - val_auc: 0.7618 - val_loss: 0.6903
# Epoch 9/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.9256 - loss: 0.3403 - val_auc: 0.7634 - val_loss: 0.6818
# Epoch 10/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9250 - loss: 0.3367 - val_auc: 0.7650 - val_loss: 0.6712
# Epoch 11/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9306 - loss: 0.3270 - val_auc: 0.7670 - val_loss: 0.6967
# Epoch 12/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9364 - loss: 0.3159 - val_auc: 0.7649 - val_loss: 0.6856
# Epoch 13/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.9429 - loss: 0.3016 - val_auc: 0.7596 - val_loss: 0.6629
# Epoch 14/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - auc: 0.9433 - loss: 0.2957 - val_auc: 0.7599 - val_loss: 0.6886
# Epoch 15/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - auc: 0.9452 - loss: 0.2907 - val_auc: 0.7507 - val_loss: 0.6691
# Epoch 16/25
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - auc: 0.9512 - loss: 0.2768 - val_auc: 0.7446 - val_loss: 0.6778
# {'TSS': np.float64(0.4097), 'PR_AUC': np.float64(0.4936), 'Recall': 0.75, 'Precision': 0.3367, 'F1': 0.4648, 'Threshold': 0.68}
#
# === 24h_Tuned_BiLSTM_BlockedTemporalCV | Fold_2 ===
# Train=1522 pos=163 | Val=352 pos=55 | Test=234 pos=74
# Epoch 1/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - auc: 0.7876 - loss: 0.5757 - val_auc: 0.7626 - val_loss: 0.6988
# Epoch 2/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8400 - loss: 0.4882 - val_auc: 0.7663 - val_loss: 0.7307
# Epoch 3/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8531 - loss: 0.4649 - val_auc: 0.7751 - val_loss: 0.6993
# Epoch 4/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8679 - loss: 0.4468 - val_auc: 0.7823 - val_loss: 0.6998
# Epoch 5/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8834 - loss: 0.4259 - val_auc: 0.7912 - val_loss: 0.6951
# Epoch 6/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.8933 - loss: 0.4091 - val_auc: 0.7955 - val_loss: 0.6976
# Epoch 7/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.8973 - loss: 0.3994 - val_auc: 0.7943 - val_loss: 0.6910
# Epoch 8/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9034 - loss: 0.3893 - val_auc: 0.7990 - val_loss: 0.6943
# Epoch 9/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - auc: 0.9066 - loss: 0.3835 - val_auc: 0.7967 - val_loss: 0.6820
# Epoch 10/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - auc: 0.9118 - loss: 0.3697 - val_auc: 0.7989 - val_loss: 0.6858
# Epoch 11/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - auc: 0.9146 - loss: 0.3648 - val_auc: 0.7986 - val_loss: 0.6799
# Epoch 12/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - auc: 0.9191 - loss: 0.3554 - val_auc: 0.7975 - val_loss: 0.6654
# Epoch 13/25
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - auc: 0.9267 - loss: 0.3387 - val_auc: 0.7968 - val_loss: 0.6580
# {'TSS': np.float64(0.6409), 'PR_AUC': np.float64(0.8221), 'Recall': 0.8784, 'Precision': 0.6311, 'F1': 0.7345, 'Threshold': 0.65}
#
# === 24h_Tuned_BiLSTM_BlockedTemporalCV | Fold_3 ===
# Train=1756 pos=188 | Val=352 pos=104 | Test=234 pos=52
# Epoch 1/25
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - auc: 0.7384 - loss: 0.6105 - val_auc: 0.8025 - val_loss: 0.6192
# Epoch 2/25
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.8262 - loss: 0.5020 - val_auc: 0.8157 - val_loss: 0.6369
# Epoch 3/25
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - auc: 0.8434 - loss: 0.4765 - val_auc: 0.8301 - val_loss: 0.6136
# Epoch 4/25
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - auc: 0.8565 - loss: 0.4572 - val_auc: 0.8434 - val_loss: 0.5952
# Epoch 5/25
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - auc: 0.8687 - loss: 0.4426 - val_auc: 0.8522 - val_loss: 0.5746
# Epoch 6/25
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - auc: 0.8798 - loss: 0.4281 - val_auc: 0.8580 - val_loss: 0.5668
# Epoch 7/25
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - auc: 0.8897 - loss: 0.4155 - val_auc: 0.8592 - val_loss: 0.5536
# Epoch 8/25
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - auc: 0.8976 - loss: 0.4020 - val_auc: 0.8602 - val_loss: 0.5553
# Epoch 9/25
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - auc: 0.9040 - loss: 0.3890 - val_auc: 0.8599 - val_loss: 0.5489
# Epoch 10/25
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - auc: 0.9109 - loss: 0.3761 - val_auc: 0.8579 - val_loss: 0.5420
# Epoch 11/25
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9092 - loss: 0.3779 - val_auc: 0.8568 - val_loss: 0.5599
# Epoch 12/25
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9203 - loss: 0.3557 - val_auc: 0.8562 - val_loss: 0.5477
# Epoch 13/25
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9205 - loss: 0.3551 - val_auc: 0.8563 - val_loss: 0.5436
# {'TSS': np.float64(0.3242), 'PR_AUC': np.float64(0.4958), 'Recall': 0.5385, 'Precision': 0.4179, 'F1': 0.4706, 'Threshold': 0.73}
#         TSS       HSS   ROC_AUC    PR_AUC    Recall  Precision        F1   TN  \
# 0  0.409686  0.278267  0.785221  0.493649  0.750000   0.336735  0.464789  126
# 1  0.640878  0.579812  0.892736  0.822063  0.878378   0.631068  0.734463  122
# 2  0.324176  0.293898  0.757502  0.495798  0.538462   0.417910  0.470588  143
#
#    FP  FN  ...  Test_N  Train_Pos  Val_Pos  Test_Pos          Train_Start  \
# 0  65  11  ...     235        130       44        44  2010-05-08 12:00:00
# 1  38   9  ...     234        163       55        74  2010-05-08 12:00:00
# 2  39  24  ...     234        188      104        52  2010-05-08 12:00:00
#
#              Train_End            Val_Start              Val_End  \
# 0  2021-11-27 12:00:00  2021-11-28 12:00:00  2023-02-22 12:00:00
# 1  2022-10-04 12:00:00  2022-10-05 12:00:00  2023-10-05 12:00:00
# 2  2023-06-27 12:00:00  2023-06-28 12:00:00  2024-07-07 12:00:00
#
#             Test_Start             Test_End
# 0  2023-02-24 12:00:00  2023-10-05 12:00:00
# 1  2023-10-05 12:00:00  2024-07-07 12:00:00
# 2  2024-07-08 12:00:00  2025-04-18 12:00:00
#
# [3 rows x 30 columns]
#       Metric      Mean        SD       Min       Max      Mean ± SD
# 0        TSS  0.458247  0.163841  0.324176  0.640878  0.458 ± 0.164
# 1        HSS  0.383992  0.169765  0.278267  0.579812  0.384 ± 0.170
# 2    ROC_AUC  0.811820  0.071433  0.757502  0.892736  0.812 ± 0.071
# 3     PR_AUC  0.603837  0.188993  0.493649  0.822063  0.604 ± 0.189
# 4     Recall  0.722280  0.171645  0.538462  0.878378  0.722 ± 0.172
# 5  Precision  0.461904  0.152018  0.336735  0.631068  0.462 ± 0.152
# 6         F1  0.556613  0.154050  0.464789  0.734463  0.557 ± 0.154

# %%
from pathlib import Path

OUT_DIR = Path("/content/drive/MyDrive/ASR_MAJOR_REVISION_TEMPORAL_CV")
OUT_DIR.mkdir(parents=True, exist_ok=True)

fold_24h.to_csv(OUT_DIR / "fold_24h_blocked_temporal_cv.csv", index=False)
summary_24h.to_csv(OUT_DIR / "summary_24h_blocked_temporal_cv.csv", index=False)

print("Saved 24h CV results to:", OUT_DIR)
# Out:
# Saved 24h CV results to: /content/drive/MyDrive/ASR_MAJOR_REVISION_TEMPORAL_CV

# %%
import numpy as np

for name in ["X_seq", "y_seq", "t_seq", "X_train_seq", "y_train_seq", "X_test_seq", "y_test_seq"]:
    if name in globals():
        obj = globals()[name]
        print(name, obj.shape, obj.dtype)
# Out:
# X_seq (2342, 4, 21) float32
# y_seq (2342,) int64
# t_seq (2342,) datetime64[ns]
# X_train_seq (1639, 4, 21) float32
# y_train_seq (1639,) int64
# X_test_seq (352, 4, 21) float32
# y_test_seq (352,) int64

# %% [markdown]
# ---

# %%
# ============================================================
# 24H STATIC BASELINES: LR, MLP, LINEAR SVM
# Must be run inside the 24h notebook after X_seq/y_seq/t_seq exist
# ============================================================

import os
import random
from pathlib import Path

import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.metrics import (
    confusion_matrix,
    roc_auc_score,
    average_precision_score,
    precision_score,
    recall_score,
    f1_score
)
from sklearn.utils.class_weight import compute_class_weight

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, optimizers

HORIZON = "24h"
TEMPORAL_HEADLINE_TSS = 0.481

OUT_DIR = Path("/content/drive/MyDrive/ASR_MAJOR_REVISION_STATIC_BASELINES")
OUT_DIR.mkdir(parents=True, exist_ok=True)

SEED = 42
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# Direct assignment from 24h notebook arrays
X_full = X_seq
y_full = y_seq
time_full = t_seq

print("Using direct 24h arrays:")
print("X_full:", X_full.shape)
print("y_full:", y_full.shape, "positives:", int(y_full.sum()), "prevalence:", float(y_full.mean()))
print("time_full:", time_full.shape)

# Static representation: last time step only
X_static = np.asarray(X_full)[:, -1, :].astype("float32")
y_static = np.asarray(y_full).astype("int64")
time_static = pd.to_datetime(time_full)

order = np.argsort(time_static.values)
X_static = X_static[order]
y_static = y_static[order]
time_static = time_static.values[order]

print("X_static:", X_static.shape)
print("Date range:", pd.to_datetime(time_static).min(), "to", pd.to_datetime(time_static).max())

# Chronological 70/15/15 split
n = len(y_static)
n_train = int(round(0.70 * n))
n_val = int(round(0.15 * n))
n_test = n - n_train - n_val

idx_train = np.arange(0, n_train)
idx_val = np.arange(n_train, n_train + n_val)
idx_test = np.arange(n_train + n_val, n)

X_train, y_train = X_static[idx_train], y_static[idx_train]
X_val, y_val = X_static[idx_val], y_static[idx_val]
X_test, y_test = X_static[idx_test], y_static[idx_test]

print("\nSplit summary")
print("Train:", X_train.shape, "pos:", int(y_train.sum()))
print("Val:  ", X_val.shape, "pos:", int(y_val.sum()))
print("Test: ", X_test.shape, "pos:", int(y_test.sum()))

# Scale using train only
scaler = StandardScaler()
X_train_s = scaler.fit_transform(X_train)
X_val_s = scaler.transform(X_val)
X_test_s = scaler.transform(X_test)

def compute_tss_hss(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred, labels=[0, 1]).ravel()
    pod = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    far = fp / (fp + tn) if (fp + tn) > 0 else 0.0
    tss = pod - far
    denom = ((tp + fn) * (fn + tn) + (tp + fp) * (fp + tn))
    hss = (2 * ((tp * tn) - (fn * fp)) / denom) if denom > 0 else 0.0
    return tss, hss, tn, fp, fn, tp

def best_threshold_by_val_tss(y_val, val_scores):
    thresholds = np.unique(np.quantile(val_scores, np.linspace(0.01, 0.99, 99)))
    best_thr = thresholds[0]
    best_tss = -999.0
    for thr in thresholds:
        pred = (val_scores >= thr).astype(int)
        tss, *_ = compute_tss_hss(y_val, pred)
        if tss > best_tss:
            best_tss = tss
            best_thr = float(thr)
    return best_thr, best_tss

def evaluate_scores(y_true, scores, threshold):
    pred = (scores >= threshold).astype(int)
    tss, hss, tn, fp, fn, tp = compute_tss_hss(y_true, pred)
    return {
        "TSS": tss,
        "HSS": hss,
        "ROC_AUC": roc_auc_score(y_true, scores),
        "PR_AUC": average_precision_score(y_true, scores),
        "Recall": recall_score(y_true, pred, zero_division=0),
        "Precision": precision_score(y_true, pred, zero_division=0),
        "F1": f1_score(y_true, pred, zero_division=0),
        "TN": tn,
        "FP": fp,
        "FN": fn,
        "TP": tp,
        "Threshold": threshold,
    }

def class_weight_dict(y_train):
    classes = np.array([0, 1])
    weights = compute_class_weight(
        class_weight="balanced",
        classes=classes,
        y=y_train.astype(int)
    )
    return {0: float(weights[0]), 1: float(weights[1])}

results = []

# Logistic Regression
lr_model = LogisticRegression(
    max_iter=3000,
    class_weight="balanced",
    solver="lbfgs",
    random_state=SEED
)
lr_model.fit(X_train_s, y_train)
val_scores_lr = lr_model.predict_proba(X_val_s)[:, 1]
test_scores_lr = lr_model.predict_proba(X_test_s)[:, 1]
thr_lr, val_tss_lr = best_threshold_by_val_tss(y_val, val_scores_lr)
metrics_lr = evaluate_scores(y_test, test_scores_lr, thr_lr)
metrics_lr.update({
    "Horizon": HORIZON,
    "Model": "Static Logistic Regression",
    "Input": "Last time step only",
    "Val_TSS_Selected": val_tss_lr,
    "Temporal_Headline_TSS": TEMPORAL_HEADLINE_TSS,
    "TSS_Gain_Temporal_minus_Static": TEMPORAL_HEADLINE_TSS - metrics_lr["TSS"],
})
results.append(metrics_lr)

# MLP
def build_static_mlp(input_dim, lr=1e-3, dropout=0.3):
    inp = layers.Input(shape=(input_dim,))
    x = layers.Dense(64, activation="relu")(inp)
    x = layers.Dropout(dropout)(x)
    x = layers.Dense(32, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    out = layers.Dense(1, activation="sigmoid")(x)
    model = models.Model(inp, out)
    model.compile(
        optimizer=optimizers.Adam(learning_rate=lr),
        loss="binary_crossentropy",
        metrics=[tf.keras.metrics.AUC(name="auc")]
    )
    return model

tf.keras.backend.clear_session()
mlp_model = build_static_mlp(X_train_s.shape[1], lr=1e-3, dropout=0.3)

es = callbacks.EarlyStopping(
    monitor="val_auc",
    mode="max",
    patience=6,
    restore_best_weights=True
)

history_mlp = mlp_model.fit(
    X_train_s,
    y_train,
    validation_data=(X_val_s, y_val),
    epochs=40,
    batch_size=64,
    class_weight=class_weight_dict(y_train),
    callbacks=[es],
    verbose=1
)

val_scores_mlp = mlp_model.predict(X_val_s, verbose=0).ravel()
test_scores_mlp = mlp_model.predict(X_test_s, verbose=0).ravel()
thr_mlp, val_tss_mlp = best_threshold_by_val_tss(y_val, val_scores_mlp)
metrics_mlp = evaluate_scores(y_test, test_scores_mlp, thr_mlp)
metrics_mlp.update({
    "Horizon": HORIZON,
    "Model": "Static MLP",
    "Input": "Last time step only",
    "Val_TSS_Selected": val_tss_mlp,
    "Temporal_Headline_TSS": TEMPORAL_HEADLINE_TSS,
    "TSS_Gain_Temporal_minus_Static": TEMPORAL_HEADLINE_TSS - metrics_mlp["TSS"],
})
results.append(metrics_mlp)

# Linear SVM
svm_model = SGDClassifier(
    loss="hinge",
    penalty="l2",
    alpha=1e-4,
    max_iter=3000,
    tol=1e-3,
    class_weight="balanced",
    random_state=SEED
)
svm_model.fit(X_train_s, y_train)
val_scores_svm = svm_model.decision_function(X_val_s)
test_scores_svm = svm_model.decision_function(X_test_s)
thr_svm, val_tss_svm = best_threshold_by_val_tss(y_val, val_scores_svm)
metrics_svm = evaluate_scores(y_test, test_scores_svm, thr_svm)
metrics_svm.update({
    "Horizon": HORIZON,
    "Model": "Static Linear SVM",
    "Input": "Last time step only",
    "Val_TSS_Selected": val_tss_svm,
    "Temporal_Headline_TSS": TEMPORAL_HEADLINE_TSS,
    "TSS_Gain_Temporal_minus_Static": TEMPORAL_HEADLINE_TSS - metrics_svm["TSS"],
})
results.append(metrics_svm)

static_baseline_df = pd.DataFrame(results)

cols = [
    "Horizon", "Model", "Input", "Threshold", "Val_TSS_Selected",
    "TSS", "HSS", "ROC_AUC", "PR_AUC", "Recall", "Precision", "F1",
    "TN", "FP", "FN", "TP",
    "Temporal_Headline_TSS", "TSS_Gain_Temporal_minus_Static"
]

static_baseline_df = static_baseline_df[cols]

display(static_baseline_df)

out_file = OUT_DIR / "static_baselines_24h.csv"
static_baseline_df.to_csv(out_file, index=False)

print("Saved to:", out_file)
# Out:
# Using direct 24h arrays:
# X_full: (2342, 4, 21)
# y_full: (2342,) positives: 344 prevalence: 0.14688300597779674
# time_full: (2342,)
# X_static: (2342, 21)
# Date range: 2010-05-08 12:00:00 to 2025-04-18 12:00:00
#
# Split summary
# Train: (1639, 21) pos: 174
# Val:   (351, 21) pos: 63
# Test:  (352, 21) pos: 107
# Epoch 1/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - auc: 0.7374 - loss: 0.6102 - val_auc: 0.8447 - val_loss: 0.6734
# Epoch 2/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8491 - loss: 0.5005 - val_auc: 0.8453 - val_loss: 0.6332
# Epoch 3/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8728 - loss: 0.4574 - val_auc: 0.8469 - val_loss: 0.6096
# Epoch 4/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8629 - loss: 0.4637 - val_auc: 0.8516 - val_loss: 0.6170
# Epoch 5/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8656 - loss: 0.4604 - val_auc: 0.8533 - val_loss: 0.5965
# Epoch 6/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8788 - loss: 0.4343 - val_auc: 0.8522 - val_loss: 0.5876
# Epoch 7/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8809 - loss: 0.4282 - val_auc: 0.8536 - val_loss: 0.5833
# Epoch 8/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8895 - loss: 0.4209 - val_auc: 0.8539 - val_loss: 0.5821
# Epoch 9/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8899 - loss: 0.4150 - val_auc: 0.8550 - val_loss: 0.5724
# Epoch 10/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8866 - loss: 0.4263 - val_auc: 0.8544 - val_loss: 0.5829
# Epoch 11/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8837 - loss: 0.4257 - val_auc: 0.8547 - val_loss: 0.5833
# Epoch 12/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8883 - loss: 0.4149 - val_auc: 0.8549 - val_loss: 0.5767
# Epoch 13/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9034 - loss: 0.3909 - val_auc: 0.8545 - val_loss: 0.5732
# Epoch 14/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8894 - loss: 0.4144 - val_auc: 0.8555 - val_loss: 0.5584
# Epoch 15/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8914 - loss: 0.4072 - val_auc: 0.8547 - val_loss: 0.5779
# Epoch 16/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.8906 - loss: 0.4110 - val_auc: 0.8550 - val_loss: 0.5700
# Epoch 17/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8960 - loss: 0.4017 - val_auc: 0.8534 - val_loss: 0.5653
# Epoch 18/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9007 - loss: 0.3936 - val_auc: 0.8546 - val_loss: 0.5656
# Epoch 19/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.8910 - loss: 0.4088 - val_auc: 0.8547 - val_loss: 0.5702
# Epoch 20/40
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - auc: 0.9057 - loss: 0.3836 - val_auc: 0.8543 - val_loss: 0.5719
#   Horizon                       Model                Input  Threshold  \
# 0     24h  Static Logistic Regression  Last time step only   0.570083
# 1     24h                  Static MLP  Last time step only   0.440520
# 2     24h           Static Linear SVM  Last time step only  -0.053352
#
#    Val_TSS_Selected       TSS       HSS   ROC_AUC    PR_AUC    Recall  \
# 0          0.569444  0.479039  0.400064  0.795651  0.638264  0.850467
# 1          0.563492  0.457562  0.362223  0.809308  0.665158  0.906542
# 2          0.559028  0.399771  0.315815  0.784055  0.644480  0.869159
#
#    Precision        F1   TN   FP  FN  TP  Temporal_Headline_TSS  \
# 0   0.500000  0.629758  154   91  16  91                  0.481
# 1   0.468599  0.617834  135  110  10  97                  0.481
# 2   0.447115  0.590476  130  115  14  93                  0.481
#
#    TSS_Gain_Temporal_minus_Static
# 0                        0.001961
# 1                        0.023438
# 2                        0.081229
# Saved to: /content/drive/MyDrive/ASR_MAJOR_REVISION_STATIC_BASELINES/static_baselines_24h.csv

# %% [markdown]
# ---

# %%
# ============================================================
# ROUND 1A: 24H FEATURE-GROUP ABLATION
# SHARP only vs GOES-history only vs SHARP + GOES history
# Model: tuned-style BiLSTM
# Paste inside 24h notebook AFTER X_seq, y_seq, t_seq exist
# ============================================================

import os
import random
from pathlib import Path

import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    confusion_matrix,
    roc_auc_score,
    average_precision_score,
    precision_score,
    recall_score,
    f1_score
)
from sklearn.utils.class_weight import compute_class_weight

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, optimizers


# ------------------------------------------------------------
# 0. Settings
# ------------------------------------------------------------
HORIZON = "24h"
MODEL_NAME = "BiLSTM"
OUT_DIR = Path("/content/drive/MyDrive/ASR_MAJOR_REVISION_FEATURE_ABLATION")
OUT_DIR.mkdir(parents=True, exist_ok=True)

SEED = 42
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)


# ------------------------------------------------------------
# 1. Use 24h sequence arrays directly
# ------------------------------------------------------------
X_full = X_seq
y_full = y_seq.astype("int64")
time_full = pd.to_datetime(t_seq)

print("Using 24h arrays:")
print("X_full:", X_full.shape)
print("y_full:", y_full.shape, "positives:", int(y_full.sum()), "prevalence:", float(y_full.mean()))
print("time_full:", time_full.shape)
print("date range:", time_full.min(), "to", time_full.max())

assert X_full.shape[-1] == 21, "Expected 24h input to have 21 features: 16 SHARP + 5 GOES-history."


# ------------------------------------------------------------
# 2. Feature groups
# ------------------------------------------------------------
SHARP_16 = [
    "MEANGBZ", "MEANGAM", "MEANGBT", "MEANGBH",
    "MEANJZD", "TOTUSJZ", "MEANALP", "MEANJZH",
    "ABSNJZH", "SAVNCPP", "MEANSHR", "SHRGT45",
    "R_VALUE", "USFLUX", "TOTPOT", "TOTUSJH"
]

GOES_5 = [
    "flare_count_past_24h",
    "time_since_last_flare_hours_24h",
    "max_peak_flux_past_24h",
    "mean_peak_flux_past_24h",
    "flare_activity_index_past_24h"
]

feature_groups = {
    "SHARP only": {
        "indices": list(range(0, 16)),
        "description": "16 SHARP magnetic parameters only",
        "feature_names": SHARP_16,
    },
    "GOES history only": {
        "indices": list(range(16, 21)),
        "description": "5 GOES-derived flare-history features only",
        "feature_names": GOES_5,
    },
    "SHARP + GOES history": {
        "indices": list(range(0, 21)),
        "description": "Full 24h feature set: 16 SHARP + 5 GOES-history",
        "feature_names": SHARP_16 + GOES_5,
    },
}

for k, v in feature_groups.items():
    print(f"{k}: {len(v['indices'])} features")


# ------------------------------------------------------------
# 3. Chronological sort and 70/15/15 split
# ------------------------------------------------------------
order = np.argsort(time_full.values)

X_full = X_full[order]
y_full = y_full[order]
time_full = time_full.values[order]

n = len(y_full)
n_train = int(round(0.70 * n))
n_val = int(round(0.15 * n))
n_test = n - n_train - n_val

idx_train = np.arange(0, n_train)
idx_val = np.arange(n_train, n_train + n_val)
idx_test = np.arange(n_train + n_val, n)

print("\nSplit summary:")
print("Train:", len(idx_train), "pos:", int(y_full[idx_train].sum()), pd.to_datetime(time_full[idx_train[0]]), "to", pd.to_datetime(time_full[idx_train[-1]]))
print("Val:  ", len(idx_val), "pos:", int(y_full[idx_val].sum()), pd.to_datetime(time_full[idx_val[0]]), "to", pd.to_datetime(time_full[idx_val[-1]]))
print("Test: ", len(idx_test), "pos:", int(y_full[idx_test].sum()), pd.to_datetime(time_full[idx_test[0]]), "to", pd.to_datetime(time_full[idx_test[-1]]))


# ------------------------------------------------------------
# 4. Metric helpers
# ------------------------------------------------------------
def compute_tss_hss(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred, labels=[0, 1]).ravel()

    pod = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    far = fp / (fp + tn) if (fp + tn) > 0 else 0.0
    tss = pod - far

    denom = ((tp + fn) * (fn + tn) + (tp + fp) * (fp + tn))
    hss = (2 * ((tp * tn) - (fn * fp)) / denom) if denom > 0 else 0.0

    return tss, hss, tn, fp, fn, tp


def best_threshold_by_val_tss(y_val, p_val, grid=None):
    if grid is None:
        grid = np.linspace(0.01, 0.99, 99)

    best_thr = 0.5
    best_tss = -999.0

    for thr in grid:
        pred = (p_val >= thr).astype(int)
        tss, *_ = compute_tss_hss(y_val, pred)

        if tss > best_tss:
            best_tss = tss
            best_thr = float(thr)

    return best_thr, best_tss


def evaluate_probs(y_true, p, threshold):
    pred = (p >= threshold).astype(int)
    tss, hss, tn, fp, fn, tp = compute_tss_hss(y_true, pred)

    return {
        "TSS": tss,
        "HSS": hss,
        "ROC_AUC": roc_auc_score(y_true, p) if len(np.unique(y_true)) == 2 else np.nan,
        "PR_AUC": average_precision_score(y_true, p),
        "Recall": recall_score(y_true, pred, zero_division=0),
        "Precision": precision_score(y_true, pred, zero_division=0),
        "F1": f1_score(y_true, pred, zero_division=0),
        "TN": tn,
        "FP": fp,
        "FN": fn,
        "TP": tp,
        "Threshold": threshold,
    }


def class_weight_dict(y_train):
    classes = np.array([0, 1])
    weights = compute_class_weight(
        class_weight="balanced",
        classes=classes,
        y=y_train.astype(int)
    )
    return {0: float(weights[0]), 1: float(weights[1])}


def scale_3d_train_only(X_train, X_val, X_test):
    n_steps, n_feat = X_train.shape[1], X_train.shape[2]

    scaler = StandardScaler()
    scaler.fit(X_train.reshape(-1, n_feat))

    def transform(X):
        return scaler.transform(X.reshape(-1, n_feat)).reshape(X.shape[0], n_steps, n_feat)

    return transform(X_train), transform(X_val), transform(X_test), scaler


# ------------------------------------------------------------
# 5. Model builder: tuned-style BiLSTM
# ------------------------------------------------------------
def build_bilstm(input_shape, units=64, dense_units=32, dropout=0.3, lr=1e-3):
    inp = layers.Input(shape=input_shape)

    x = layers.Bidirectional(layers.LSTM(units))(inp)
    x = layers.Dropout(dropout)(x)
    x = layers.Dense(dense_units, activation="relu")(x)

    out = layers.Dense(1, activation="sigmoid")(x)

    model = models.Model(inp, out)

    model.compile(
        optimizer=optimizers.Adam(learning_rate=lr),
        loss="binary_crossentropy",
        metrics=[tf.keras.metrics.AUC(name="auc")]
    )

    return model


# ------------------------------------------------------------
# 6. Run ablation
# ------------------------------------------------------------
ablation_rows = []

for feature_set_name, cfg in feature_groups.items():
    print("\n" + "=" * 70)
    print(f"24h feature ablation: {feature_set_name}")
    print("=" * 70)

    idx_features = cfg["indices"]

    X_group = X_full[:, :, idx_features].astype("float32")
    y_group = y_full.copy()

    X_train = X_group[idx_train]
    y_train = y_group[idx_train]

    X_val = X_group[idx_val]
    y_val = y_group[idx_val]

    X_test = X_group[idx_test]
    y_test = y_group[idx_test]

    X_train_s, X_val_s, X_test_s, scaler = scale_3d_train_only(X_train, X_val, X_test)

    print("X_train:", X_train_s.shape, "pos:", int(y_train.sum()))
    print("X_val:  ", X_val_s.shape, "pos:", int(y_val.sum()))
    print("X_test: ", X_test_s.shape, "pos:", int(y_test.sum()))

    tf.keras.backend.clear_session()

    model = build_bilstm(
        input_shape=X_train_s.shape[1:],
        units=64,
        dense_units=32,
        dropout=0.3,
        lr=1e-3
    )

    es = callbacks.EarlyStopping(
        monitor="val_auc",
        mode="max",
        patience=6,
        restore_best_weights=True
    )

    history = model.fit(
        X_train_s,
        y_train,
        validation_data=(X_val_s, y_val),
        epochs=35,
        batch_size=64,
        class_weight=class_weight_dict(y_train),
        callbacks=[es],
        verbose=1
    )

    # Save learning curve for each ablation group
    safe_name = feature_set_name.lower().replace(" ", "_").replace("+", "plus")
    history_df = pd.DataFrame(history.history)
    history_file = OUT_DIR / f"learning_curve_24h_ablation_{safe_name}.csv"
    history_df.to_csv(history_file, index=False)

    p_val = model.predict(X_val_s, verbose=0).ravel()
    p_test = model.predict(X_test_s, verbose=0).ravel()

    thr, val_tss = best_threshold_by_val_tss(y_val, p_val)
    metrics = evaluate_probs(y_test, p_test, threshold=thr)

    metrics.update({
        "Horizon": HORIZON,
        "Model": MODEL_NAME,
        "Feature_Set": feature_set_name,
        "Feature_Count": len(idx_features),
        "Feature_Description": cfg["description"],
        "Val_TSS_Selected": val_tss,
        "Train_N": len(y_train),
        "Val_N": len(y_val),
        "Test_N": len(y_test),
        "Train_Pos": int(y_train.sum()),
        "Val_Pos": int(y_val.sum()),
        "Test_Pos": int(y_test.sum()),
        "Learning_Curve_File": str(history_file),
    })

    ablation_rows.append(metrics)

    print({
        k: round(metrics[k], 4) if isinstance(metrics[k], float) else metrics[k]
        for k in ["Feature_Set", "Val_TSS_Selected", "TSS", "HSS", "ROC_AUC", "PR_AUC", "Recall", "Precision", "F1", "Threshold"]
    })


# ------------------------------------------------------------
# 7. Save final ablation table
# ------------------------------------------------------------
ablation_24h_df = pd.DataFrame(ablation_rows)

cols = [
    "Horizon",
    "Model",
    "Feature_Set",
    "Feature_Count",
    "Feature_Description",
    "Threshold",
    "Val_TSS_Selected",
    "TSS",
    "HSS",
    "ROC_AUC",
    "PR_AUC",
    "Recall",
    "Precision",
    "F1",
    "TN",
    "FP",
    "FN",
    "TP",
    "Train_N",
    "Val_N",
    "Test_N",
    "Train_Pos",
    "Val_Pos",
    "Test_Pos",
    "Learning_Curve_File",
]

ablation_24h_df = ablation_24h_df[cols]

display(ablation_24h_df)

out_file = OUT_DIR / "feature_ablation_24h.csv"
ablation_24h_df.to_csv(out_file, index=False)

print("\nSaved 24h feature ablation results to:", out_file)
# Out:
# Using 24h arrays:
# X_full: (2342, 4, 21)
# y_full: (2342,) positives: 344 prevalence: 0.14688300597779674
# time_full: (2342,)
# date range: 2010-05-08 12:00:00 to 2025-04-18 12:00:00
# SHARP only: 16 features
# GOES history only: 5 features
# SHARP + GOES history: 21 features
#
# Split summary:
# Train: 1639 pos: 174 2010-05-08 12:00:00 to 2023-02-22 12:00:00
# Val:   351 pos: 63 2023-02-24 12:00:00 to 2024-02-16 12:00:00
# Test:  352 pos: 107 2024-02-16 12:00:00 to 2025-04-18 12:00:00
#
# ======================================================================
# 24h feature ablation: SHARP only
# ======================================================================
# X_train: (1639, 4, 16) pos: 174
# X_val:   (351, 4, 16) pos: 63
# X_test:  (352, 4, 16) pos: 107
# Epoch 1/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 36ms/step - auc: 0.7399 - loss: 0.6058 - val_auc: 0.7688 - val_loss: 0.6898
# Epoch 2/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8129 - loss: 0.5213 - val_auc: 0.7677 - val_loss: 0.6859
# Epoch 3/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.8269 - loss: 0.4986 - val_auc: 0.7696 - val_loss: 0.6818
# Epoch 4/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8386 - loss: 0.4822 - val_auc: 0.7741 - val_loss: 0.6712
# Epoch 5/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8499 - loss: 0.4651 - val_auc: 0.7789 - val_loss: 0.6565
# Epoch 6/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8527 - loss: 0.4615 - val_auc: 0.7860 - val_loss: 0.6438
# Epoch 7/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8705 - loss: 0.4430 - val_auc: 0.7922 - val_loss: 0.6272
# Epoch 8/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8695 - loss: 0.4416 - val_auc: 0.7985 - val_loss: 0.6192
# Epoch 9/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8862 - loss: 0.4212 - val_auc: 0.7977 - val_loss: 0.5996
# Epoch 10/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - auc: 0.8916 - loss: 0.4088 - val_auc: 0.8043 - val_loss: 0.5959
# Epoch 11/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8994 - loss: 0.3998 - val_auc: 0.8054 - val_loss: 0.5782
# Epoch 12/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8985 - loss: 0.3965 - val_auc: 0.8099 - val_loss: 0.5755
# Epoch 13/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9043 - loss: 0.3867 - val_auc: 0.8139 - val_loss: 0.5703
# Epoch 14/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9070 - loss: 0.3794 - val_auc: 0.8067 - val_loss: 0.5695
# Epoch 15/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9090 - loss: 0.3746 - val_auc: 0.8137 - val_loss: 0.5705
# Epoch 16/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9088 - loss: 0.3762 - val_auc: 0.8161 - val_loss: 0.5600
# Epoch 17/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9154 - loss: 0.3655 - val_auc: 0.8134 - val_loss: 0.5497
# Epoch 18/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.9194 - loss: 0.3570 - val_auc: 0.8079 - val_loss: 0.5646
# Epoch 19/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9235 - loss: 0.3470 - val_auc: 0.8050 - val_loss: 0.5425
# Epoch 20/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9252 - loss: 0.3418 - val_auc: 0.8073 - val_loss: 0.5428
# Epoch 21/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9234 - loss: 0.3435 - val_auc: 0.8080 - val_loss: 0.5647
# Epoch 22/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9306 - loss: 0.3317 - val_auc: 0.8084 - val_loss: 0.5564
# {'Feature_Set': 'SHARP only', 'Val_TSS_Selected': np.float64(0.4965), 'TSS': np.float64(0.2641), 'HSS': np.float64(0.2323), 'ROC_AUC': np.float64(0.6934), 'PR_AUC': np.float64(0.5287), 'Recall': 0.6355, 'Precision': 0.4277, 'F1': 0.5113, 'Threshold': 0.59}
#
# ======================================================================
# 24h feature ablation: GOES history only
# ======================================================================
# X_train: (1639, 4, 5) pos: 174
# X_val:   (351, 4, 5) pos: 63
# X_test:  (352, 4, 5) pos: 107
# Epoch 1/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - auc: 0.7518 - loss: 0.6330 - val_auc: 0.7569 - val_loss: 0.6377
# Epoch 2/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8111 - loss: 0.5384 - val_auc: 0.7671 - val_loss: 0.6361
# Epoch 3/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8314 - loss: 0.5080 - val_auc: 0.7779 - val_loss: 0.6543
# Epoch 4/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8413 - loss: 0.4920 - val_auc: 0.7846 - val_loss: 0.6761
# Epoch 5/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8510 - loss: 0.4770 - val_auc: 0.7861 - val_loss: 0.6918
# Epoch 6/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8521 - loss: 0.4765 - val_auc: 0.7884 - val_loss: 0.7070
# Epoch 7/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8570 - loss: 0.4694 - val_auc: 0.7906 - val_loss: 0.7184
# Epoch 8/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.8566 - loss: 0.4681 - val_auc: 0.7918 - val_loss: 0.7231
# Epoch 9/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8587 - loss: 0.4645 - val_auc: 0.7933 - val_loss: 0.7350
# Epoch 10/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8589 - loss: 0.4629 - val_auc: 0.7923 - val_loss: 0.7393
# Epoch 11/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - auc: 0.8561 - loss: 0.4676 - val_auc: 0.7940 - val_loss: 0.7386
# Epoch 12/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.8604 - loss: 0.4597 - val_auc: 0.7935 - val_loss: 0.7405
# Epoch 13/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - auc: 0.8630 - loss: 0.4579 - val_auc: 0.7931 - val_loss: 0.7490
# Epoch 14/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - auc: 0.8626 - loss: 0.4548 - val_auc: 0.7913 - val_loss: 0.7481
# Epoch 15/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - auc: 0.8649 - loss: 0.4523 - val_auc: 0.7905 - val_loss: 0.7536
# Epoch 16/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - auc: 0.8682 - loss: 0.4474 - val_auc: 0.7873 - val_loss: 0.7497
# Epoch 17/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - auc: 0.8644 - loss: 0.4516 - val_auc: 0.7892 - val_loss: 0.7531
# {'Feature_Set': 'GOES history only', 'Val_TSS_Selected': np.float64(0.5273), 'TSS': np.float64(0.4672), 'HSS': np.float64(0.4177), 'ROC_AUC': np.float64(0.8166), 'PR_AUC': np.float64(0.7026), 'Recall': 0.757, 'Precision': 0.5329, 'F1': 0.6255, 'Threshold': 0.69}
#
# ======================================================================
# 24h feature ablation: SHARP + GOES history
# ======================================================================
# X_train: (1639, 4, 21) pos: 174
# X_val:   (351, 4, 21) pos: 63
# X_test:  (352, 4, 21) pos: 107
# Epoch 1/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - auc: 0.7353 - loss: 0.6203 - val_auc: 0.7754 - val_loss: 0.6358
# Epoch 2/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - auc: 0.8268 - loss: 0.5031 - val_auc: 0.7884 - val_loss: 0.6789
# Epoch 3/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - auc: 0.8424 - loss: 0.4790 - val_auc: 0.7992 - val_loss: 0.6694
# Epoch 4/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - auc: 0.8571 - loss: 0.4604 - val_auc: 0.8090 - val_loss: 0.6557
# Epoch 5/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - auc: 0.8701 - loss: 0.4391 - val_auc: 0.8188 - val_loss: 0.6398
# Epoch 6/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - auc: 0.8780 - loss: 0.4293 - val_auc: 0.8289 - val_loss: 0.6213
# Epoch 7/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - auc: 0.8910 - loss: 0.4126 - val_auc: 0.8344 - val_loss: 0.6087
# Epoch 8/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - auc: 0.9022 - loss: 0.3922 - val_auc: 0.8392 - val_loss: 0.5948
# Epoch 9/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - auc: 0.9023 - loss: 0.3908 - val_auc: 0.8394 - val_loss: 0.5960
# Epoch 10/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9121 - loss: 0.3718 - val_auc: 0.8407 - val_loss: 0.5710
# Epoch 11/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9144 - loss: 0.3663 - val_auc: 0.8410 - val_loss: 0.5646
# Epoch 12/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.9216 - loss: 0.3509 - val_auc: 0.8390 - val_loss: 0.5426
# Epoch 13/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9234 - loss: 0.3462 - val_auc: 0.8358 - val_loss: 0.5458
# Epoch 14/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9280 - loss: 0.3369 - val_auc: 0.8375 - val_loss: 0.5365
# Epoch 15/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9326 - loss: 0.3246 - val_auc: 0.8345 - val_loss: 0.5405
# Epoch 16/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.9356 - loss: 0.3171 - val_auc: 0.8318 - val_loss: 0.5276
# Epoch 17/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9409 - loss: 0.3057 - val_auc: 0.8266 - val_loss: 0.5149
# {'Feature_Set': 'SHARP + GOES history', 'Val_TSS_Selected': np.float64(0.567), 'TSS': np.float64(0.3869), 'HSS': np.float64(0.3121), 'ROC_AUC': np.float64(0.7922), 'PR_AUC': np.float64(0.6536), 'Recall': 0.8318, 'Precision': 0.4495, 'F1': 0.5836, 'Threshold': 0.51}
#   Horizon   Model           Feature_Set  Feature_Count  \
# 0     24h  BiLSTM            SHARP only             16
# 1     24h  BiLSTM     GOES history only              5
# 2     24h  BiLSTM  SHARP + GOES history             21
#
#                                Feature_Description  Threshold  \
# 0                16 SHARP magnetic parameters only       0.59
# 1       5 GOES-derived flare-history features only       0.69
# 2  Full 24h feature set: 16 SHARP + 5 GOES-history       0.51
#
#    Val_TSS_Selected       TSS       HSS   ROC_AUC  ...   FP  FN  TP  Train_N  \
# 0          0.496528  0.264085  0.232292  0.693382  ...   91  39  68     1639
# 1          0.527282  0.467213  0.417735  0.816632  ...   71  26  81     1639
# 2          0.566964  0.386878  0.312119  0.792218  ...  109  18  89     1639
#
#    Val_N  Test_N  Train_Pos  Val_Pos  Test_Pos  \
# 0    351     352        174       63       107
# 1    351     352        174       63       107
# 2    351     352        174       63       107
#
#                                  Learning_Curve_File
# 0  /content/drive/MyDrive/ASR_MAJOR_REVISION_FEAT...
# 1  /content/drive/MyDrive/ASR_MAJOR_REVISION_FEAT...
# 2  /content/drive/MyDrive/ASR_MAJOR_REVISION_FEAT...
#
# [3 rows x 25 columns]
# Saved 24h feature ablation results to: /content/drive/MyDrive/ASR_MAJOR_REVISION_FEATURE_ABLATION/feature_ablation_24h.csv

# %% [markdown]
# ---
#
#
#
# ---

# %%
from pathlib import Path
import pandas as pd
import numpy as np

OUT_DIR = Path("/content/drive/MyDrive/ASR_MAJOR_REVISION_FEATURE_ABLATION")

files = [
    OUT_DIR / "feature_ablation_3h.csv",
    OUT_DIR / "feature_ablation_24h.csv",
    OUT_DIR / "feature_ablation_72h.csv",
]

for f in files:
    print(f.name, f.exists())

ablation_all = pd.concat([pd.read_csv(f) for f in files], ignore_index=True)

display_cols = [
    "Horizon", "Model", "Feature_Set", "Feature_Count", "MA_Kernel",
    "Val_TSS_Selected", "TSS", "HSS", "ROC_AUC", "PR_AUC",
    "Recall", "Precision", "F1", "TN", "FP", "FN", "TP"
]

# Some 24h table may not have MA_Kernel; fill it
if "MA_Kernel" not in ablation_all.columns:
    ablation_all["MA_Kernel"] = np.nan

ablation_display = ablation_all[display_cols].copy()

num_cols = ablation_display.select_dtypes(include=[np.number]).columns
ablation_display[num_cols] = ablation_display[num_cols].round(3)

display(ablation_display)

ablation_display.to_csv(
    OUT_DIR / "combined_feature_ablation_table_manuscript_ready.csv",
    index=False
)

print("Saved:", OUT_DIR / "combined_feature_ablation_table_manuscript_ready.csv")
# Out:
# feature_ablation_3h.csv True
# feature_ablation_24h.csv True
# feature_ablation_72h.csv True
#   Horizon           Model              Feature_Set  Feature_Count  MA_Kernel  \
# 0      3h  DLSTM-like MA3               SHARP only             16        3.0
# 1      3h  DLSTM-like MA3        GOES history only              5        3.0
# 2      3h  DLSTM-like MA3     SHARP + GOES history             21        3.0
# 3     24h          BiLSTM               SHARP only             16        NaN
# 4     24h          BiLSTM        GOES history only              5        NaN
# 5     24h          BiLSTM     SHARP + GOES history             21        NaN
# 6     72h  DLSTM-like MA5               SHARP only             16        5.0
# 7     72h  DLSTM-like MA5     Delta/evolution only             16        5.0
# 8     72h  DLSTM-like MA5  SHARP + Delta/evolution             32        5.0
#
#    Val_TSS_Selected    TSS    HSS  ROC_AUC  PR_AUC  Recall  Precision     F1  \
# 0             0.630  0.611  0.021    0.897   0.066   0.895      0.016  0.031
# 1             0.677  0.684  0.111    0.870   0.182   0.739      0.065  0.119
# 2             0.706  0.711  0.051    0.931   0.165   0.843      0.031  0.061
# 3             0.497  0.264  0.232    0.693   0.529   0.636      0.428  0.511
# 4             0.527  0.467  0.418    0.817   0.703   0.757      0.533  0.625
# 5             0.567  0.387  0.312    0.792   0.654   0.832      0.449  0.584
# 6             0.562  0.581  0.267    0.869   0.384   0.906      0.247  0.388
# 7             0.559  0.449  0.280    0.830   0.331   0.651      0.275  0.386
# 8             0.583  0.567  0.309    0.858   0.376   0.812      0.281  0.417
#
#       TN     FP  FN   TP
# 0  43051  17138  32  274
# 1  56925   3264  80  226
# 2  52255   7934  48  258
# 3    154     91  39   68
# 4    174     71  26   81
# 5    136    109  18   89
# 6    855    411  14  135
# 7   1010    256  52   97
# 8    956    310  28  121
# Saved: /content/drive/MyDrive/ASR_MAJOR_REVISION_FEATURE_ABLATION/combined_feature_ablation_table_manuscript_ready.csv

# %%
from pathlib import Path
import pandas as pd
import numpy as np

OUT_DIR = Path("/content/drive/MyDrive/ASR_MAJOR_REVISION_FEATURE_ABLATION")

files = [
    OUT_DIR / "feature_ablation_3h.csv",
    OUT_DIR / "feature_ablation_24h.csv",
    OUT_DIR / "feature_ablation_72h.csv",
]

ablation_all = pd.concat([pd.read_csv(f) for f in files], ignore_index=True)

# Make sure MA_Kernel exists
if "MA_Kernel" not in ablation_all.columns:
    ablation_all["MA_Kernel"] = np.nan

# Clean display value
ablation_all["MA_Kernel_Display"] = ablation_all["MA_Kernel"].apply(
    lambda x: "N/A (BiLSTM)" if pd.isna(x) else str(int(x))
)

display_cols = [
    "Horizon",
    "Model",
    "Feature_Set",
    "Feature_Count",
    "MA_Kernel_Display",
    "Val_TSS_Selected",
    "TSS",
    "HSS",
    "ROC_AUC",
    "PR_AUC",
    "Recall",
    "Precision",
    "F1",
    "TN",
    "FP",
    "FN",
    "TP"
]

ablation_display = ablation_all[display_cols].copy()

ablation_display = ablation_display.rename(columns={
    "MA_Kernel_Display": "MA_Kernel",
    "ROC_AUC": "ROC-AUC",
    "PR_AUC": "PR-AUC",
    "Val_TSS_Selected": "Validation TSS"
})

num_cols = ablation_display.select_dtypes(include=[np.number]).columns
ablation_display[num_cols] = ablation_display[num_cols].round(3)

display(ablation_display)

out_file = OUT_DIR / "combined_feature_ablation_table_manuscript_ready.csv"
ablation_display.to_csv(out_file, index=False)

print("Saved:", out_file)
# Out:
#   Horizon           Model              Feature_Set  Feature_Count  \
# 0      3h  DLSTM-like MA3               SHARP only             16
# 1      3h  DLSTM-like MA3        GOES history only              5
# 2      3h  DLSTM-like MA3     SHARP + GOES history             21
# 3     24h          BiLSTM               SHARP only             16
# 4     24h          BiLSTM        GOES history only              5
# 5     24h          BiLSTM     SHARP + GOES history             21
# 6     72h  DLSTM-like MA5               SHARP only             16
# 7     72h  DLSTM-like MA5     Delta/evolution only             16
# 8     72h  DLSTM-like MA5  SHARP + Delta/evolution             32
#
#       MA_Kernel  Validation TSS    TSS    HSS  ROC-AUC  PR-AUC  Recall  \
# 0             3           0.630  0.611  0.021    0.897   0.066   0.895
# 1             3           0.677  0.684  0.111    0.870   0.182   0.739
# 2             3           0.706  0.711  0.051    0.931   0.165   0.843
# 3  N/A (BiLSTM)           0.497  0.264  0.232    0.693   0.529   0.636
# 4  N/A (BiLSTM)           0.527  0.467  0.418    0.817   0.703   0.757
# 5  N/A (BiLSTM)           0.567  0.387  0.312    0.792   0.654   0.832
# 6             5           0.562  0.581  0.267    0.869   0.384   0.906
# 7             5           0.559  0.449  0.280    0.830   0.331   0.651
# 8             5           0.583  0.567  0.309    0.858   0.376   0.812
#
#    Precision     F1     TN     FP  FN   TP
# 0      0.016  0.031  43051  17138  32  274
# 1      0.065  0.119  56925   3264  80  226
# 2      0.031  0.061  52255   7934  48  258
# 3      0.428  0.511    154     91  39   68
# 4      0.533  0.625    174     71  26   81
# 5      0.449  0.584    136    109  18   89
# 6      0.247  0.388    855    411  14  135
# 7      0.275  0.386   1010    256  52   97
# 8      0.281  0.417    956    310  28  121
# Saved: /content/drive/MyDrive/ASR_MAJOR_REVISION_FEATURE_ABLATION/combined_feature_ablation_table_manuscript_ready.csv

# %% [markdown]
# ---
#
#
#
# ---

# %%
# ============================================================
# ROUND 2 COMMON HELPERS: DLSTM MOVING-AVERAGE KERNEL SENSITIVITY
# Works for 3h, 24h, and 72h notebooks
# ============================================================

import os
import random
from pathlib import Path

import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    confusion_matrix,
    roc_auc_score,
    average_precision_score,
    precision_score,
    recall_score,
    f1_score
)
from sklearn.utils.class_weight import compute_class_weight

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, optimizers


# ------------------------------------------------------------
# 0. Reproducibility and output directory
# ------------------------------------------------------------
SEED = 42
os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

OUT_DIR = Path("/content/drive/MyDrive/ASR_MAJOR_REVISION_KERNEL_SENSITIVITY")
OUT_DIR.mkdir(parents=True, exist_ok=True)


# ------------------------------------------------------------
# 1. Metrics
# ------------------------------------------------------------
def compute_tss_hss(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred, labels=[0, 1]).ravel()

    pod = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    far = fp / (fp + tn) if (fp + tn) > 0 else 0.0
    tss = pod - far

    denom = ((tp + fn) * (fn + tn) + (tp + fp) * (fp + tn))
    hss = (2 * ((tp * tn) - (fn * fp)) / denom) if denom > 0 else 0.0

    return tss, hss, tn, fp, fn, tp


def best_threshold_by_val_tss(y_val, p_val, grid=None):
    if grid is None:
        grid = np.linspace(0.01, 0.99, 99)

    best_thr = 0.5
    best_tss = -999.0

    for thr in grid:
        pred = (p_val >= thr).astype(int)
        tss, *_ = compute_tss_hss(y_val, pred)

        if tss > best_tss:
            best_tss = tss
            best_thr = float(thr)

    return best_thr, best_tss


def evaluate_probs(y_true, p, threshold):
    pred = (p >= threshold).astype(int)

    tss, hss, tn, fp, fn, tp = compute_tss_hss(y_true, pred)

    return {
        "TSS": tss,
        "HSS": hss,
        "ROC_AUC": roc_auc_score(y_true, p) if len(np.unique(y_true)) == 2 else np.nan,
        "PR_AUC": average_precision_score(y_true, p),
        "Recall": recall_score(y_true, pred, zero_division=0),
        "Precision": precision_score(y_true, pred, zero_division=0),
        "F1": f1_score(y_true, pred, zero_division=0),
        "TN": tn,
        "FP": fp,
        "FN": fn,
        "TP": tp,
        "Threshold": threshold,
    }


def class_weight_dict(y_train):
    classes = np.array([0, 1])
    weights = compute_class_weight(
        class_weight="balanced",
        classes=classes,
        y=y_train.astype(int)
    )
    return {0: float(weights[0]), 1: float(weights[1])}


# ------------------------------------------------------------
# 2. Scaling and decomposition
# ------------------------------------------------------------
def scale_3d_train_only(X_train, X_val, X_test):
    n_steps, n_feat = X_train.shape[1], X_train.shape[2]

    scaler = StandardScaler()
    scaler.fit(X_train.reshape(-1, n_feat))

    def transform(X):
        return scaler.transform(X.reshape(-1, n_feat)).reshape(X.shape[0], n_steps, n_feat)

    return transform(X_train), transform(X_val), transform(X_test), scaler


def moving_average_decompose_fast(X, kernel=3):
    """
    Same-length moving-average decomposition.
    Returns concatenated [trend, residual] feature channels.
    """
    if kernel > X.shape[1]:
        raise ValueError(
            f"Kernel {kernel} cannot exceed sequence length {X.shape[1]}."
        )

    pad_left = kernel // 2
    pad_right = kernel - 1 - pad_left

    padded = np.pad(
        X,
        pad_width=((0, 0), (pad_left, pad_right), (0, 0)),
        mode="edge"
    )

    trend = np.zeros_like(X, dtype="float32")

    for k in range(kernel):
        trend += padded[:, k:k + X.shape[1], :]

    trend = trend / float(kernel)
    residual = X - trend

    return np.concatenate([trend, residual], axis=-1).astype("float32")


# ------------------------------------------------------------
# 3. DLSTM-like model
# ------------------------------------------------------------
def build_dlstmlike(input_shape, units=64, dense_units=32, dropout=0.2, lr=1e-3):
    inp = layers.Input(shape=input_shape)

    x = layers.LSTM(units)(inp)
    x = layers.Dropout(dropout)(x)
    x = layers.Dense(dense_units, activation="relu")(x)

    out = layers.Dense(1, activation="sigmoid")(x)

    model = models.Model(inp, out)

    model.compile(
        optimizer=optimizers.Adam(learning_rate=lr),
        loss="binary_crossentropy",
        metrics=[tf.keras.metrics.AUC(name="auc")]
    )

    return model


# ------------------------------------------------------------
# 4. Main kernel sensitivity runner
# ------------------------------------------------------------
def run_kernel_sensitivity(
    X_full,
    y_full,
    time_full,
    horizon,
    kernels,
    epochs,
    batch_size,
    patience,
    lr,
    dropout,
    units=64,
    dense_units=32,
):
    X_full = np.asarray(X_full).astype("float32")
    y_full = np.asarray(y_full).astype("int64")
    time_full = pd.to_datetime(time_full)

    order = np.argsort(time_full.values)

    X_full = X_full[order]
    y_full = y_full[order]
    time_full = time_full.values[order]

    print(f"\nUsing {horizon} arrays")
    print("X_full:", X_full.shape)
    print("y_full:", y_full.shape, "positives:", int(y_full.sum()), "prevalence:", float(y_full.mean()))
    print("Date range:", pd.to_datetime(time_full).min(), "to", pd.to_datetime(time_full).max())

    n = len(y_full)
    n_train = int(round(0.70 * n))
    n_val = int(round(0.15 * n))
    n_test = n - n_train - n_val

    idx_train = np.arange(0, n_train)
    idx_val = np.arange(n_train, n_train + n_val)
    idx_test = np.arange(n_train + n_val, n)

    X_train = X_full[idx_train]
    y_train = y_full[idx_train]

    X_val = X_full[idx_val]
    y_val = y_full[idx_val]

    X_test = X_full[idx_test]
    y_test = y_full[idx_test]

    print("\nSplit summary")
    print("Train:", X_train.shape, "pos:", int(y_train.sum()), pd.to_datetime(time_full[idx_train[0]]), "to", pd.to_datetime(time_full[idx_train[-1]]))
    print("Val:  ", X_val.shape, "pos:", int(y_val.sum()), pd.to_datetime(time_full[idx_val[0]]), "to", pd.to_datetime(time_full[idx_val[-1]]))
    print("Test: ", X_test.shape, "pos:", int(y_test.sum()), pd.to_datetime(time_full[idx_test[0]]), "to", pd.to_datetime(time_full[idx_test[-1]]))

    X_train_s, X_val_s, X_test_s, _ = scale_3d_train_only(X_train, X_val, X_test)

    rows = []

    for kernel in kernels:
        print("\n" + "=" * 80)
        print(f"{horizon} DLSTM kernel sensitivity: MA kernel = {kernel}")
        print("=" * 80)

        X_train_d = moving_average_decompose_fast(X_train_s, kernel=kernel)
        X_val_d = moving_average_decompose_fast(X_val_s, kernel=kernel)
        X_test_d = moving_average_decompose_fast(X_test_s, kernel=kernel)

        print("Decomposed shapes")
        print("X_train_d:", X_train_d.shape)
        print("X_val_d:  ", X_val_d.shape)
        print("X_test_d: ", X_test_d.shape)

        tf.keras.backend.clear_session()
        tf.random.set_seed(SEED)

        model = build_dlstmlike(
            input_shape=X_train_d.shape[1:],
            units=units,
            dense_units=dense_units,
            dropout=dropout,
            lr=lr
        )

        es = callbacks.EarlyStopping(
            monitor="val_auc",
            mode="max",
            patience=patience,
            restore_best_weights=True
        )

        history = model.fit(
            X_train_d,
            y_train,
            validation_data=(X_val_d, y_val),
            epochs=epochs,
            batch_size=batch_size,
            class_weight=class_weight_dict(y_train),
            callbacks=[es],
            verbose=1
        )

        history_df = pd.DataFrame(history.history)
        history_file = OUT_DIR / f"learning_curve_kernel_{horizon}_ma{kernel}.csv"
        history_df.to_csv(history_file, index=False)

        p_val = model.predict(X_val_d, verbose=0).ravel()
        p_test = model.predict(X_test_d, verbose=0).ravel()

        thr, val_tss = best_threshold_by_val_tss(y_val, p_val)
        metrics = evaluate_probs(y_test, p_test, threshold=thr)

        best_epoch = int(np.argmax(history.history["val_auc"]) + 1)

        metrics.update({
            "Horizon": horizon,
            "Model": "DLSTM-like",
            "MA_Kernel": kernel,
            "Sequence_Length": X_full.shape[1],
            "Input_Features": X_full.shape[2],
            "Decomposed_Features": X_train_d.shape[2],
            "Val_TSS_Selected": val_tss,
            "Best_Val_AUC": float(np.max(history.history["val_auc"])),
            "Best_Epoch_By_Val_AUC": best_epoch,
            "Epochs_Run": len(history.history["loss"]),
            "Dropout": dropout,
            "Learning_Rate": lr,
            "Train_N": len(y_train),
            "Val_N": len(y_val),
            "Test_N": len(y_test),
            "Train_Pos": int(y_train.sum()),
            "Val_Pos": int(y_val.sum()),
            "Test_Pos": int(y_test.sum()),
            "Learning_Curve_File": str(history_file),
        })

        rows.append(metrics)

        print({
            k: round(metrics[k], 4) if isinstance(metrics[k], float) else metrics[k]
            for k in [
                "MA_Kernel", "Val_TSS_Selected", "TSS", "HSS", "ROC_AUC",
                "PR_AUC", "Recall", "Precision", "F1", "Threshold",
                "Best_Val_AUC", "Best_Epoch_By_Val_AUC"
            ]
        })

    kernel_df = pd.DataFrame(rows)

    cols = [
        "Horizon",
        "Model",
        "MA_Kernel",
        "Sequence_Length",
        "Input_Features",
        "Decomposed_Features",
        "Threshold",
        "Val_TSS_Selected",
        "TSS",
        "HSS",
        "ROC_AUC",
        "PR_AUC",
        "Recall",
        "Precision",
        "F1",
        "TN",
        "FP",
        "FN",
        "TP",
        "Best_Val_AUC",
        "Best_Epoch_By_Val_AUC",
        "Epochs_Run",
        "Dropout",
        "Learning_Rate",
        "Train_N",
        "Val_N",
        "Test_N",
        "Train_Pos",
        "Val_Pos",
        "Test_Pos",
        "Learning_Curve_File",
    ]

    kernel_df = kernel_df[cols]

    out_file = OUT_DIR / f"dlstm_kernel_sensitivity_{horizon}.csv"
    kernel_df.to_csv(out_file, index=False)

    display(kernel_df)

    print("\nSaved kernel sensitivity results to:", out_file)

    return kernel_df


print("✅ Kernel sensitivity helpers loaded.")
# Out:
# ✅ Kernel sensitivity helpers loaded.

# %%
# ============================================================
# ROUND 2A: 24H DLSTM KERNEL SENSITIVITY
# Kernels: 2, 3, 4
# Paste inside 24h notebook AFTER X_seq, y_seq, t_seq exist
# ============================================================

assert "X_seq" in globals(), "X_seq not found. Run the 24h notebook first."
assert "y_seq" in globals(), "y_seq not found. Run the 24h notebook first."
assert "t_seq" in globals(), "t_seq not found. Run the 24h notebook first."

assert X_seq.shape[1] == 4, f"Expected 24h sequence length 4, got {X_seq.shape[1]}"
assert X_seq.shape[-1] == 21, f"Expected 24h 21 features, got {X_seq.shape[-1]}"

kernel_24h_df = run_kernel_sensitivity(
    X_full=X_seq,
    y_full=y_seq,
    time_full=t_seq,
    horizon="24h",
    kernels=[2, 3, 4],
    epochs=35,
    batch_size=64,
    patience=6,
    lr=1e-3,
    dropout=0.2,
    units=64,
    dense_units=32,
)
# Out:
# Using 24h arrays
# X_full: (2342, 4, 21)
# y_full: (2342,) positives: 344 prevalence: 0.14688300597779674
# Date range: 2010-05-08 12:00:00 to 2025-04-18 12:00:00
#
# Split summary
# Train: (1639, 4, 21) pos: 174 2010-05-08 12:00:00 to 2023-02-22 12:00:00
# Val:   (351, 4, 21) pos: 63 2023-02-24 12:00:00 to 2024-02-16 12:00:00
# Test:  (352, 4, 21) pos: 107 2024-02-16 12:00:00 to 2025-04-18 12:00:00
#
# ================================================================================
# 24h DLSTM kernel sensitivity: MA kernel = 2
# ================================================================================
# Decomposed shapes
# X_train_d: (1639, 4, 42)
# X_val_d:   (351, 4, 42)
# X_test_d:  (352, 4, 42)
# Epoch 1/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - auc: 0.7791 - loss: 0.6079 - val_auc: 0.7823 - val_loss: 0.7378
# Epoch 2/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.8426 - loss: 0.5149 - val_auc: 0.7950 - val_loss: 0.6596
# Epoch 3/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - auc: 0.8599 - loss: 0.4688 - val_auc: 0.8075 - val_loss: 0.6338
# Epoch 4/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - auc: 0.8766 - loss: 0.4402 - val_auc: 0.8236 - val_loss: 0.6268
# Epoch 5/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8862 - loss: 0.4227 - val_auc: 0.8281 - val_loss: 0.6124
# Epoch 6/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.8927 - loss: 0.4116 - val_auc: 0.8345 - val_loss: 0.6063
# Epoch 7/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.8998 - loss: 0.3961 - val_auc: 0.8362 - val_loss: 0.5930
# Epoch 8/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9061 - loss: 0.3829 - val_auc: 0.8407 - val_loss: 0.5812
# Epoch 9/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9107 - loss: 0.3751 - val_auc: 0.8402 - val_loss: 0.5739
# Epoch 10/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9137 - loss: 0.3677 - val_auc: 0.8388 - val_loss: 0.5710
# Epoch 11/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9202 - loss: 0.3547 - val_auc: 0.8408 - val_loss: 0.5624
# Epoch 12/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9211 - loss: 0.3523 - val_auc: 0.8382 - val_loss: 0.5505
# Epoch 13/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9275 - loss: 0.3420 - val_auc: 0.8398 - val_loss: 0.5526
# Epoch 14/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9334 - loss: 0.3274 - val_auc: 0.8386 - val_loss: 0.5469
# Epoch 15/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9360 - loss: 0.3215 - val_auc: 0.8406 - val_loss: 0.5310
# Epoch 16/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9415 - loss: 0.3057 - val_auc: 0.8408 - val_loss: 0.5168
# Epoch 17/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9450 - loss: 0.2984 - val_auc: 0.8397 - val_loss: 0.5137
# {'MA_Kernel': 2, 'Val_TSS_Selected': np.float64(0.5501), 'TSS': np.float64(0.3875), 'HSS': np.float64(0.3042), 'ROC_AUC': np.float64(0.798), 'PR_AUC': np.float64(0.66), 'Recall': 0.8692, 'Precision': 0.4408, 'F1': 0.5849, 'Threshold': 0.46, 'Best_Val_AUC': 0.8408, 'Best_Epoch_By_Val_AUC': 11}
#
# ================================================================================
# 24h DLSTM kernel sensitivity: MA kernel = 3
# ================================================================================
# Decomposed shapes
# X_train_d: (1639, 4, 42)
# X_val_d:   (351, 4, 42)
# X_test_d:  (352, 4, 42)
# Epoch 1/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - auc: 0.7818 - loss: 0.5985 - val_auc: 0.7948 - val_loss: 0.6580
# Epoch 2/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.8365 - loss: 0.4971 - val_auc: 0.8000 - val_loss: 0.6588
# Epoch 3/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.8534 - loss: 0.4659 - val_auc: 0.8117 - val_loss: 0.6322
# Epoch 4/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.8700 - loss: 0.4465 - val_auc: 0.8222 - val_loss: 0.6210
# Epoch 5/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.8784 - loss: 0.4316 - val_auc: 0.8318 - val_loss: 0.6096
# Epoch 6/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.8877 - loss: 0.4167 - val_auc: 0.8393 - val_loss: 0.5985
# Epoch 7/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.8928 - loss: 0.4110 - val_auc: 0.8416 - val_loss: 0.5934
# Epoch 8/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9053 - loss: 0.3858 - val_auc: 0.8442 - val_loss: 0.5755
# Epoch 9/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9099 - loss: 0.3783 - val_auc: 0.8483 - val_loss: 0.5704
# Epoch 10/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9129 - loss: 0.3720 - val_auc: 0.8493 - val_loss: 0.5584
# Epoch 11/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9196 - loss: 0.3561 - val_auc: 0.8456 - val_loss: 0.5445
# Epoch 12/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9199 - loss: 0.3565 - val_auc: 0.8479 - val_loss: 0.5511
# Epoch 13/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9266 - loss: 0.3413 - val_auc: 0.8468 - val_loss: 0.5431
# Epoch 14/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9267 - loss: 0.3388 - val_auc: 0.8473 - val_loss: 0.5309
# Epoch 15/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9337 - loss: 0.3263 - val_auc: 0.8434 - val_loss: 0.5217
# Epoch 16/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9361 - loss: 0.3167 - val_auc: 0.8345 - val_loss: 0.5235
# {'MA_Kernel': 3, 'Val_TSS_Selected': np.float64(0.561), 'TSS': np.float64(0.4294), 'HSS': np.float64(0.3594), 'ROC_AUC': np.float64(0.8051), 'PR_AUC': np.float64(0.6778), 'Recall': 0.8131, 'Precision': 0.4807, 'F1': 0.6042, 'Threshold': 0.56, 'Best_Val_AUC': 0.8493, 'Best_Epoch_By_Val_AUC': 10}
#
# ================================================================================
# 24h DLSTM kernel sensitivity: MA kernel = 4
# ================================================================================
# Decomposed shapes
# X_train_d: (1639, 4, 42)
# X_val_d:   (351, 4, 42)
# X_test_d:  (352, 4, 42)
# Epoch 1/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - auc: 0.7571 - loss: 0.6083 - val_auc: 0.7819 - val_loss: 0.6721
# Epoch 2/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.8348 - loss: 0.5047 - val_auc: 0.7963 - val_loss: 0.6377
# Epoch 3/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.8526 - loss: 0.4715 - val_auc: 0.8110 - val_loss: 0.6270
# Epoch 4/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.8716 - loss: 0.4450 - val_auc: 0.8233 - val_loss: 0.6194
# Epoch 5/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.8827 - loss: 0.4285 - val_auc: 0.8302 - val_loss: 0.6144
# Epoch 6/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.8893 - loss: 0.4173 - val_auc: 0.8341 - val_loss: 0.6029
# Epoch 7/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.8992 - loss: 0.4003 - val_auc: 0.8371 - val_loss: 0.5929
# Epoch 8/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9016 - loss: 0.3949 - val_auc: 0.8401 - val_loss: 0.5799
# Epoch 9/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9061 - loss: 0.3858 - val_auc: 0.8440 - val_loss: 0.5759
# Epoch 10/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9147 - loss: 0.3685 - val_auc: 0.8434 - val_loss: 0.5621
# Epoch 11/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9195 - loss: 0.3584 - val_auc: 0.8415 - val_loss: 0.5587
# Epoch 12/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9278 - loss: 0.3415 - val_auc: 0.8395 - val_loss: 0.5433
# Epoch 13/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9328 - loss: 0.3306 - val_auc: 0.8390 - val_loss: 0.5431
# Epoch 14/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9343 - loss: 0.3233 - val_auc: 0.8347 - val_loss: 0.5433
# Epoch 15/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9383 - loss: 0.3152 - val_auc: 0.8311 - val_loss: 0.5391
# {'MA_Kernel': 4, 'Val_TSS_Selected': np.float64(0.5531), 'TSS': np.float64(0.4265), 'HSS': np.float64(0.3539), 'ROC_AUC': np.float64(0.8115), 'PR_AUC': np.float64(0.6843), 'Recall': 0.8224, 'Precision': 0.4757, 'F1': 0.6027, 'Threshold': 0.52, 'Best_Val_AUC': 0.844, 'Best_Epoch_By_Val_AUC': 9}
#   Horizon       Model  MA_Kernel  Sequence_Length  Input_Features  \
# 0     24h  DLSTM-like          2                4              21
# 1     24h  DLSTM-like          3                4              21
# 2     24h  DLSTM-like          4                4              21
#
#    Decomposed_Features  Threshold  Val_TSS_Selected       TSS       HSS  ...  \
# 0                   42       0.46          0.550099  0.387526  0.304244  ...
# 1                   42       0.56          0.561012  0.429411  0.359407  ...
# 2                   42       0.52          0.553075  0.426512  0.353863  ...
#
#    Epochs_Run  Dropout  Learning_Rate  Train_N  Val_N  Test_N  Train_Pos  \
# 0          17      0.2          0.001     1639    351     352        174
# 1          16      0.2          0.001     1639    351     352        174
# 2          15      0.2          0.001     1639    351     352        174
#
#    Val_Pos  Test_Pos                                Learning_Curve_File
# 0       63       107  /content/drive/MyDrive/ASR_MAJOR_REVISION_KERN...
# 1       63       107  /content/drive/MyDrive/ASR_MAJOR_REVISION_KERN...
# 2       63       107  /content/drive/MyDrive/ASR_MAJOR_REVISION_KERN...
#
# [3 rows x 31 columns]
# Saved kernel sensitivity results to: /content/drive/MyDrive/ASR_MAJOR_REVISION_KERNEL_SENSITIVITY/dlstm_kernel_sensitivity_24h.csv

# %% [markdown]
# ---
#
#
#
# ---

# %%
# ============================================================
# ROUND 3 COMMON HELPERS:
# OVERFITTING EVIDENCE + DROPOUT SENSITIVITY
# Works for 3h, 24h, 72h notebooks
# ============================================================

import os
import random
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    confusion_matrix,
    roc_auc_score,
    average_precision_score,
    precision_score,
    recall_score,
    f1_score
)
from sklearn.utils.class_weight import compute_class_weight

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, optimizers


# ------------------------------------------------------------
# 0. Reproducibility and output folders
# ------------------------------------------------------------
SEED = 42

os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

OUT_DIR = Path("/content/drive/MyDrive/ASR_MAJOR_REVISION_OVERFITTING")
OUT_DIR.mkdir(parents=True, exist_ok=True)

CURVE_DIR = OUT_DIR / "learning_curves"
CURVE_DIR.mkdir(parents=True, exist_ok=True)

DROPOUT_DIR = OUT_DIR / "dropout_sensitivity"
DROPOUT_DIR.mkdir(parents=True, exist_ok=True)


# ------------------------------------------------------------
# 1. Metric helpers
# ------------------------------------------------------------
def compute_tss_hss(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred, labels=[0, 1]).ravel()

    pod = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    far = fp / (fp + tn) if (fp + tn) > 0 else 0.0

    tss = pod - far

    denom = ((tp + fn) * (fn + tn) + (tp + fp) * (fp + tn))
    hss = (2 * ((tp * tn) - (fn * fp)) / denom) if denom > 0 else 0.0

    return tss, hss, tn, fp, fn, tp


def best_threshold_by_val_tss(y_val, p_val, grid=None):
    if grid is None:
        grid = np.linspace(0.01, 0.99, 99)

    best_thr = 0.5
    best_tss = -999.0

    for thr in grid:
        pred = (p_val >= thr).astype(int)
        tss, *_ = compute_tss_hss(y_val, pred)

        if tss > best_tss:
            best_tss = tss
            best_thr = float(thr)

    return best_thr, best_tss


def evaluate_probs(y_true, p, threshold):
    pred = (p >= threshold).astype(int)

    tss, hss, tn, fp, fn, tp = compute_tss_hss(y_true, pred)

    return {
        "TSS": tss,
        "HSS": hss,
        "ROC_AUC": roc_auc_score(y_true, p) if len(np.unique(y_true)) == 2 else np.nan,
        "PR_AUC": average_precision_score(y_true, p),
        "Recall": recall_score(y_true, pred, zero_division=0),
        "Precision": precision_score(y_true, pred, zero_division=0),
        "F1": f1_score(y_true, pred, zero_division=0),
        "TN": tn,
        "FP": fp,
        "FN": fn,
        "TP": tp,
        "Threshold": threshold,
    }


def class_weight_dict(y_train):
    classes = np.array([0, 1])
    weights = compute_class_weight(
        class_weight="balanced",
        classes=classes,
        y=y_train.astype(int)
    )
    return {0: float(weights[0]), 1: float(weights[1])}


# ------------------------------------------------------------
# 2. Scaling + moving-average decomposition
# ------------------------------------------------------------
def scale_3d_train_only(X_train, X_val, X_test):
    n_steps, n_feat = X_train.shape[1], X_train.shape[2]

    scaler = StandardScaler()
    scaler.fit(X_train.reshape(-1, n_feat))

    def transform(X):
        return scaler.transform(X.reshape(-1, n_feat)).reshape(X.shape[0], n_steps, n_feat)

    return transform(X_train), transform(X_val), transform(X_test), scaler


def moving_average_decompose_fast(X, kernel=3):
    """
    Same-length moving-average decomposition.
    Returns concatenated [trend, residual] channels.
    """
    if kernel is None:
        return X.astype("float32")

    if kernel > X.shape[1]:
        raise ValueError(f"Kernel {kernel} cannot exceed sequence length {X.shape[1]}.")

    pad_left = kernel // 2
    pad_right = kernel - 1 - pad_left

    padded = np.pad(
        X,
        pad_width=((0, 0), (pad_left, pad_right), (0, 0)),
        mode="edge"
    )

    trend = np.zeros_like(X, dtype="float32")

    for k in range(kernel):
        trend += padded[:, k:k + X.shape[1], :]

    trend = trend / float(kernel)
    residual = X - trend

    return np.concatenate([trend, residual], axis=-1).astype("float32")


# ------------------------------------------------------------
# 3. Model builders
# ------------------------------------------------------------
def build_bilstm(input_shape, units=64, dense_units=32, dropout=0.2, lr=1e-3):
    inp = layers.Input(shape=input_shape)

    x = layers.Bidirectional(layers.LSTM(units))(inp)
    x = layers.Dropout(dropout)(x)
    x = layers.Dense(dense_units, activation="relu")(x)

    out = layers.Dense(1, activation="sigmoid")(x)

    model = models.Model(inp, out)

    model.compile(
        optimizer=optimizers.Adam(learning_rate=lr),
        loss="binary_crossentropy",
        metrics=[tf.keras.metrics.AUC(name="auc")]
    )

    return model


def build_dlstmlike(input_shape, units=64, dense_units=32, dropout=0.2, lr=1e-3):
    inp = layers.Input(shape=input_shape)

    x = layers.LSTM(units)(inp)
    x = layers.Dropout(dropout)(x)
    x = layers.Dense(dense_units, activation="relu")(x)

    out = layers.Dense(1, activation="sigmoid")(x)

    model = models.Model(inp, out)

    model.compile(
        optimizer=optimizers.Adam(learning_rate=lr),
        loss="binary_crossentropy",
        metrics=[tf.keras.metrics.AUC(name="auc")]
    )

    return model


# ------------------------------------------------------------
# 4. Learning-curve plotting
# ------------------------------------------------------------
def save_learning_curve_plots(history_df, horizon, model_name, dropout, ma_kernel):
    safe_model = model_name.replace(" ", "_").replace("/", "_")
    kernel_label = "NA" if ma_kernel is None else str(ma_kernel)
    prefix = f"{horizon}_{safe_model}_dropout_{dropout}_ma_{kernel_label}"

    csv_path = CURVE_DIR / f"{prefix}_history.csv"
    loss_png = CURVE_DIR / f"{prefix}_loss_curve.png"
    auc_png = CURVE_DIR / f"{prefix}_auc_curve.png"

    history_df.to_csv(csv_path, index=False)

    # Loss curve
    plt.figure(figsize=(7, 5))
    plt.plot(history_df["loss"], label="Training loss")
    plt.plot(history_df["val_loss"], label="Validation loss")
    plt.xlabel("Epoch")
    plt.ylabel("Binary cross-entropy loss")
    plt.title(f"{horizon} {model_name}: loss curve, dropout={dropout}, MA={kernel_label}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(loss_png, dpi=300)
    plt.show()

    # AUC curve
    plt.figure(figsize=(7, 5))
    plt.plot(history_df["auc"], label="Training AUC")
    plt.plot(history_df["val_auc"], label="Validation AUC")
    plt.xlabel("Epoch")
    plt.ylabel("AUC")
    plt.title(f"{horizon} {model_name}: AUC curve, dropout={dropout}, MA={kernel_label}")
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(auc_png, dpi=300)
    plt.show()

    return str(csv_path), str(loss_png), str(auc_png)


# ------------------------------------------------------------
# 5. Main dropout-sensitivity runner
# ------------------------------------------------------------
def run_dropout_sensitivity(
    X_full,
    y_full,
    time_full,
    horizon,
    model_type,
    dropout_values,
    ma_kernel=None,
    epochs=25,
    batch_size=128,
    patience=5,
    lr=1e-3,
    units=64,
    dense_units=32,
):
    """
    model_type:
        "bilstm"  -> BiLSTM without moving-average decomposition
        "dlstm"   -> DLSTM-like trend/residual decomposition before LSTM
    """

    X_full = np.asarray(X_full).astype("float32")
    y_full = np.asarray(y_full).astype("int64")
    time_full = pd.to_datetime(time_full)

    order = np.argsort(time_full.values)

    X_full = X_full[order]
    y_full = y_full[order]
    time_full = time_full.values[order]

    print(f"\nUsing {horizon} arrays")
    print("X_full:", X_full.shape)
    print("y_full:", y_full.shape, "positives:", int(y_full.sum()), "prevalence:", float(y_full.mean()))
    print("Date range:", pd.to_datetime(time_full).min(), "to", pd.to_datetime(time_full).max())

    n = len(y_full)
    n_train = int(round(0.70 * n))
    n_val = int(round(0.15 * n))
    n_test = n - n_train - n_val

    idx_train = np.arange(0, n_train)
    idx_val = np.arange(n_train, n_train + n_val)
    idx_test = np.arange(n_train + n_val, n)

    X_train = X_full[idx_train]
    y_train = y_full[idx_train]

    X_val = X_full[idx_val]
    y_val = y_full[idx_val]

    X_test = X_full[idx_test]
    y_test = y_full[idx_test]

    print("\nSplit summary")
    print("Train:", X_train.shape, "pos:", int(y_train.sum()), pd.to_datetime(time_full[idx_train[0]]), "to", pd.to_datetime(time_full[idx_train[-1]]))
    print("Val:  ", X_val.shape, "pos:", int(y_val.sum()), pd.to_datetime(time_full[idx_val[0]]), "to", pd.to_datetime(time_full[idx_val[-1]]))
    print("Test: ", X_test.shape, "pos:", int(y_test.sum()), pd.to_datetime(time_full[idx_test[0]]), "to", pd.to_datetime(time_full[idx_test[-1]]))

    X_train_s, X_val_s, X_test_s, _ = scale_3d_train_only(X_train, X_val, X_test)

    if model_type.lower() == "dlstm":
        X_train_model = moving_average_decompose_fast(X_train_s, kernel=ma_kernel)
        X_val_model = moving_average_decompose_fast(X_val_s, kernel=ma_kernel)
        X_test_model = moving_average_decompose_fast(X_test_s, kernel=ma_kernel)
        model_name = f"DLSTM-like MA{ma_kernel}"
    elif model_type.lower() == "bilstm":
        X_train_model = X_train_s
        X_val_model = X_val_s
        X_test_model = X_test_s
        model_name = "BiLSTM"
    else:
        raise ValueError("model_type must be either 'bilstm' or 'dlstm'.")

    print("\nModel input shapes")
    print("X_train_model:", X_train_model.shape)
    print("X_val_model:  ", X_val_model.shape)
    print("X_test_model: ", X_test_model.shape)

    rows = []

    for dropout in dropout_values:
        print("\n" + "=" * 80)
        print(f"{horizon} dropout sensitivity: {model_name}, dropout={dropout}")
        print("=" * 80)

        tf.keras.backend.clear_session()
        tf.random.set_seed(SEED)

        if model_type.lower() == "dlstm":
            model = build_dlstmlike(
                input_shape=X_train_model.shape[1:],
                units=units,
                dense_units=dense_units,
                dropout=dropout,
                lr=lr
            )
        else:
            model = build_bilstm(
                input_shape=X_train_model.shape[1:],
                units=units,
                dense_units=dense_units,
                dropout=dropout,
                lr=lr
            )

        es = callbacks.EarlyStopping(
            monitor="val_auc",
            mode="max",
            patience=patience,
            restore_best_weights=True
        )

        history = model.fit(
            X_train_model,
            y_train,
            validation_data=(X_val_model, y_val),
            epochs=epochs,
            batch_size=batch_size,
            class_weight=class_weight_dict(y_train),
            callbacks=[es],
            verbose=1
        )

        history_df = pd.DataFrame(history.history)

        history_csv, loss_png, auc_png = save_learning_curve_plots(
            history_df=history_df,
            horizon=horizon,
            model_name=model_name,
            dropout=dropout,
            ma_kernel=ma_kernel
        )

        p_val = model.predict(X_val_model, verbose=0).ravel()
        p_test = model.predict(X_test_model, verbose=0).ravel()

        thr, val_tss = best_threshold_by_val_tss(y_val, p_val)
        metrics = evaluate_probs(y_test, p_test, threshold=thr)

        best_epoch_idx = int(np.argmax(history_df["val_auc"].values))
        best_epoch = best_epoch_idx + 1

        train_auc_at_best = float(history_df.loc[best_epoch_idx, "auc"])
        val_auc_at_best = float(history_df.loc[best_epoch_idx, "val_auc"])
        train_loss_at_best = float(history_df.loc[best_epoch_idx, "loss"])
        val_loss_at_best = float(history_df.loc[best_epoch_idx, "val_loss"])

        metrics.update({
            "Horizon": horizon,
            "Model": model_name,
            "Model_Type": model_type,
            "MA_Kernel": ma_kernel if ma_kernel is not None else "N/A",
            "Dropout": dropout,
            "Val_TSS_Selected": val_tss,
            "Best_Val_AUC": val_auc_at_best,
            "Train_AUC_At_Best_Val_AUC": train_auc_at_best,
            "AUC_Gap_Train_Minus_Val": train_auc_at_best - val_auc_at_best,
            "Train_Loss_At_Best_Val_AUC": train_loss_at_best,
            "Val_Loss_At_Best_Val_AUC": val_loss_at_best,
            "Loss_Gap_Val_Minus_Train": val_loss_at_best - train_loss_at_best,
            "Best_Epoch_By_Val_AUC": best_epoch,
            "Epochs_Run": len(history_df),
            "Learning_Curve_CSV": history_csv,
            "Loss_Curve_PNG": loss_png,
            "AUC_Curve_PNG": auc_png,
            "Train_N": len(y_train),
            "Val_N": len(y_val),
            "Test_N": len(y_test),
            "Train_Pos": int(y_train.sum()),
            "Val_Pos": int(y_val.sum()),
            "Test_Pos": int(y_test.sum()),
        })

        rows.append(metrics)

        print({
            k: round(metrics[k], 4) if isinstance(metrics[k], float) else metrics[k]
            for k in [
                "Dropout", "Val_TSS_Selected", "TSS", "HSS", "ROC_AUC", "PR_AUC",
                "Recall", "Precision", "F1", "Best_Val_AUC",
                "AUC_Gap_Train_Minus_Val", "Loss_Gap_Val_Minus_Train",
                "Best_Epoch_By_Val_AUC"
            ]
        })

    dropout_df = pd.DataFrame(rows)

    cols = [
        "Horizon",
        "Model",
        "Model_Type",
        "MA_Kernel",
        "Dropout",
        "Threshold",
        "Val_TSS_Selected",
        "TSS",
        "HSS",
        "ROC_AUC",
        "PR_AUC",
        "Recall",
        "Precision",
        "F1",
        "TN",
        "FP",
        "FN",
        "TP",
        "Best_Val_AUC",
        "Train_AUC_At_Best_Val_AUC",
        "AUC_Gap_Train_Minus_Val",
        "Train_Loss_At_Best_Val_AUC",
        "Val_Loss_At_Best_Val_AUC",
        "Loss_Gap_Val_Minus_Train",
        "Best_Epoch_By_Val_AUC",
        "Epochs_Run",
        "Train_N",
        "Val_N",
        "Test_N",
        "Train_Pos",
        "Val_Pos",
        "Test_Pos",
        "Learning_Curve_CSV",
        "Loss_Curve_PNG",
        "AUC_Curve_PNG",
    ]

    dropout_df = dropout_df[cols]

    out_file = DROPOUT_DIR / f"dropout_sensitivity_{horizon}.csv"
    dropout_df.to_csv(out_file, index=False)

    display(dropout_df)

    print("\nSaved dropout sensitivity results to:", out_file)

    return dropout_df


print("✅ Round 3 overfitting/dropout helper loaded.")
# Out:
# ✅ Round 3 overfitting/dropout helper loaded.

# %%
# ============================================================
# ROUND 3A: 24H OVERFITTING + DROPOUT SENSITIVITY
# Representative model: BiLSTM
# Paste inside 24h notebook AFTER X_seq, y_seq, t_seq exist
# ============================================================

assert "X_seq" in globals(), "X_seq not found. Run the 24h notebook first."
assert "y_seq" in globals(), "y_seq not found. Run the 24h notebook first."
assert "t_seq" in globals(), "t_seq not found. Run the 24h notebook first."

assert X_seq.shape[1] == 4, f"Expected 24h sequence length 4, got {X_seq.shape[1]}"
assert X_seq.shape[-1] == 21, f"Expected 24h 21 features, got {X_seq.shape[-1]}"

dropout_24h_df = run_dropout_sensitivity(
    X_full=X_seq,
    y_full=y_seq,
    time_full=t_seq,
    horizon="24h",
    model_type="bilstm",
    dropout_values=[0.1, 0.2, 0.3, 0.5],
    ma_kernel=None,
    epochs=35,
    batch_size=64,
    patience=6,
    lr=1e-3,
    units=64,
    dense_units=32,
)
# Out:
# Using 24h arrays
# X_full: (2342, 4, 21)
# y_full: (2342,) positives: 344 prevalence: 0.14688300597779674
# Date range: 2010-05-08 12:00:00 to 2025-04-18 12:00:00
#
# Split summary
# Train: (1639, 4, 21) pos: 174 2010-05-08 12:00:00 to 2023-02-22 12:00:00
# Val:   (351, 4, 21) pos: 63 2023-02-24 12:00:00 to 2024-02-16 12:00:00
# Test:  (352, 4, 21) pos: 107 2024-02-16 12:00:00 to 2025-04-18 12:00:00
#
# Model input shapes
# X_train_model: (1639, 4, 21)
# X_val_model:   (351, 4, 21)
# X_test_model:  (352, 4, 21)
#
# ================================================================================
# 24h dropout sensitivity: BiLSTM, dropout=0.1
# ================================================================================
# Epoch 1/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - auc: 0.7785 - loss: 0.5810 - val_auc: 0.7934 - val_loss: 0.6831
# Epoch 2/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8408 - loss: 0.4859 - val_auc: 0.8008 - val_loss: 0.6548
# Epoch 3/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.8586 - loss: 0.4583 - val_auc: 0.8142 - val_loss: 0.6452
# Epoch 4/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8746 - loss: 0.4378 - val_auc: 0.8260 - val_loss: 0.6329
# Epoch 5/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8891 - loss: 0.4169 - val_auc: 0.8316 - val_loss: 0.6183
# Epoch 6/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.8982 - loss: 0.4018 - val_auc: 0.8369 - val_loss: 0.6107
# Epoch 7/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - auc: 0.9080 - loss: 0.3853 - val_auc: 0.8383 - val_loss: 0.5878
# Epoch 8/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - auc: 0.9103 - loss: 0.3775 - val_auc: 0.8355 - val_loss: 0.5733
# Epoch 9/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - auc: 0.9212 - loss: 0.3576 - val_auc: 0.8338 - val_loss: 0.5674
# Epoch 10/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - auc: 0.9249 - loss: 0.3483 - val_auc: 0.8328 - val_loss: 0.5599
# Epoch 11/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - auc: 0.9288 - loss: 0.3377 - val_auc: 0.8319 - val_loss: 0.5538
# Epoch 12/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - auc: 0.9352 - loss: 0.3219 - val_auc: 0.8292 - val_loss: 0.5405
# Epoch 13/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - auc: 0.9396 - loss: 0.3125 - val_auc: 0.8288 - val_loss: 0.5589
# {'Dropout': 0.1, 'Val_TSS_Selected': np.float64(0.565), 'TSS': np.float64(0.4347), 'HSS': np.float64(0.3622), 'ROC_AUC': np.float64(0.8099), 'PR_AUC': np.float64(0.6903), 'Recall': 0.8224, 'Precision': 0.4809, 'F1': 0.6069, 'Best_Val_AUC': 0.8383, 'AUC_Gap_Train_Minus_Val': 0.0696, 'Loss_Gap_Val_Minus_Train': 0.2025, 'Best_Epoch_By_Val_AUC': 7}
#
# ================================================================================
# 24h dropout sensitivity: BiLSTM, dropout=0.2
# ================================================================================
# Epoch 1/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - auc: 0.7809 - loss: 0.5787 - val_auc: 0.7874 - val_loss: 0.6685
# Epoch 2/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - auc: 0.8359 - loss: 0.4909 - val_auc: 0.7949 - val_loss: 0.6726
# Epoch 3/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.8503 - loss: 0.4683 - val_auc: 0.8083 - val_loss: 0.6543
# Epoch 4/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8668 - loss: 0.4470 - val_auc: 0.8220 - val_loss: 0.6467
# Epoch 5/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8831 - loss: 0.4282 - val_auc: 0.8319 - val_loss: 0.6364
# Epoch 6/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8885 - loss: 0.4168 - val_auc: 0.8332 - val_loss: 0.6269
# Epoch 7/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.9012 - loss: 0.3940 - val_auc: 0.8358 - val_loss: 0.6016
# Epoch 8/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.9044 - loss: 0.3865 - val_auc: 0.8344 - val_loss: 0.5917
# Epoch 9/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.9134 - loss: 0.3701 - val_auc: 0.8358 - val_loss: 0.5745
# Epoch 10/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.9163 - loss: 0.3622 - val_auc: 0.8338 - val_loss: 0.5629
# Epoch 11/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.9194 - loss: 0.3538 - val_auc: 0.8339 - val_loss: 0.5585
# Epoch 12/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.9228 - loss: 0.3497 - val_auc: 0.8356 - val_loss: 0.5650
# Epoch 13/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.9287 - loss: 0.3359 - val_auc: 0.8338 - val_loss: 0.5386
# {'Dropout': 0.2, 'Val_TSS_Selected': np.float64(0.5263), 'TSS': np.float64(0.4493), 'HSS': np.float64(0.3719), 'ROC_AUC': np.float64(0.8115), 'PR_AUC': np.float64(0.6852), 'Recall': 0.8411, 'Precision': 0.4839, 'F1': 0.6143, 'Best_Val_AUC': 0.8358, 'AUC_Gap_Train_Minus_Val': 0.0654, 'Loss_Gap_Val_Minus_Train': 0.2076, 'Best_Epoch_By_Val_AUC': 7}
#
# ================================================================================
# 24h dropout sensitivity: BiLSTM, dropout=0.3
# ================================================================================
# Epoch 1/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 6s 38ms/step - auc: 0.7353 - loss: 0.6203 - val_auc: 0.7754 - val_loss: 0.6358
# Epoch 2/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.8268 - loss: 0.5031 - val_auc: 0.7884 - val_loss: 0.6789
# Epoch 3/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8424 - loss: 0.4790 - val_auc: 0.7992 - val_loss: 0.6694
# Epoch 4/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.8571 - loss: 0.4604 - val_auc: 0.8090 - val_loss: 0.6557
# Epoch 5/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8701 - loss: 0.4391 - val_auc: 0.8188 - val_loss: 0.6398
# Epoch 6/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8780 - loss: 0.4293 - val_auc: 0.8289 - val_loss: 0.6213
# Epoch 7/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.8910 - loss: 0.4126 - val_auc: 0.8344 - val_loss: 0.6087
# Epoch 8/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9022 - loss: 0.3922 - val_auc: 0.8392 - val_loss: 0.5948
# Epoch 9/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9023 - loss: 0.3908 - val_auc: 0.8394 - val_loss: 0.5960
# Epoch 10/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.9121 - loss: 0.3718 - val_auc: 0.8407 - val_loss: 0.5710
# Epoch 11/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9144 - loss: 0.3663 - val_auc: 0.8410 - val_loss: 0.5646
# Epoch 12/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9216 - loss: 0.3509 - val_auc: 0.8390 - val_loss: 0.5426
# Epoch 13/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9234 - loss: 0.3462 - val_auc: 0.8358 - val_loss: 0.5458
# Epoch 14/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.9280 - loss: 0.3369 - val_auc: 0.8375 - val_loss: 0.5365
# Epoch 15/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9326 - loss: 0.3246 - val_auc: 0.8345 - val_loss: 0.5405
# Epoch 16/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.9356 - loss: 0.3171 - val_auc: 0.8318 - val_loss: 0.5276
# Epoch 17/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.9409 - loss: 0.3057 - val_auc: 0.8266 - val_loss: 0.5149
# {'Dropout': 0.3, 'Val_TSS_Selected': np.float64(0.567), 'TSS': np.float64(0.3869), 'HSS': np.float64(0.3121), 'ROC_AUC': np.float64(0.7922), 'PR_AUC': np.float64(0.6536), 'Recall': 0.8318, 'Precision': 0.4495, 'F1': 0.5836, 'Best_Val_AUC': 0.841, 'AUC_Gap_Train_Minus_Val': 0.0734, 'Loss_Gap_Val_Minus_Train': 0.1983, 'Best_Epoch_By_Val_AUC': 11}
#
# ================================================================================
# 24h dropout sensitivity: BiLSTM, dropout=0.5
# ================================================================================
# Epoch 1/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - auc: 0.7820 - loss: 0.5866 - val_auc: 0.7849 - val_loss: 0.7096
# Epoch 2/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8376 - loss: 0.4978 - val_auc: 0.7908 - val_loss: 0.6463
# Epoch 3/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.8449 - loss: 0.4760 - val_auc: 0.7987 - val_loss: 0.6338
# Epoch 4/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8578 - loss: 0.4564 - val_auc: 0.8120 - val_loss: 0.6235
# Epoch 5/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - auc: 0.8728 - loss: 0.4416 - val_auc: 0.8228 - val_loss: 0.6184
# Epoch 6/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - auc: 0.8851 - loss: 0.4226 - val_auc: 0.8292 - val_loss: 0.6028
# Epoch 7/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - auc: 0.8860 - loss: 0.4231 - val_auc: 0.8333 - val_loss: 0.5996
# Epoch 8/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - auc: 0.8922 - loss: 0.4132 - val_auc: 0.8377 - val_loss: 0.5813
# Epoch 9/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - auc: 0.9012 - loss: 0.3988 - val_auc: 0.8393 - val_loss: 0.5745
# Epoch 10/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - auc: 0.9017 - loss: 0.3956 - val_auc: 0.8412 - val_loss: 0.5571
# Epoch 11/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.9070 - loss: 0.3828 - val_auc: 0.8396 - val_loss: 0.5596
# Epoch 12/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.9162 - loss: 0.3672 - val_auc: 0.8356 - val_loss: 0.5408
# Epoch 13/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9133 - loss: 0.3701 - val_auc: 0.8358 - val_loss: 0.5354
# Epoch 14/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.9128 - loss: 0.3693 - val_auc: 0.8359 - val_loss: 0.5319
# Epoch 15/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - auc: 0.9179 - loss: 0.3562 - val_auc: 0.8354 - val_loss: 0.5357
# Epoch 16/35
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.9219 - loss: 0.3532 - val_auc: 0.8310 - val_loss: 0.5244
# {'Dropout': 0.5, 'Val_TSS_Selected': np.float64(0.5605), 'TSS': np.float64(0.3986), 'HSS': np.float64(0.3169), 'ROC_AUC': np.float64(0.8061), 'PR_AUC': np.float64(0.6884), 'Recall': 0.8598, 'Precision': 0.4488, 'F1': 0.5897, 'Best_Val_AUC': 0.8412, 'AUC_Gap_Train_Minus_Val': 0.0606, 'Loss_Gap_Val_Minus_Train': 0.1615, 'Best_Epoch_By_Val_AUC': 10}
#   Horizon   Model Model_Type MA_Kernel  Dropout  Threshold  Val_TSS_Selected  \
# 0     24h  BiLSTM     bilstm       N/A      0.1       0.57          0.564980
# 1     24h  BiLSTM     bilstm       N/A      0.2       0.58          0.526290
# 2     24h  BiLSTM     bilstm       N/A      0.3       0.51          0.566964
# 3     24h  BiLSTM     bilstm       N/A      0.5       0.49          0.560516
#
#         TSS       HSS   ROC_AUC  ...  Epochs_Run  Train_N  Val_N  Test_N  \
# 0  0.434675  0.362217  0.809880  ...          13     1639    351     352
# 1  0.449285  0.371945  0.811482  ...          13     1639    351     352
# 2  0.386878  0.312119  0.792218  ...          17     1639    351     352
# 3  0.398589  0.316857  0.806103  ...          16     1639    351     352
#
#    Train_Pos  Val_Pos  Test_Pos  \
# 0        174       63       107
# 1        174       63       107
# 2        174       63       107
# 3        174       63       107
#
#                                   Learning_Curve_CSV  \
# 0  /content/drive/MyDrive/ASR_MAJOR_REVISION_OVER...
# 1  /content/drive/MyDrive/ASR_MAJOR_REVISION_OVER...
# 2  /content/drive/MyDrive/ASR_MAJOR_REVISION_OVER...
# 3  /content/drive/MyDrive/ASR_MAJOR_REVISION_OVER...
#
#                                       Loss_Curve_PNG  \
# 0  /content/drive/MyDrive/ASR_MAJOR_REVISION_OVER...
# 1  /content/drive/MyDrive/ASR_MAJOR_REVISION_OVER...
# 2  /content/drive/MyDrive/ASR_MAJOR_REVISION_OVER...
# 3  /content/drive/MyDrive/ASR_MAJOR_REVISION_OVER...
#
#                                        AUC_Curve_PNG
# 0  /content/drive/MyDrive/ASR_MAJOR_REVISION_OVER...
# 1  /content/drive/MyDrive/ASR_MAJOR_REVISION_OVER...
# 2  /content/drive/MyDrive/ASR_MAJOR_REVISION_OVER...
# 3  /content/drive/MyDrive/ASR_MAJOR_REVISION_OVER...
#
# [4 rows x 35 columns]
# Saved dropout sensitivity results to: /content/drive/MyDrive/ASR_MAJOR_REVISION_OVERFITTING/dropout_sensitivity/dropout_sensitivity_24h.csv
